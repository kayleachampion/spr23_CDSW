# %% [markdown]
# # GPT with Python

# %% [markdown]
# This command installs the `openai` package; you only need to run it once.

# %%
pip install openai
# Out:
# Requirement already satisfied: openai in /Users/joshuah/anaconda3/lib/python3.10/site-packages (0.27.6)
# Requirement already satisfied: tqdm in /Users/joshuah/anaconda3/lib/python3.10/site-packages (from openai) (4.64.1)
# Requirement already satisfied: aiohttp in /Users/joshuah/anaconda3/lib/python3.10/site-packages (from openai) (3.8.4)
# Requirement already satisfied: requests>=2.20 in /Users/joshuah/anaconda3/lib/python3.10/site-packages (from openai) (2.28.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/joshuah/anaconda3/lib/python3.10/site-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/joshuah/anaconda3/lib/python3.10/site-packages (from requests>=2.20->openai) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/joshuah/anaconda3/lib/python3.10/site-packages (from requests>=2.20->openai) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/joshuah/anaconda3/lib/python3.10/site-packages (from requests>=2.20->openai) (2022.12.7)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/joshuah/anaconda3/lib/python3.10/site-packages (from aiohttp->openai) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/joshuah/anaconda3/lib/python3.10/site-packages (from aiohttp->openai) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/joshuah/anaconda3/lib/python3.10/site-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/joshuah/anaconda3/lib/python3.10/site-packages (from aiohttp->openai) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/joshuah/anaconda3/lib/python3.10/site-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /Users/joshuah/anaconda3/lib/python3.10/site-packages (from aiohttp->openai) (22.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Get an API key from [OpenAI](https://platform.openai.com/) and put it into `my_keys.py` in this directory.
#
# Now we can load the package and use it.

# %%
import openai
import my_keys

openai.api_key = my_keys.openai_api_key

# %% [markdown]
# ChatGPT (GPT 3.5) uses a back-and-forth chat interface. So we prompt ChatGPT with a few chat messages.

# %%
response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "What do I do in Python to get something from a dictionary?"},
    ]
)

response
# Out:
# <OpenAIObject chat.completion id=chatcmpl-7JCtcPBXkS70EsTlr466lN0ibHmun at 0x1212b96c0> JSON: {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "message": {
#         "content": "To get a value from a dictionary in Python, you can use the square bracket notation with the key of the item you want to retrieve. For example, if you had a dictionary named `my_dict` with the keys `\"key1\"` and `\"key2\"`, you could get the value associated with `\"key1\"` like this:\n\n```\nmy_dict = {\"key1\": \"value1\", \"key2\": \"value2\"}\nvalue = my_dict[\"key1\"]\nprint(value)  # Output: \"value1\"\n```\n\nIf the key doesn't exist in the dictionary, this method will raise a `KeyError`. To avoid this, you can use the `.get()` method, which will return `None` (or a default value you specify) if the key is not found:\n\n```\nmy_dict = {\"key1\": \"value1\", \"key2\": \"value2\"}\nvalue = my_dict.get(\"key3\")\nprint(value)  # Output: None\n```",
#         "role": "assistant"
#       }
#     }
#   ],
#   "created": 1684812160,
#   "id": "chatcmpl-7JCtcPBXkS70EsTlr466lN0ibHmun",
#   "model": "gpt-3.5-turbo-0301",
#   "object": "chat.completion",
#   "usage": {
#     "completion_tokens": 203,
#     "prompt_tokens": 32,
#     "total_tokens": 235
#   }
# }

# %% [markdown]
# Aside from the weird `<OpenAIObject ...>` stuff, this looks like what you'd get from using `requests.get` and calling `.json()` on the response: a bunch of nested dictionaries and lists and such. We can drill down into it to get the useful part:

# %%
print(response['choices'][0]['message']['content'])
# Out:
# To get a value from a dictionary in Python, you can use the following syntax:
#
# ```python
# my_dict = {'key1': 'value1', 'key2': 'value2', 'key3': 'value3'}
# value = my_dict['key1']  # Access the value associated with 'key1'
# print(value)  # Output: 'value1'
# ```
#
# In the above example, we create a dictionary called `my_dict` that contains keys `'key1'`, `'key2'`, and `'key3'`, each with a corresponding value. We access the value associated with `'key1'` by using the syntax `my_dict['key1']`. Then, we assign this value to a variable called `value`. Finally, we print the value of `value`.

# %% [markdown]
# This is the kind of thing you'd expect to get through the ChatGPT interface!

# %% [markdown]
# ## GPT (without the Chat)

# %% [markdown]
# FYI: Before ChatGPT, there was good old GPT. GPT uses a more straightforward text-completion interface, rather than a chat-centered API. Here's how you use it:

# %%
prompt = "Hi! My name is"

response = openai.Completion.create(
    engine="text-curie-001",
    prompt=prompt,
    temperature=2,
)

response
# Out:
# <OpenAIObject text_completion id=cmpl-7JD0ml7vSjmildUEng4uaQ82VjFRT at 0x12366d210> JSON: {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " Connor Montgomery Hobbyon; most people just call me SpaThermo because I signed"
#     }
#   ],
#   "created": 1684812604,
#   "id": "cmpl-7JD0ml7vSjmildUEng4uaQ82VjFRT",
#   "model": "text-curie-001",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 5,
#     "total_tokens": 21
#   }
# }

# %%
print(prompt + response["choices"][0]["text"])
# Out:
# Hi! My name is Mickey and I'm an artist.
#
# Wow! That sounds really cool!

# %% [markdown]
# ChatGPT was trained to be a helpful chat assistant. GPT by itself is weirder, and really likes making things up. But it can be fun. And it can be a lot faster!

# %% [markdown]
# ## Processing data with a language model

# %%
import pandas as pd

df = pd.read_csv("Code_Complaints_and_Violations.csv")

df_smol = df.head(30).copy()

df_smol
# Out:
#       RecordNum RecordType RecordTypeMapped   RecordTypeDesc  \
# 0   001001-03CP  Complaint          Request     Construction
# 1   001002-03CP  Complaint          Request     Construction
# 2   001003-03CP  Complaint          Request  Vacant Building
# 3   001004-03CP  Complaint          Request         Land Use
# 4   001005-03CP  Complaint          Request         Land Use
# 5   001006-03CP  Complaint          Request     Construction
# 6   001007-03CP  Complaint          Request            Weeds
# 7   001008-03CP  Complaint          Request         Land Use
# 8   001009-03CP  Complaint          Request              NaN
# 9   001010-03CP  Complaint          Request              NaN
# 10  001011-03CP  Complaint          Request     Construction
# 11  001012-03CP  Complaint          Request            Weeds
# 12  001013-03CP  Complaint          Request            Weeds
# 13  001014-03CP  Complaint          Request     Construction
# 14  001015-03CP  Complaint          Request              NaN
# 15  001016-03CP  Complaint          Request            Weeds
# 16  001017-03CP  Complaint          Request            Weeds
# 17  001018-03CP  Complaint          Request         Land Use
# 18  001019-03CP  Complaint          Request         Land Use
# 19  001020-03CP  Complaint          Request            Weeds
# 20  001021-03CP  Complaint          Request         Land Use
# 21  001022-03CP  Complaint          Request     Construction
# 22  001023-03CP  Complaint          Request     Construction
# 23  001024-03CP  Complaint          Request              NaN
# 24  001025-03CP  Complaint          Request              NaN
# 25  001026-03CP  Complaint          Request              NaN
# 26  001027-03CP  Complaint          Request        Shoreline
# 27  001028-03CP  Complaint          Request         Land Use
# 28  001029-03CP  Complaint          Request         Land Use
# 29  001030-03CP  Complaint          Request         Land Use
#
#                                           Description    OpenDate  \
# 0   Elevator gets stuck at least 3 times a week, f...  2003-11-10
# 1   Concerned about RV pumpout that is currently b...  2003-11-10
# 2   The vacant red apple building and adjacent bui...  2003-11-10
# 3   Trailor and camper parked in back yard.  Peopl...  2003-11-10
# 4   Illegal use of property."Hawkers" or vendors (...  2003-11-10
# 5                                                 NaN  2003-11-10
# 6   Vegetation encroaching 5 ft onto sidewalk on t...  2003-11-10
# 7   Unit in basement advertised for rent.  The top...  2003-11-10
# 8   Water leaked into bedroom from rain.  Carpet h...  2003-11-10
# 9   Said heaters did not work but she will talk to...  2003-11-10
# 10                                                NaN  2003-11-10
# 11             Broken tree limbs hanging over street.  2003-11-10
# 12      Overgrowth on Newell Street side of property.  2003-11-10
# 13  Demolition in an ECA after October 31. Demolit...  2003-11-10
# 14  Tenant without shower since Monday.  Mgmt has ...  2003-11-10
# 15  Observed while re-inspecting adjacent property...  2003-11-10
# 16                          Overgrowth onto sidewalk.  2003-11-10
# 17            5-6 cats on the property in a SF5 zone.  2003-11-10
# 18  Someone living in camper in northeast corner o...  2003-11-10
# 19                                                NaN  2003-11-10
# 20  inoperable vehicles stored in front yard--junk...  2003-11-10
# 21  Built 12 ft x 12 ft attached addition to west ...  2003-11-10
# 22  Work w/o permit.Windows being replaced on the ...  2003-11-10
# 23  light fixture in stairwell of duplex does not ...  2003-11-10
# 24  mold inside bedroom window and on bathroom cei...  2003-11-10
# 25  broken clothes dryer--broken boards in floor o...  2003-11-10
# 26  Shoreline public access not provided as requir...  2003-11-12
# 27  Possible illegal home business: painting/build...  2003-11-12
# 28                     Parked cars on the front lawn.  2003-11-12
# 29  Dragging an extra sewer line for the R.V. park...  2003-11-12
#
#                          LastInspDate LastInspResult StatusCurrent  \
# 0   POINT (-122.33582172 47.60642293)      Completed     Completed
# 1   POINT (-122.35191884 47.68639169)      Completed     Completed
# 2   POINT (-122.31388805 47.61559829)      Completed     Completed
# 3   POINT (-122.36215164 47.69226044)      Completed     Completed
# 4   POINT (-122.33832038 47.60911773)      Completed     Completed
# 5   POINT (-122.37646766 47.51987357)      Completed     Completed
# 6   POINT (-122.27299176 47.56277982)      Completed     Completed
# 7   POINT (-122.35588241 47.53435301)      Completed     Completed
# 8   POINT (-122.32760387 47.61760046)      Completed     Completed
# 9   POINT (-122.32928651 47.72436569)            NaN     Completed
# 10  POINT (-122.36184719 47.55859477)      Completed     Completed
# 11  POINT (-122.31852856 47.61945997)      Completed     Completed
# 12  POINT (-122.35279984 47.64483395)      Completed     Completed
# 13  POINT (-122.39520009 47.51374663)      Completed     Completed
# 14  POINT (-122.32685399 47.70964995)            NaN     Completed
# 15  POINT (-122.27685898 47.54647421)      Completed     Completed
# 16     POINT (-122.3589485 47.627166)      Completed     Completed
# 17  POINT (-122.29045901 47.62234641)      Completed     Completed
# 18  POINT (-122.35522959 47.70656401)      Completed     Completed
# 19                                NaN      Completed     Completed
# 20  POINT (-122.30221301 47.61099075)      Completed     Completed
# 21  POINT (-122.29045901 47.62234641)      Completed     Completed
# 22  POINT (-122.32225108 47.59849998)      Completed     Completed
# 23   POINT (-122.2912118 47.62526387)            NaN     Completed
# 24    POINT (-122.3538566 47.6261401)      Completed     Completed
# 25  POINT (-122.31735107 47.60223849)      Completed     Completed
# 26  POINT (-122.32440186 47.64993516)      Completed     Completed
# 27  POINT (-122.36327086 47.67765205)      Completed     Completed
# 28  POINT (-122.35172373 47.70163114)            NaN     Completed
# 29  POINT (-122.35191884 47.68639169)      Completed     Completed
#
#               OriginalAddress1 OriginalCity OriginalState  OriginalZip  \
# 0                 1100 2ND AVE      SEATTLE            WA      98101.0
# 1                512 N 79TH ST      SEATTLE            WA      98103.0
# 2               1400 E PINE ST      SEATTLE            WA      98122.0
# 3               332 NW 87TH ST      SEATTLE            WA      98117.0
# 4                 1430 2ND AVE      SEATTLE            WA      98101.0
# 5             9238 35TH AVE SW      SEATTLE            WA      98126.0
# 6             4801 S OREGON ST      SEATTLE            WA      98118.0
# 7            1617 SW AUSTIN ST      SEATTLE            WA      98106.0
# 8             1718 MELROSE AVE      SEATTLE            WA      98122.0
# 9             13039 1ST AVE NE      SEATTLE            WA      98125.0
# 10            4821 23RD AVE SW      SEATTLE            WA      98106.0
# 11              121 11TH AVE E      SEATTLE            WA      98102.0
# 12          2703 MAYFAIR AVE N      SEATTLE            WA      98109.0
# 13           10001 51ST AVE SW      SEATTLE            WA      98146.0
# 14            11200 1ST AVE NE      SEATTLE            WA      98125.0
# 15          6211 RAINIER AVE S      SEATTLE            WA      98118.0
# 16               912 2ND AVE W      SEATTLE            WA      98119.0
# 17          3215 E HARRISON ST      SEATTLE            WA      98112.0
# 18       10552 GREENWOOD AVE N      SEATTLE            WA      98133.0
# 19                         NaN          NaN           NaN          NaN
# 20                932 23RD AVE      SEATTLE            WA      98122.0
# 21          3215 E HARRISON ST      SEATTLE            WA      98112.0
# 22               418 8TH AVE S      SEATTLE            WA      98104.0
# 23  600 LAKE WASHINGTON BLVD E      SEATTLE            WA      98112.0
# 24               155 VALLEY ST      SEATTLE            WA      98109.0
# 25                117 12TH AVE      SEATTLE            WA      98122.0
# 26         3123 FAIRVIEW AVE E      SEATTLE            WA      98102.0
# 27             6556 6TH AVE NW      SEATTLE            WA      98117.0
# 28              520 N 100TH ST      SEATTLE            WA      98133.0
# 29               512 N 79TH ST      SEATTLE            WA      98103.0
#
#                                                  Link   Latitude   Longitude  \
# 0   https://cosaccela.seattle.gov/portal/customize...  47.606423 -122.335822
# 1   https://cosaccela.seattle.gov/portal/customize...  47.686392 -122.351919
# 2   https://cosaccela.seattle.gov/portal/customize...  47.615598 -122.313888
# 3   https://cosaccela.seattle.gov/portal/customize...  47.692260 -122.362152
# 4   https://cosaccela.seattle.gov/portal/customize...  47.609118 -122.338320
# 5   https://cosaccela.seattle.gov/portal/customize...  47.519874 -122.376468
# 6   https://cosaccela.seattle.gov/portal/customize...  47.562780 -122.272992
# 7   https://cosaccela.seattle.gov/portal/customize...  47.534353 -122.355882
# 8   https://cosaccela.seattle.gov/portal/customize...  47.617600 -122.327604
# 9   https://cosaccela.seattle.gov/portal/customize...  47.724366 -122.329287
# 10  https://cosaccela.seattle.gov/portal/customize...  47.558595 -122.361847
# 11  https://cosaccela.seattle.gov/portal/customize...  47.619460 -122.318529
# 12  https://cosaccela.seattle.gov/portal/customize...  47.644834 -122.352800
# 13  https://cosaccela.seattle.gov/portal/customize...  47.513747 -122.395200
# 14  https://cosaccela.seattle.gov/portal/customize...  47.709650 -122.326854
# 15  https://cosaccela.seattle.gov/portal/customize...  47.546474 -122.276859
# 16  https://cosaccela.seattle.gov/portal/customize...  47.627166 -122.358948
# 17  https://cosaccela.seattle.gov/portal/customize...  47.622346 -122.290459
# 18  https://cosaccela.seattle.gov/portal/customize...  47.706564 -122.355230
# 19  https://cosaccela.seattle.gov/portal/customize...        NaN         NaN
# 20  https://cosaccela.seattle.gov/portal/customize...  47.610991 -122.302213
# 21  https://cosaccela.seattle.gov/portal/customize...  47.622346 -122.290459
# 22  https://cosaccela.seattle.gov/portal/customize...  47.598500 -122.322251
# 23  https://cosaccela.seattle.gov/portal/customize...  47.625264 -122.291212
# 24  https://cosaccela.seattle.gov/portal/customize...  47.626140 -122.353857
# 25  https://cosaccela.seattle.gov/portal/customize...  47.602238 -122.317351
# 26  https://cosaccela.seattle.gov/portal/customize...  47.649935 -122.324402
# 27  https://cosaccela.seattle.gov/portal/customize...  47.677652 -122.363271
# 28  https://cosaccela.seattle.gov/portal/customize...  47.701631 -122.351724
# 29  https://cosaccela.seattle.gov/portal/customize...  47.686392 -122.351919
#
#                        Location1
# 0   (47.60642293, -122.33582172)
# 1   (47.68639169, -122.35191884)
# 2   (47.61559829, -122.31388805)
# 3   (47.69226044, -122.36215164)
# 4   (47.60911773, -122.33832038)
# 5   (47.51987357, -122.37646766)
# 6   (47.56277982, -122.27299176)
# 7   (47.53435301, -122.35588241)
# 8   (47.61760046, -122.32760387)
# 9   (47.72436569, -122.32928651)
# 10  (47.55859477, -122.36184719)
# 11  (47.61945997, -122.31852856)
# 12  (47.64483395, -122.35279984)
# 13  (47.51374663, -122.39520009)
# 14  (47.70964995, -122.32685399)
# 15  (47.54647421, -122.27685898)
# 16     (47.627166, -122.3589485)
# 17  (47.62234641, -122.29045901)
# 18  (47.70656401, -122.35522959)
# 19                           NaN
# 20  (47.61099075, -122.30221301)
# 21  (47.62234641, -122.29045901)
# 22  (47.59849998, -122.32225108)
# 23   (47.62526387, -122.2912118)
# 24    (47.6261401, -122.3538566)
# 25  (47.60223849, -122.31735107)
# 26  (47.64993516, -122.32440186)
# 27  (47.67765205, -122.36327086)
# 28  (47.70163114, -122.35172373)
# 29  (47.68639169, -122.35191884)

# %%
df_smol["answer"] = pd.Series(dtype='string')

for i, row in df_smol.iterrows():
    if pd.isnull(row["Description"]): continue
    
    prompt = (
        "The following complaint was submitted to the Seattle Department of Construction & Inspections. " +
        "Classify it as related to animals, plants, or neither. " +
        "Your response should be simply 'animals', 'plants', or 'neither'. One word, all lowercase." +
        "\n\n" +
        row["Description"]
    )

    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "user", "content": prompt},
        ]
    )

#     response = openai.Completion.create(
#         engine="text-curie-001",
#         prompt=prompt
#     )

    print(row["Description"])
    answer = response["choices"][0]["message"]["content"]
#     print(response["choices"][0]["text"].strip())
    print(answer)
    print()
    df_smol["answer"][i] = answer
# Out:
# Elevator gets stuck at least 3 times a week, feels it is a danger.  Wants to keep a low profile, but will live name and number for contact.  Works on the 5th floor of WAMU building.
# neither
#
# Concerned about RV pumpout that is currently being installed.  Too close to property line and concerned someone will be living in trailer in SF zone.
# neither
#
# The vacant red apple building and adjacent building on lot are now the home to several homeless people.  The grounds are littered with beer bottles. Smell of urine all over property. Graffiti on building.  Fence surrounding building is frequently moved so people can get in and out of the premises.
# neither
#
# Trailor and camper parked in back yard.  People living in them.
# animals
#
# Illegal use of property."Hawkers" or vendors (retail sales) set up in parking lot.
# neither
#
# Vegetation encroaching 5 ft onto sidewalk on the north and west sides.
# plants
#
# Unit in basement advertised for rent.  The top floor is already rented could it be an illegal unit?
# neither
#
# Water leaked into bedroom from rain.  Carpet has mildewed and has not been replaced.  Outlets on wet wall spark or dont work.
# neither
#
# Said heaters did not work but she will talk to owners befroe she make her complaint.
# neither
#
# Broken tree limbs hanging over street.
# plants
#
# Overgrowth on Newell Street side of property.
# plants
#
# Demolition in an ECA after October 31. Demolition is causing tremendous vibration - can it be suggested to the owner to use a jack hammer or anything else other than the method which is being used: dropping the front end loader onto the foundation like a hammer.
# neither
#
# Tenant without shower since Monday.  Mgmt has not come back to complete repair of shower head.  Wall around shower damaged.
# neither
#
# Observed while re-inspecting adjacent property with blackberries overgrowing onto sidewalk.- Blackberries obstructing sidewalk.
# plants
#
# Overgrowth onto sidewalk.
# plants
#
# 5-6 cats on the property in a SF5 zone.
# animals
#
# Someone living in camper in northeast corner of car wash.
# neither
#
# inoperable vehicles stored in front yard--junk storage (carparts, appliances)--more than three vehicles parked on property
# neither
#
# Built 12 ft x 12 ft attached addition to west side of house about 2 months ago w/o permit.
# neither
#
# Work w/o permit.Windows being replaced on the Hip Sing Building (418-422 8th Ave. S.) without International Special Review District approval or DPD building permit.
# neither
#
# light fixture in stairwell of duplex does not work--leaves stairwell in total darkness--(the address of duplex is 608 but PTS address is 600 Lake Washington Bv E and includes both addresses--lots 1 & 2--see map)
# neither
#
# mold inside bedroom window and on bathroom ceiling and walls--there was a bathroom ceiling leak that was improperly repaired
# neither
#
# broken clothes dryer--broken boards in floor of front porch--electrical problems in bathroom caused by previous ceiling leak--floor in bathroom is rotten
# neither
#
# Shoreline public access not provided as required; land use/zoning (see original complaint)
# neither
#
# Possible illegal home business: painting/building signs in basement and can smell the fumes outside
# neither
#
# Parked cars on the front lawn.
# neither
#
# Dragging an extra sewer line for the R.V. parked in the rear yard to live in.  You can view it from the alley.
# animals

# %%
df_smol
# Out:
#       RecordNum RecordType RecordTypeMapped   RecordTypeDesc  \
# 0   001001-03CP  Complaint          Request     Construction
# 1   001002-03CP  Complaint          Request     Construction
# 2   001003-03CP  Complaint          Request  Vacant Building
# 3   001004-03CP  Complaint          Request         Land Use
# 4   001005-03CP  Complaint          Request         Land Use
# 5   001006-03CP  Complaint          Request     Construction
# 6   001007-03CP  Complaint          Request            Weeds
# 7   001008-03CP  Complaint          Request         Land Use
# 8   001009-03CP  Complaint          Request              NaN
# 9   001010-03CP  Complaint          Request              NaN
# 10  001011-03CP  Complaint          Request     Construction
# 11  001012-03CP  Complaint          Request            Weeds
# 12  001013-03CP  Complaint          Request            Weeds
# 13  001014-03CP  Complaint          Request     Construction
# 14  001015-03CP  Complaint          Request              NaN
# 15  001016-03CP  Complaint          Request            Weeds
# 16  001017-03CP  Complaint          Request            Weeds
# 17  001018-03CP  Complaint          Request         Land Use
# 18  001019-03CP  Complaint          Request         Land Use
# 19  001020-03CP  Complaint          Request            Weeds
# 20  001021-03CP  Complaint          Request         Land Use
# 21  001022-03CP  Complaint          Request     Construction
# 22  001023-03CP  Complaint          Request     Construction
# 23  001024-03CP  Complaint          Request              NaN
# 24  001025-03CP  Complaint          Request              NaN
# 25  001026-03CP  Complaint          Request              NaN
# 26  001027-03CP  Complaint          Request        Shoreline
# 27  001028-03CP  Complaint          Request         Land Use
# 28  001029-03CP  Complaint          Request         Land Use
# 29  001030-03CP  Complaint          Request         Land Use
#
#                                           Description    OpenDate  \
# 0   Elevator gets stuck at least 3 times a week, f...  2003-11-10
# 1   Concerned about RV pumpout that is currently b...  2003-11-10
# 2   The vacant red apple building and adjacent bui...  2003-11-10
# 3   Trailor and camper parked in back yard.  Peopl...  2003-11-10
# 4   Illegal use of property."Hawkers" or vendors (...  2003-11-10
# 5                                                 NaN  2003-11-10
# 6   Vegetation encroaching 5 ft onto sidewalk on t...  2003-11-10
# 7   Unit in basement advertised for rent.  The top...  2003-11-10
# 8   Water leaked into bedroom from rain.  Carpet h...  2003-11-10
# 9   Said heaters did not work but she will talk to...  2003-11-10
# 10                                                NaN  2003-11-10
# 11             Broken tree limbs hanging over street.  2003-11-10
# 12      Overgrowth on Newell Street side of property.  2003-11-10
# 13  Demolition in an ECA after October 31. Demolit...  2003-11-10
# 14  Tenant without shower since Monday.  Mgmt has ...  2003-11-10
# 15  Observed while re-inspecting adjacent property...  2003-11-10
# 16                          Overgrowth onto sidewalk.  2003-11-10
# 17            5-6 cats on the property in a SF5 zone.  2003-11-10
# 18  Someone living in camper in northeast corner o...  2003-11-10
# 19                                                NaN  2003-11-10
# 20  inoperable vehicles stored in front yard--junk...  2003-11-10
# 21  Built 12 ft x 12 ft attached addition to west ...  2003-11-10
# 22  Work w/o permit.Windows being replaced on the ...  2003-11-10
# 23  light fixture in stairwell of duplex does not ...  2003-11-10
# 24  mold inside bedroom window and on bathroom cei...  2003-11-10
# 25  broken clothes dryer--broken boards in floor o...  2003-11-10
# 26  Shoreline public access not provided as requir...  2003-11-12
# 27  Possible illegal home business: painting/build...  2003-11-12
# 28                     Parked cars on the front lawn.  2003-11-12
# 29  Dragging an extra sewer line for the R.V. park...  2003-11-12
#
#                          LastInspDate LastInspResult StatusCurrent  \
# 0   POINT (-122.33582172 47.60642293)      Completed     Completed
# 1   POINT (-122.35191884 47.68639169)      Completed     Completed
# 2   POINT (-122.31388805 47.61559829)      Completed     Completed
# 3   POINT (-122.36215164 47.69226044)      Completed     Completed
# 4   POINT (-122.33832038 47.60911773)      Completed     Completed
# 5   POINT (-122.37646766 47.51987357)      Completed     Completed
# 6   POINT (-122.27299176 47.56277982)      Completed     Completed
# 7   POINT (-122.35588241 47.53435301)      Completed     Completed
# 8   POINT (-122.32760387 47.61760046)      Completed     Completed
# 9   POINT (-122.32928651 47.72436569)            NaN     Completed
# 10  POINT (-122.36184719 47.55859477)      Completed     Completed
# 11  POINT (-122.31852856 47.61945997)      Completed     Completed
# 12  POINT (-122.35279984 47.64483395)      Completed     Completed
# 13  POINT (-122.39520009 47.51374663)      Completed     Completed
# 14  POINT (-122.32685399 47.70964995)            NaN     Completed
# 15  POINT (-122.27685898 47.54647421)      Completed     Completed
# 16     POINT (-122.3589485 47.627166)      Completed     Completed
# 17  POINT (-122.29045901 47.62234641)      Completed     Completed
# 18  POINT (-122.35522959 47.70656401)      Completed     Completed
# 19                                NaN      Completed     Completed
# 20  POINT (-122.30221301 47.61099075)      Completed     Completed
# 21  POINT (-122.29045901 47.62234641)      Completed     Completed
# 22  POINT (-122.32225108 47.59849998)      Completed     Completed
# 23   POINT (-122.2912118 47.62526387)            NaN     Completed
# 24    POINT (-122.3538566 47.6261401)      Completed     Completed
# 25  POINT (-122.31735107 47.60223849)      Completed     Completed
# 26  POINT (-122.32440186 47.64993516)      Completed     Completed
# 27  POINT (-122.36327086 47.67765205)      Completed     Completed
# 28  POINT (-122.35172373 47.70163114)            NaN     Completed
# 29  POINT (-122.35191884 47.68639169)      Completed     Completed
#
#               OriginalAddress1 OriginalCity OriginalState  OriginalZip  \
# 0                 1100 2ND AVE      SEATTLE            WA      98101.0
# 1                512 N 79TH ST      SEATTLE            WA      98103.0
# 2               1400 E PINE ST      SEATTLE            WA      98122.0
# 3               332 NW 87TH ST      SEATTLE            WA      98117.0
# 4                 1430 2ND AVE      SEATTLE            WA      98101.0
# 5             9238 35TH AVE SW      SEATTLE            WA      98126.0
# 6             4801 S OREGON ST      SEATTLE            WA      98118.0
# 7            1617 SW AUSTIN ST      SEATTLE            WA      98106.0
# 8             1718 MELROSE AVE      SEATTLE            WA      98122.0
# 9             13039 1ST AVE NE      SEATTLE            WA      98125.0
# 10            4821 23RD AVE SW      SEATTLE            WA      98106.0
# 11              121 11TH AVE E      SEATTLE            WA      98102.0
# 12          2703 MAYFAIR AVE N      SEATTLE            WA      98109.0
# 13           10001 51ST AVE SW      SEATTLE            WA      98146.0
# 14            11200 1ST AVE NE      SEATTLE            WA      98125.0
# 15          6211 RAINIER AVE S      SEATTLE            WA      98118.0
# 16               912 2ND AVE W      SEATTLE            WA      98119.0
# 17          3215 E HARRISON ST      SEATTLE            WA      98112.0
# 18       10552 GREENWOOD AVE N      SEATTLE            WA      98133.0
# 19                         NaN          NaN           NaN          NaN
# 20                932 23RD AVE      SEATTLE            WA      98122.0
# 21          3215 E HARRISON ST      SEATTLE            WA      98112.0
# 22               418 8TH AVE S      SEATTLE            WA      98104.0
# 23  600 LAKE WASHINGTON BLVD E      SEATTLE            WA      98112.0
# 24               155 VALLEY ST      SEATTLE            WA      98109.0
# 25                117 12TH AVE      SEATTLE            WA      98122.0
# 26         3123 FAIRVIEW AVE E      SEATTLE            WA      98102.0
# 27             6556 6TH AVE NW      SEATTLE            WA      98117.0
# 28              520 N 100TH ST      SEATTLE            WA      98133.0
# 29               512 N 79TH ST      SEATTLE            WA      98103.0
#
#                                                  Link   Latitude   Longitude  \
# 0   https://cosaccela.seattle.gov/portal/customize...  47.606423 -122.335822
# 1   https://cosaccela.seattle.gov/portal/customize...  47.686392 -122.351919
# 2   https://cosaccela.seattle.gov/portal/customize...  47.615598 -122.313888
# 3   https://cosaccela.seattle.gov/portal/customize...  47.692260 -122.362152
# 4   https://cosaccela.seattle.gov/portal/customize...  47.609118 -122.338320
# 5   https://cosaccela.seattle.gov/portal/customize...  47.519874 -122.376468
# 6   https://cosaccela.seattle.gov/portal/customize...  47.562780 -122.272992
# 7   https://cosaccela.seattle.gov/portal/customize...  47.534353 -122.355882
# 8   https://cosaccela.seattle.gov/portal/customize...  47.617600 -122.327604
# 9   https://cosaccela.seattle.gov/portal/customize...  47.724366 -122.329287
# 10  https://cosaccela.seattle.gov/portal/customize...  47.558595 -122.361847
# 11  https://cosaccela.seattle.gov/portal/customize...  47.619460 -122.318529
# 12  https://cosaccela.seattle.gov/portal/customize...  47.644834 -122.352800
# 13  https://cosaccela.seattle.gov/portal/customize...  47.513747 -122.395200
# 14  https://cosaccela.seattle.gov/portal/customize...  47.709650 -122.326854
# 15  https://cosaccela.seattle.gov/portal/customize...  47.546474 -122.276859
# 16  https://cosaccela.seattle.gov/portal/customize...  47.627166 -122.358948
# 17  https://cosaccela.seattle.gov/portal/customize...  47.622346 -122.290459
# 18  https://cosaccela.seattle.gov/portal/customize...  47.706564 -122.355230
# 19  https://cosaccela.seattle.gov/portal/customize...        NaN         NaN
# 20  https://cosaccela.seattle.gov/portal/customize...  47.610991 -122.302213
# 21  https://cosaccela.seattle.gov/portal/customize...  47.622346 -122.290459
# 22  https://cosaccela.seattle.gov/portal/customize...  47.598500 -122.322251
# 23  https://cosaccela.seattle.gov/portal/customize...  47.625264 -122.291212
# 24  https://cosaccela.seattle.gov/portal/customize...  47.626140 -122.353857
# 25  https://cosaccela.seattle.gov/portal/customize...  47.602238 -122.317351
# 26  https://cosaccela.seattle.gov/portal/customize...  47.649935 -122.324402
# 27  https://cosaccela.seattle.gov/portal/customize...  47.677652 -122.363271
# 28  https://cosaccela.seattle.gov/portal/customize...  47.701631 -122.351724
# 29  https://cosaccela.seattle.gov/portal/customize...  47.686392 -122.351919
#
#                        Location1   answer
# 0   (47.60642293, -122.33582172)  neither
# 1   (47.68639169, -122.35191884)  neither
# 2   (47.61559829, -122.31388805)  neither
# 3   (47.69226044, -122.36215164)  animals
# 4   (47.60911773, -122.33832038)  neither
# 5   (47.51987357, -122.37646766)     <NA>
# 6   (47.56277982, -122.27299176)   plants
# 7   (47.53435301, -122.35588241)  neither
# 8   (47.61760046, -122.32760387)  neither
# 9   (47.72436569, -122.32928651)  neither
# 10  (47.55859477, -122.36184719)     <NA>
# 11  (47.61945997, -122.31852856)   plants
# 12  (47.64483395, -122.35279984)   plants
# 13  (47.51374663, -122.39520009)  neither
# 14  (47.70964995, -122.32685399)  neither
# 15  (47.54647421, -122.27685898)   plants
# 16     (47.627166, -122.3589485)   plants
# 17  (47.62234641, -122.29045901)  animals
# 18  (47.70656401, -122.35522959)  neither
# 19                           NaN     <NA>
# 20  (47.61099075, -122.30221301)  neither
# 21  (47.62234641, -122.29045901)  neither
# 22  (47.59849998, -122.32225108)  neither
# 23   (47.62526387, -122.2912118)  neither
# 24    (47.6261401, -122.3538566)  neither
# 25  (47.60223849, -122.31735107)  neither
# 26  (47.64993516, -122.32440186)  neither
# 27  (47.67765205, -122.36327086)  neither
# 28  (47.70163114, -122.35172373)  neither
# 29  (47.68639169, -122.35191884)  animals

# %%
type(Out[44])
# Out:
# pandas._libs.missing.NAType
