# %%
#0 Setup
from ssadata import boys, girls
for name in boys.keys():
    if name == "mako":
        print("There were " + str(boys[name]) + " boys named " + name)
# Out:
# There were 24 boys named mako

# %%
for name in boys.keys():
    if name in girls.keys():
        print(name)
# Out:
# liam
# noah
# oliver
# elijah
# james
# william
# benjamin
# lucas
# henry
# theodore
# jack
# levi
# alexander
# jackson
# mateo
# daniel
# michael
# mason
# sebastian
# ethan
# logan
# owen
# samuel
# jacob
# asher
# aiden
# john
# joseph
# wyatt
# david
# leo
# luke
# julian
# hudson
# grayson
# matthew
# ezra
# gabriel
# carter
# jayden
# luca
# anthony
# dylan
# lincoln
# thomas
# maverick
# elias
# josiah
# caleb
# christopher
# ezekiel
# miles
# jaxon
# isaiah
# andrew
# nathan
# nolan
# adrian
# cameron
# santiago
# eli
# aaron
# ryan
# angel
# cooper
# waylon
# easton
# kai
# christian
# landon
# colton
# roman
# axel
# brooks
# jonathan
# jameson
# ian
# everett
# greyson
# wesley
# jeremiah
# hunter
# jordan
# jose
# bennett
# silas
# parker
# beau
# weston
# austin
# connor
# carson
# dominic
# xavier
# jaxson
# jace
# emmett
# declan
# rowan
# micah
# kayden
# gael
# river
# ryder
# kingston
# sawyer
# luka
# evan
# legend
# myles
# harrison
# august
# bryson
# amir
# ...

# %%
#1 Your own name!
if "Lori" == boys.keys():
    print("There were " + str(boys["Lori"]) + " boys named " + "Lori")
else:
    print("You are the only one!")
# Out:
# You are the only one!

# %%
if "Lori" == girls.keys():
    print("There were " + str(girls["Lori"]) + " girlds named " + "Lori")
else:
    print("You are the only one!")
# Out:
# You are the only one!

# %%
#2 Every baby counts
##2.1 How many boy names and girl names are described in the dataset

len(boys)
# Out:
# 13993

# %%
len(girls)
# Out:
# 17544

# %%
len(boys)+len(girls)
# Out:
# 31537

# %%
##2.2 How many boys and girls (actual babies!) are described in the dataset?
sum(boys.values())
# Out:
# 1734277

# %%
sum(girls.values())
# Out:
# 1627098

# %%
sum(boys.values())+sum(girls.values())
# Out:
# 3361375

# %%
#3 A sense of what's common

# %%
##3.1 What is the most common name for each gender in your data (i.e. 2021)?
for name,number in boys.items():
    if number==max(boys.values()):
        print(name)
# Out:
# liam

# %%
for name,number in girls.items():
    if number==max(girls.values()):
        print(name)
# Out:
# olivia

# %%
##3.2 What is the least common name?
min_boys={}
min_girls={}
for boyname,number in boys.items():
    if number==min(boys.values()):
        min_boys[boyname]=number
        
for girlname,number in girls.items():
    if number==min(girls.values()):
         min_girls[girlname]=number

# %%
if min(boys.values())<min(girls.values()):
    print(min_boys)
elif min(boys.values())>min(girls.values()):
    print(min_girls)
else:
    min_name={}
    min_name.update(min_boys)
    min_name.update(min_girls)
    print(min_name)
# Out:
# {'aadith': 5, 'aaidyn': 5, 'aaliyan': 5, 'aang': 5, 'aansh': 5, 'aaqil': 5, 'aaravreddy': 5, 'aaryash': 5, 'aashay': 5, 'aavi': 5, 'ab': 5, 'abdihafid': 5, 'abdulai': 5, 'abdulkabir': 5, 'abdulsalam': 5, 'abdurahmon': 5, 'absalom': 5, 'abshir': 5, 'abubacarr': 5, 'acetyn': 5, 'acey': 5, 'acheron': 5, 'achim': 5, 'acie': 5, 'action': 5, 'adaiah': 5, 'addler': 5, 'adewale': 5, 'adis': 5, 'adisa': 5, 'adith': 5, 'adlan': 5, 'adorian': 5, 'adream': 5, 'adrienne': 5, 'adris': 5, 'adron': 5, 'aegan': 5, 'aelius': 5, 'aeros': 5, 'aerys': 5, 'aesop': 5, 'agamjot': 5, 'ahiyan': 5, 'ahkai': 5, 'ahlee': 5, 'ahlijah': 5, 'ahman': 5, 'ahmi': 5, 'ahsaan': 5, 'ahsai': 5, 'ahsaun': 5, 'aidynn': 5, 'aikam': 5, 'aireon': 5, 'aires': 5, 'airis': 5, 'airo': 5, 'aison': 5, 'aisyn': 5, 'ajeet': 5, 'ajith': 5, 'akachukwu': 5, 'akito': 5, 'alaki': 5, 'alameen': 5, 'alante': 5, 'alastar': 5, 'alayan': 5, 'albara': 5, 'albino': 5, 'alby': 5, 'aldahir': 5, 'aldwin': 5, 'alecxander': 5, 'alef': 5, 'aleix': 5, '
# ...

# %%
##3.3How often do the least common names occur? (Does your answer to this question bother you? Why?)
names={}
names.update(boys)
names.update(girls)

if min(boys.values())<min(girls.values()):
    print(len(min_boys)/len(names))
elif min(boys.values())>min(girls.values()):
    print(len(min_girls)/len(names))
else:
    min_name={}
    min_name.update(min_boys)
    min_name.update(min_girls)
    print(len(min_name)/len(names))
# Out:
# 0.1493698135481407

# %%
#4 She wasn't long for this dataset

# %%
##4.1 What is the longest name in the dataset? How many boys/girls names are exactly that length? What's going on?
#count the chaacters
name_length = []

for name in boys.keys():
    name_length.append(len(name))
for name in girls.keys():
    name_length.append(len(name))
max_name_length = max(name_length)
 
print(longest_length)


for name in names.keys():
    if int(len(name))==max_name_length:
        print(name)
# Out:
# 15
# christopherjohn
# muhammadibrahim

# %%
#5 Initials to spreadsheets

# %%
##5.1 Make a dictionary girl_initials that says, for each letter of the alphabet (a-z), how many unique girl names begin with that letter.
from ssadata import boys, girls
girl_initials = {}

for names in girls.keys():
    first_letter = names[0]
    if first_letter in girl_initials.keys():
        girl_initials[first_letter] += 1       
    else:
        girl_initials[first_letter] = 1

girl_initials

###how to make them in the alphabet order?
###if not unique, should we mutiple the "values"?
# Out:
# {'o': 174,
#  'e': 995,
#  'c': 775,
#  'a': 2739,
#  's': 1227,
#  'i': 379,
#  'm': 1524,
#  'h': 471,
#  'l': 1024,
#  'g': 322,
#  'p': 270,
#  'n': 745,
#  'v': 209,
#  'r': 896,
#  'z': 528,
#  'w': 138,
#  'k': 1571,
#  'd': 702,
#  'b': 602,
#  'j': 1087,
#  'q': 41,
#  'x': 86,
#  'f': 210,
#  't': 521,
#  'y': 280,
#  'u': 28}

# %%
##5.2Do the same for boy names to make boy_initials.
boy_initials = {}

for names in boys.keys():
    first_letter = names[0]
    if first_letter in boy_initials.keys():
        boy_initials[first_letter] += 1       
    else:
        boy_initials[first_letter] = 1

boy_initials
# Out:
# {'l': 528,
#  'n': 442,
#  'o': 251,
#  'e': 606,
#  'j': 1191,
#  'w': 206,
#  'b': 626,
#  'h': 406,
#  't': 691,
#  'a': 1599,
#  'm': 942,
#  'd': 865,
#  's': 819,
#  'g': 318,
#  'c': 692,
#  'i': 251,
#  'r': 776,
#  'k': 1352,
#  'p': 209,
#  'x': 72,
#  'v': 165,
#  'z': 415,
#  'f': 214,
#  'q': 52,
#  'u': 43,
#  'y': 262}

# %%
##5.3Create a "tab separated values" (TSV) file that reports the data in girl_initials. Be sure to include a descriptive header columns! You will probably want the file to end with .tsv so that your computer knows it's a TSV file.
with open("girl_initials.tsv", "w") as my_file:
    print("letter \t number of unique names", file = my_file)
    for letter in girl_initials.keys():
        print(f"{letter}\t{girl_initials[letter]}", file=my_file)

# %%
##5.4 Now do the same for boy_initials (be sure to save it into a different file!)
with open("boy_initials.tsv", "w") as my_file:
    print("letter \t number of unique names", file = my_file)
    for letter in boy_initials.keys():
        print(f"{letter}\t{boy_initials[letter]}", file=my_file)

# %%
##5.5 Once you've done this, load up the two files into Google Sheets or Excel.
#girl_initials https://docs.google.com/spreadsheets/d/1medmiWCZqHGV2PkHUyM_TFWPzg8Tp0d7oIbf_Ub-bF8/edit?usp=sharing
#boy_initials https://docs.google.com/spreadsheets/d/15THEkeqER3myVdK3aC-vFzBEyOH5Pgemo47ZW3E4Uos/edit?usp=sharing

# %%
#5.6 For every letter, be ready to tell if there are more boys names or girls names.
for letter in boy_initials.keys():
    if letter in girl_initials.keys():
        if boy_initials[letter]>girl_initials[letter]:
            print(letter,"Boys are more")
        elif boy_initials[letter]<girl_initials[letter]:
            print(letter,"Girls are more")
        else:
            print(letter,"Exact same!")
    else:
        print(letter,"just boy have this" )
# Out:
# l Girls are more
# n Girls are more
# o Boys are more
# e Girls are more
# j Boys are more
# w Boys are more
# b Boys are more
# h Girls are more
# t Boys are more
# a Girls are more
# m Girls are more
# d Boys are more
# s Girls are more
# g Girls are more
# c Girls are more
# i Girls are more
# r Girls are more
# k Girls are more
# p Girls are more
# x Girls are more
# v Girls are more
# z Girls are more
# f Boys are more
# q Boys are more
# u Boys are more
# y Girls are more

# %%
##5.7 Play around with graphing and see if you can build some instructive graph that shows us something.
import matplotlib.pyplot as plt
for letter,number in boy_initials.items():
    plt.plot(letter, number, color='green', linewidth=2, marker='o', markersize=8)
    plt.title('boy name initials')
    plt.xlabel('letter')
    plt.ylabel('number')
    plt.grid(True)

plt.show()

# %%
#6 Concentration in names

# %%
##6.1 What percentage of boys have one of the 10 most popular boys names?What percentage of girls have one of the 10 most popular girls names?
for name,number in boys.items():
    count_boys_top_10 = sum(list(boys.values())[:10])
    
rate=(count_boys_top_10/sum(boys.values()))
percentage='{:.2%}'.format(rate)
      
print(percentage)


for name,number in girls.items():
    count_girls_top_10 = sum(list(girls.values())[:10])
    
rate=(count_girls_top_10/sum(girls.values()))
percentage='{:.2%}'.format(rate)
      
print(percentage)
# Out:
# 7.78%
# 7.67%

# %%
##6.2 Take the top 10% most popular boys names. (For instance: If there were 500 boys names, we're looking for the 50 most popular ones.) How many girls were given one of those names? 
##6.2Take the top 10% most popular girls names. How many boys were given one of those names?
#先算总数 再算10%是多少个  再按人数排列  提取前10% keys
sum_boy_uniqename=[]
for names in boys.keys():
    sum_boy_uniqename.append(names)
    
boys10percent=int(len(sum_boy_uniqename))*(1/10)
print(boys10percent)

boy_number=[]
boy_10popular=[]
for numbers in boys.values():
    boy_number.append(numbers)
sorted(boy_number)
boy_10popular=boy_number[0:10]
print(boy_10popular)

popular_boyname = [name for name, number in boys.items() if number in boy_10popular]
print(popular_boyname)

for name in popular_boyname:
    if name in girls.keys():
        print(name,girls[name])
    elif name not in girls.keys():
        print(name,"just boys have this name")
# Out:
# 1399.3000000000002
# [20272, 18739, 14616, 12708, 12367, 12088, 11791, 11501, 11307, 9535]
# ['liam', 'noah', 'oliver', 'elijah', 'james', 'william', 'benjamin', 'lucas', 'henry', 'theodore']
# liam 30
# noah 415
# oliver 25
# elijah 28
# james 67
# william 21
# benjamin 11
# lucas 5
# henry 15
# theodore 8

# %%
##6.2 Take the top 10% most popular boys names. (For instance: If there were 500 boys names, we're looking for the 50 most popular ones.) How many girls were given one of those names? 
##6.2Take the top 10% most popular girls names. How many boys were given one of those names?
#先算总数 再算10%是多少个  再按人数排列  提取前10% keys
sum_girl_uniqename=[]
for names in girls.keys():
    sum_girl_uniqename.append(names)
    
girls10percent=int(len(sum_girl_uniqename))*(1/10)
print(girls10percent)

girl_number=[]
girl_10popular=[]
for numbers in girls.values():
    girl_number.append(numbers)
sorted(girl_number)
girl_10popular=girl_number[0:10]
print(girl_10popular)

popular_girlname = [name for name, number in girls.items() if number in girl_10popular]
print(popular_girlname)

for name in popular_girlname:
    if name in boys.keys():
        print(name,boys[name])
    elif name not in boys.keys():
        print(name,"just boys have this name")
# Out:
# 1754.4
# [17728, 15433, 13285, 12952, 12759, 12496, 11201, 11096, 9434, 8388]
# ['olivia', 'emma', 'charlotte', 'amelia', 'ava', 'sophia', 'isabella', 'mia', 'evelyn', 'harper']
# olivia 9
# emma 14
# charlotte 13
# amelia 8
# ava 8
# sophia 10
# isabella 9
# mia 10
# evelyn 9
# harper 149

# %%
#7 Something extra

# %%
##7.1 Discover at least one fact about the names that is not listed above! Include the code, and a description of your observation written in English text, into your notebook.
#What names begin with two consecutive letters?
for name in boys.keys():
    if name[0:2]==["ab","bc","cd","de","ef","fg","gh","hi","ij","jk","kl","lm","mn","no","op","pq","qr","rs","st","tu","uv","vw","wx","xy","yz"]:
        print(name)
    else:
        print("No way!")


for name in girls.keys():
    if name[0:2]==["ab","bc","cd","de","ef","fg","gh","hi","ij","jk","kl","lm","mn","no","op","pq","qr","rs","st","tu","uv","vw","wx","xy","yz"]:
        print(name)
    else:
        print("No way!")
# Out:
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# No way!
# ...

# %%
#8 Thinking about this dataset
##What are some questions you have about this dataset and it was collected or created? What is at least two challenges that people creating this dataset must have faced? How did they resolve them? What are some assumptions they faced?
###QUESTIONS:
###What was the data source for this dataset?
###Are these names sorted by popularity in a specific state, region, or the entire country?

###CHALLENGES:
###Hard to ensure that the names and their corresponding counts are accurate and free of errors or duplications.
###Hard to determine the most appropriate way to represent the data. 

###Assumptions:
###The dataset assumes that the data is comprehensive and that all names given to babies in the United States during the time period covered are included.
