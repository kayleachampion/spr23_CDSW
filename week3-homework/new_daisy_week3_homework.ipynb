# %%
from ssadata import boys, girls

# %%
for name in boys.keys():
    if name == "mako":
        print("There were " + str(boys[name]) + " boys named " + name)
# Out:
# There were 24 boys named mako

# %% [markdown]
# ### Print all the boy's names that are also girl's names

# %%
for name in boys.keys():
    if name in girls.keys():
        print(name)
# Out:
# liam
# noah
# oliver
# elijah
# james
# william
# benjamin
# lucas
# henry
# theodore
# jack
# levi
# alexander
# jackson
# mateo
# daniel
# michael
# mason
# sebastian
# ethan
# logan
# owen
# samuel
# jacob
# asher
# aiden
# john
# joseph
# wyatt
# david
# leo
# luke
# julian
# hudson
# grayson
# matthew
# ezra
# gabriel
# carter
# jayden
# luca
# anthony
# dylan
# lincoln
# thomas
# maverick
# elias
# josiah
# caleb
# christopher
# ezekiel
# miles
# jaxon
# isaiah
# andrew
# nathan
# nolan
# adrian
# cameron
# santiago
# eli
# aaron
# ryan
# angel
# cooper
# waylon
# easton
# kai
# christian
# landon
# colton
# roman
# axel
# brooks
# jonathan
# jameson
# ian
# everett
# greyson
# wesley
# jeremiah
# hunter
# jordan
# jose
# bennett
# silas
# parker
# beau
# weston
# austin
# connor
# carson
# dominic
# xavier
# jaxson
# jace
# emmett
# declan
# rowan
# micah
# kayden
# gael
# river
# ryder
# kingston
# sawyer
# luka
# evan
# legend
# myles
# harrison
# august
# bryson
# amir
# giovanni
# chase
# milo
# jasper
# walker
# brayden
# cole
# george
# zion
# luis
# archer
# jonah
# theo
# ayden
# calvin
# braxton
# ashton
# rhett
# atlas
# jude
# bentley
# ryker
# adriel
# ace
# tyler
# jayce
# max
# elliot
# graham
# kaiden
# maxwell
# dean
# malachi
# elliott
# jesus
# messiah
# maddox
# camden
# hayden
# tucker
# judah
# finn
# king
# brody
# xander
# charlie
# arlo
# emmanuel
# barrett
# felix
# alex
# abel
# beckett
# amari
# karter
# jesse
# zayden
# blake
# dawson
# tristan
# avery
# joel
# knox
# beckham
# adonis
# kyrie
# hayes
# caden
# remington
# griffin
# nash
# israel
# holden
# zane
# kash
# preston
# kyler
# jax
# jett
# riley
# phoenix
# bryce
# cash
# lennox
# paxton
# malakai
# nico
# kaden
# lane
# kairo
# finley
# atticus
# crew
# brantley
# colin
# dallas
# brady
# callum
# ronan
# hendrix
# clayton
# emerson
# zayn
# kayson
# bodhi
# bryan
# aidan
# cohen
# cayden
# niko
# khalil
# rory
# cruz
# kobe
# reid
# jensen
# karson
# tate
# jaden
# gideon
# cody
# bradley
# orion
# spencer
# jaylen
# ellis
# cairo
# gunner
# wade
# chance
# anderson
# aziel
# rylan
# ali
# cade
# ari
# kameron
# dakota
# warren
# killian
# cyrus
# tyson
# nasir
# remy
# tanner
# lawson
# kyle
# corbin
# bowen
# wilder
# armani
# royal
# stetson
# briggs
# sullivan
# callan
# finnegan
# jay
# zayne
# marshall
# kade
# sterling
# raiden
# tatum
# zyaire
# milan
# devin
# gianni
# kamari
# royce
# franklin
# clark
# noel
# archie
# apollo
# oakley
# memphis
# quinn
# onyx
# alijah
# baylor
# nehemiah
# winston
# major
# rhys
# forrest
# jaiden
# reed
# troy
# caiden
# harvey
# collin
# sage
# grady
# kendrick
# leland
# johnny
# kashton
# ronin
# porter
# inez
# inioluwa
# irish
# ishimwe
# isra
# ivey
# iyah
# iyanu
# jaior
# jayde
# jazel
# jermoni
# josie
# journi
# judaea
# juni
# jwan
# kamarri
# kamrynn
# kashi
# kavani
# keari
# keatyn
# kelin
# kentley
# kestrel
# keyoni
# khole
# khyza
# kollyn
# kourtney
# kova
# kyndal
# lacey
# laikyn
# lakelyn
# legacee
# legacie
# lennie
# leoni
# louise
# lyla
# lynnex
# macklyn
# marian
# marlen
# marsai
# mayar
# mayce
# mazzy
# meerab
# milani
# millie
# miranda
# mitsuki
# munachi
# musiq
# ocie
# oluwaferanmi
# osinachi
# paisley
# paysen
# paz
# peyson
# preslee
# quincee
# raelynn
# raheel
# raygen
# raylynn
# remmi
# renlee
# rennie
# reylin
# rhemi
# rhettlee
# riko
# riplee
# roary
# rorey
# rudi
# sacred
# sadie
# sadler
# san
# sanai
# seyven
# shaddai
# skylin
# slone
# soni
# star
# starling
# stellar
# stori
# summer
# sutten
# tam
# taylyn
# terryn
# thyri
# trhue
# victorious
# wrenly
# yacine
# yancy
# yue
# yuli
# zani
# zari
# zariel
# zaylynn
# zyn

# %% [markdown]
# ### How many boys are named 'King'?

# %%
for name in boys.keys():
    if 'king' == name:
        print(name + " " + str(boys[name]))
# Out:
# king 2028

# %% [markdown]
#  ### How many girls are named 'Queen'?

# %%
for name in girls.keys():
    if 'queen' == name:
        print(name + " " + str(girls[name]))
# Out:
# queen 216

# %%
#1 Your own name!
print("There were " + str(girls["daisy"]) + " named daisy")
# Out:
# There were 2062 named daisy

# %%
#2 Every baby counts ?
#2.1

print(len(boys.keys()))
print(len(girls.keys()))

#2.2 
boy_counts = 0
for name_count in boys.values():
    boy_counts += name_count 

girl_counts = 0
for name_count in girls.values():
    girl_counts += name_count
    
print(f'There were {boy_counts} boys')
print(f'There were {girl_counts} girls')
# Out:
# 13993
# 17544
# There were 1734277 boys
# There were 1627098 girls

# %%
#3 A sense of what's common
#3.1
common_boy_count = 0
common_boy_name = ""
for name, count in boys.items():
    if count > common_boy_count:
        common_boy_name = name
        common_boy_count = count
print(common_boy_name)

common_girl_count = 0
common_girl_name = ""
for name, count in girls.items():
    if count > common_girl_count:
        common_girl_name = name
        common_girl_count = count
print(common_girl_name)
# Out:
# liam
# olivia

# %%
#3.2
least_common_boy_count = common_boy_count
least_common_boy_name = ""
for name, count in boys.items():
    if count < common_boy_count:
        least_common_boy_name = name
        least_common_boy_count = count
print(least_common_boy_name)
print(least_common_boy_count)

least_common_girl_count = common_girl_count
least_common_girl_name = ""
for name, count in girls.items():
    if count < common_girl_count:
        least_common_girl_name = name
        least_common_girl_count = count
print(least_common_girl_name)
print(least_common_girl_count)
# Out:
# zyn
# 5
# zyrihanna
# 5

# %%
#4 She wasn't long for this dataset

longest_boy_length = 0
for name in boys.keys():
    if len(name) > longest_boy_length:
        longest_boy_length = len(name)
print(longest_boy_length)

longest_girl_length = 0
for name in girls.keys():
    if len(name) > longest_girl_length:
        longest_girl_length = len(name)
print(longest_girl_length)

longest_length = max(longest_boy_length,longest_girl_length)
print(longest_length)
    
longest_boy_name_count = 0
for name in boys.keys():
    if len(name) == longest_length:
        longest_boy_name_count += 1
print(longest_boy_name_count)

longest_girl_name_count = 0
for name in girls.keys():
    if len(name) == longest_length:
        longest_girl_name_count += 1
print(longest_girl_name_count)
# Out:
# 15
# 14
# 15
# 2
# 0

# %%
#5 Initials to spreadsheets
#5.1
girl_initials = dict() # girl_initials = {}
for i in [chr(x) for x in range(ord('a'), ord('z')+1)]:
    girl_initials[i] = 0 
print(girl_initials.keys())
for name, value in girls.items():
    girl_initials[name[0]] += value
#5.2
boy_initials = dict()
for i in [chr(x) for x in range(ord('a'), ord('z')+1)]:
    boy_initials[i] = 0 
print(boy_initials.keys())
for name, value in boys.items():
    boy_initials[name[0]] += value
#5.3
with open("girl_initials.tsv", "w") as my_file:
    print("letter \t number of unique names", file = my_file)
    for letter in girl_initials.keys():
        print(f"{letter}\t{girl_initials[letter]}", file=my_file)
#5.4
with open("boy_initials.tsv", "w") as my_file:
    print("letter \t number of unique names", file = my_file)
    for letter in boy_initials.keys():
        print(f"{letter}\t{boy_initials[letter]}", file = my_file)
#5.5
https://docs.google.com/spreadsheets/d/1v_GGE2NKAsEIpnpiTUg5w3F2t6DlKK_ONFX9pV2QiDM/edit#gid=1034242952
http://localhost:8889/edit/Documents/commld570B/babynames-cdsw-master/boy_initials.tsv
# Out:
#   Cell In[24], line 27
#     https://docs.google.com/spreadsheets/d/1v_GGE2NKAsEIpnpiTUg5w3F2t6DlKK_ONFX9pV2QiDM/edit#gid=1034242952
#                                            ^
# SyntaxError: invalid decimal literal

# %%
#6 Concentration in names
#6.1
total_boys = sum(boys.values())
top_boys = sum(sorted(boys.values(), reverse=True)[:50])
pct_top_boys = top_boys / total_boys * 100
print(f"{pct_top_boys:.2f}% of boys have one of the 10 most popular names.")

total_girls = sum(girls.values())
top_girls = sum(sorted(girls.values(), reverse=True)[:int(len(girls)/10)])
print(f"{top_girls} girls have one of the top 10% most popular names.")

#6.2
top_boys_names = [name for name, count in sorted(boys.items(), key=lambda x: x[1], reverse=True)[:int(len(boys)/10)]]
boys_with_top_names = sum(count for name, count in boys.items() if name in top_boys_names)
print(f"{boys_with_top_names} boys have one of the top 10% most popular names.")
# Out:
# 25.88% of boys have one of the 10 most popular names.
# 1325903 girls have one of the top 10% most popular names.
# 1486939 boys have one of the top 10% most popular names.

# %%
#7 Something extra 
print("das" not in girls)
#"das" is in not a name in girls name data list
print("abby" not in girls)
#"abby" is a name in girls name data list
# Out:
# True
# False

# %%
#8 My question about the dataset is 
#how it determines the gender because some names boys 
#and girls are called by that name, so whether the keys are missed when extracted.

#I think the challenge that they will encounter, 
#is how to handle the same person called by different names, like having a nickname
#also, only record when a boy or girl is a baby's name. 
#If the baby changes his or her name, the name no longer exists,
#but the record cannot be changed.

#They hypothesized that the popularity of baby names would always be based on trends 
#in the data, regardless of other circumstances

# %%
###

girl_initials = {}

for name in girl.keys():
    first_letter = name[0]
    if first_letter in girl_initial.keys():
        girl_initials[first_letter] += 1
    else:
        girl_initials[first_letter] = 1
        
girl_initials
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 girl_initials = {}
# ----> 3 for name in girl.keys():
#       4     first_letter = name[0]
#       5     if first_letter in girl_initial.keys():
#
# NameError: name 'girl' is not defined

# %%
application interface
