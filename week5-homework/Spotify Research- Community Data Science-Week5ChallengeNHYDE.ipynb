# %% [markdown]
# Spotify API https://developer.spotify.com/documentation/web-api

# %% [markdown]
# Spotify API Documentation https://developer.spotify.com/documentation/web-api

# %% [markdown]
# Spotify End Points
#
# Artist Top Tracks: /artists/{id}/
# Get Playlist: /playlists/{playlists_is}
# Get Featured Playlist: /browswe/featured_playlists
# Get Track: /track/{id}

# %% [markdown]
# Python Module
# Spotipy https://spotipy.readthedocs.io/en/2.19.0/

# %%
import spotipy

# %%
# %env SPOTIPY_CLIENT_ID=HIDDEN
# %env SPOTIPY_CLIENT_SECRET=HIDDEN
# Out:
# env: SPOTIPY_CLIENT_ID=HIDDEN
# env: SPOTIPY_CLIENT_SECRET=HIDDEN

# %%
from spotipy.oauth2 import SpotifyClientCredentials

uri = 'spotify:artist:0oSGxfWSnnOXhD2fKuz2Gy'
spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())

results = spotify.artist_albums(uri, album_type='album')
albums = results['items']
while results['next']:
    results = spotify.next(results)
    albums.extend(results['items'])

for album in albums:
    print(album['name'])
# Out:
# Divine Symmetry
# Moonage Daydream – A Brett Morgen Film
# Toy (Toy:Box)
# Brilliant Adventure (1992 – 2001)
# At The Kit Kat Klub (Live New York 99)
# Something In The Air (Live Paris 99)
# Look At The Moon! (Live Phoenix Festival 97)
# I'm Only Dancing (The Soul Tour 74) [Live]
# No Trendy Réchauffé (Live Birmingham 95)
# The Width Of A Circle
# ChangesNowBowie
# Ouvrez Le Chien (Live Dallas 95)
# Liveandwell.com (2020 Remaster)
# Metrobolist (aka The Man Who Sold The World) [2020 Mix]
# Conversation Piece
# Space Oddity (2019 Mix)
# The 'Mercury' Demos (with John 'Hutch' Hutchinson)
# Dance
# Serious Moonlight (Live '83, 2018 Remaster)
# Glastonbury 2000 (Live)
# ライヴ・イン・モントリオール1983 (Live)
# Welcome To The Blackout (Live London '78)
# Stage (2017) [Live]
# Cracked Actor (Live, Los Angeles '74)
# Live In Berlin (1978)
# Blackstar
# The Next Day
# A Reality Tour (Live)
# VH1 Storytellers (Live)
# Glass Spider (Live Montreal '87, 2018 Remaster)
# Reality
# Heathen
# Heathen
# Heathen
# ...

# %%
results
# Out:
# {'href': 'https://api.spotify.com/v1/artists/0oSGxfWSnnOXhD2fKuz2Gy/albums?offset=60&limit=20&include_groups=album',
#  'items': [{'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0oSGxfWSnnOXhD2fKuz2Gy'},
#      'href': 'https://api.spotify.com/v1/artists/0oSGxfWSnnOXhD2fKuz2Gy',
#      'id': '0oSGxfWSnnOXhD2fKuz2Gy',
#      'name': 'David Bowie',
#      'type': 'artist',
#      'uri': 'spotify:artist:0oSGxfWSnnOXhD2fKuz2Gy'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
# ...

# %% [markdown]
# Rate Limits
#
# Yes Spotify has rate limits. - Spotify's API rate limit is calculated based on the number of calls that your app makes to Spotify in a rolling 30 second window. If your app exceeds the rate limit for your app then you'll begin to see 429 error responses from Spotify's Web API, and you may hear from users about unexpected behavior that they have noticed while using your app. The limit varies depending on whether your app is in development mode or extended quota mode.
# It has some exceptions, such as extended quota mode and backoff retry strategy.
