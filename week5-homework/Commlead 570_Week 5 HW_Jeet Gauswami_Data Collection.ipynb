# %%
import requests
import json

# %%
def get_wikipedia_pageviews(page_title):
    # /metrics/pageviews/per-article/{project}/{access}/{agent}/{article}/{granularity}/{start}/{end}
    url = ("https://wikimedia.org/api/rest_v1/metrics/pageviews/per-article/" + 
           f"en.wikipedia.org/all-access/user/{page_title}/monthly/20010101/20230424")

    headers = {
        'User-Agent': 'python data collection bot by gauswami@uw.edu'
    }

    response = requests.get(url, headers=headers)

    if not response.status_code == 200:
        print("ERROR, request not OK")
    
    data = response.json()
    return data

# %%
data = get_wikipedia_pageviews("Mahatma_Gandhi")

# %%
with open("Mahatma_Gandhi_wp_pageviews.json", 'w') as my_file:
    data_string = json.dumps(data)
    print(data_string, file=my_file)

# %%
data_string
# Out:
# '{"items": [{"project": "en.wikipedia", "article": "Mahatma_Gandhi", "granularity": "monthly", "timestamp": "2015070100", "access": "all-access", "agent": "user", "views": 500737}, {"project": "en.wikipedia", "article": "Mahatma_Gandhi", "granularity": "monthly", "timestamp": "2015080100", "access": "all-access", "agent": "user", "views": 663155}, {"project": "en.wikipedia", "article": "Mahatma_Gandhi", "granularity": "monthly", "timestamp": "2015090100", "access": "all-access", "agent": "user", "views": 644443}, {"project": "en.wikipedia", "article": "Mahatma_Gandhi", "granularity": "monthly", "timestamp": "2015100100", "access": "all-access", "agent": "user", "views": 894293}, {"project": "en.wikipedia", "article": "Mahatma_Gandhi", "granularity": "monthly", "timestamp": "2015110100", "access": "all-access", "agent": "user", "views": 560148}, {"project": "en.wikipedia", "article": "Mahatma_Gandhi", "granularity": "monthly", "timestamp": "2015120100", "access": "all-access", "agent"
# ...

# %%
url = ("https://wikimedia.org/api/rest_v1/metrics/pageviews/per-article/zh.wikipedia.org/all-access/user/Mahatma_Gandhi/monthly/20010101/20230424")

headers = {
    'User-Agent': 'python data collection bot by gauswami@uw.edu'
}

response = requests.get(url, headers=headers)

if not response.status_code == 200:
    print("ERROR, request not OK")

chinese_data = response.json()

# %%
with open("Mahatma_Gandhi_wp_chinese_pageviews.json", 'w') as my_file:
    data_string_chinese = json.dumps(chinese_data)
    print(data_string_chinese, file=my_file)

# %%
url = ("https://wikimedia.org/api/rest_v1/metrics/pageviews/per-article/es.wikipedia.org/all-access/user/Mahatma_Gandhi/monthly/20010101/20230424")

headers = {
    'User-Agent': 'python data collection bot by gauswami@uw.edu'
}

response = requests.get(url, headers=headers)

if not response.status_code == 200:
    print("ERROR, request not OK")

spanish_data = response.json()

# %%
with open("Mahatma_Gandhi_wp_spanish_pageviews.json", 'w') as my_file:
    data_string_spanish = json.dumps(spanish_data)
    print(data_string_spanish, file=my_file)

# %% [markdown]
# Collect page view data on the articles about Marvel Comics and DC Comics in English Wikipedia. (If you'd rather replace these examples with some other comparison of popular rivals, that's just as good!)

# %%
Marvel_data = get_wikipedia_pageviews("Marvel_Comics")

# %%
with open("Marvel_comic_wp_pageviews.json", 'w') as my_file:
    data_string_Marvel = json.dumps(Marvel_data)
    print(data_string_Marvel, file=my_file)

# %%
data_string_Marvel
# Out:
# '{"items": [{"project": "en.wikipedia", "article": "Marvel_Comics", "granularity": "monthly", "timestamp": "2015070100", "access": "all-access", "agent": "user", "views": 174542}, {"project": "en.wikipedia", "article": "Marvel_Comics", "granularity": "monthly", "timestamp": "2015080100", "access": "all-access", "agent": "user", "views": 170093}, {"project": "en.wikipedia", "article": "Marvel_Comics", "granularity": "monthly", "timestamp": "2015090100", "access": "all-access", "agent": "user", "views": 153288}, {"project": "en.wikipedia", "article": "Marvel_Comics", "granularity": "monthly", "timestamp": "2015100100", "access": "all-access", "agent": "user", "views": 116504}, {"project": "en.wikipedia", "article": "Marvel_Comics", "granularity": "monthly", "timestamp": "2015110100", "access": "all-access", "agent": "user", "views": 132870}, {"project": "en.wikipedia", "article": "Marvel_Comics", "granularity": "monthly", "timestamp": "2015120100", "access": "all-access", "agent": "use
# ...

# %%
DC_data = get_wikipedia_pageviews("DC_Comics")

# %%
with open("DC_Comic_wp_pageviews.json", "w") as my_file:
    data_string_DC = json.dumps(DC_data)
    print(data_string_DC, file=my_file)

# %%
data_string_DC
# Out:
# '{"items": [{"project": "en.wikipedia", "article": "DC_Comics", "granularity": "monthly", "timestamp": "2015070100", "access": "all-access", "agent": "user", "views": 173888}, {"project": "en.wikipedia", "article": "DC_Comics", "granularity": "monthly", "timestamp": "2015080100", "access": "all-access", "agent": "user", "views": 141866}, {"project": "en.wikipedia", "article": "DC_Comics", "granularity": "monthly", "timestamp": "2015090100", "access": "all-access", "agent": "user", "views": 134422}, {"project": "en.wikipedia", "article": "DC_Comics", "granularity": "monthly", "timestamp": "2015100100", "access": "all-access", "agent": "user", "views": 119671}, {"project": "en.wikipedia", "article": "DC_Comics", "granularity": "monthly", "timestamp": "2015110100", "access": "all-access", "agent": "user", "views": 119824}, {"project": "en.wikipedia", "article": "DC_Comics", "granularity": "monthly", "timestamp": "2015120100", "access": "all-access", "agent": "user", "views": 134890}, {"
# ...
