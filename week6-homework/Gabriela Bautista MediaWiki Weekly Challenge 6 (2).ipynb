# %% [markdown]
# == #1 MediaWiki API ==
#
# Identify a movie, television, video game, or other media property that has both (a) 5 or more related articles on Wikipedia '''and''' (b) 5 or more other articles on the same topic on a [https://fandom.com Fandom.com] website. Any large entertainment franchise will definitely work but feel free to get creative! For example, you might choose 5 Wikipedia articles about the anime Naruto and 5 articles (pages) from the naruto.fandom.com site. You may notice that fandom.com has a top layer with staff-produced video content, but once you dig down into a particular fandom's wiki, you'll start to see a more familiar wiki style page. For example, compare [https://spongebob.fandom.com/wiki/Help_Wanted the fandom.com page about the SpongeBob pilot episode 'Help Wanted'] and [https://en.wikipedia.org/wiki/Help_Wanted_(SpongeBob_SquarePants) the Wikipedia page about the same pilot episode].
#
# # First modify the code from first sets of notebooks I used in the [[../Week 6 lecture]] to download data (and metadata) about revisions to the 5 articles you chose from Wikipedia. Be ready to share:
# ## (i) what proportion of those edits were made by users without accounts ("anon"),
# ## (ii) what proportion of those edits were marked as "minor", and
# ## (iii) make and share a visualization of the total number of edits across those 5 articles over time (I didn't do this in class but I made the TSV file would allow this).
# # Now grab data for the 5 articles you chose from the Fandom.com wiki you identified and grab revision/edit data from there. ('''''Hint:''' Your wikipedia work will give you lots of clues here: for example, the fandom API endpoint for The Wire is https://thewire.fandom.com/api.php and the Fandom API, as I said in class, is the same as the Wikipedia API''). Produce answers to the same three questions (i, ii, and iii) above but using this dataset.
# # Finally, choose either your Wikipedia or Fandom datasets as the data source for a visualization that shows how each of those articles have grown in length (as measured in characters or "bytes") over time. ('''''Hint:''' you'll need to return "size" as one of the revision properties (<code>rvprop</code>) if you are not doing it already.'')

# %%
import requests
import json
# import time

def get_article_revision_json(title, wiki_name="wikipedia"):
    api_answers = []

    # create a base url for the api and then a normal url which is initially
    # just a copy of it
    # The following line is what the requests call is doing, basically.
    # f"http://en.wikipedia.org/w/api.php/?action=query&titles={title}&prop=revisions&rvprop=flags|timestamp|user|size|ids&rvlimit=500&format=json&continue="
    # e.g.: http://en.wikipedia.org/w/api.php/?action=query&titles=Soundgarden&prop=revisions&rvprop=flags|timestamp|user|size|ids&rvlimit=500&format=json
    wp_api_url=""
    if wiki_name=="wikipedia":
        wp_api_url = "http://en.wikipedia.org/w/api.php/"

    if wiki_name=='fandom':
        wp_api_url = "https://sims.fandom.com/api.php"


    parameters = {'action' : 'query',
                  'titles' : title,
                  'prop' : 'revisions',
                  'rvprop' : 'flags|timestamp|user|size|ids',
                  'rvlimit' : 500,
                  'format' : 'json',
                   }

    # we'll repeat this forever (i.e., we'll only stop when we find
    # the "break" command)
    while True:
        # this will wait for one second
        # time.sleep(1)
        
        # the first line open the urls but also handles unicode urls
        call = requests.get(wp_api_url, params=parameters)
        api_answer = call.json()
        
        # now we'll add this to whatever we are tracking
        api_answers.append(api_answer)
        
        # 'continue' tells us there's more revisions to add
        if 'continue' in api_answer.keys():
            # replace the 'continue' parameter with the contents of the
            # api_answer dictionary.
            parameters.update(api_answer['continue'])
        else:
            break
        
    return(api_answers)

# %%
dict_wikipedia_titles={'The_Sims_4_expansion_packs#City_Living':'',
                 'The_Sims_4_expansion_packs#Cats_&_Dogs':'', 
                 'The_Sims_4_expansion_packs#Seasons':'', 
                 'The_Sims_4_expansion_packs#Get_Famous':'', 
                 'The_Sims_4_expansion_packs#Island_Living':''}

dict_fandom_titles={'The_Sims_4:_City_Living':'',
                    #'The_Sims_4:_Cats_%26_Dogs':'',
                    'The_Sims_4:_Seasons':'',
                    'The_Sims_4:_Get_Famous':'',
                    'The_Sims_4:_Island_Living':''}

for key in dict_wikipedia_titles:
    response = get_article_revision_json(key,"wikipedia")
    dict_wikipedia_titles[key] = json.dumps(response)
    #print(response)
# for key in dict_fandom_titles:
#     response = get_article_revision_json(key)
#     dict_wikipedia_titles[key] = json.dumps(response)

# %%
def get_revision(pageJson):
    revisions=[]
    obj= json.loads(pageJson)
    currentObj = obj[0]
    pages = currentObj["query"]["pages"]
    # for every page, (there should always be only one) get its revisions:
    for page_id in pages.keys():
        #print(page_id) #They are the same The_Sims_4_expansion_packs that's why it has the same page_id
        query_revisions = pages[page_id]["revisions"]
        title = pages[page_id]['title']
        #print(title)
        for rev in query_revisions:
            if "userhidden" in rev.keys():
                continue
            # 1: add a title field for the article because we're going to mix them together
            rev["title"] = title

                # 2: let's "recode" anon so it's true or false instead of present/missing
            if "anon" in rev.keys():
                rev["anon"] = True
            else:
                rev["anon"] = False
            # 3: let's recode "minor" in the same way
            if "minor" in rev.keys():
                rev["minor"] = True
            else:
                rev["minor"] = False

            # we're going to change the timestamp to make it work a little better in excel/spreadsheets
            rev["timestamp"] = rev["timestamp"].replace("T", " ")
            rev["timestamp"] = rev["timestamp"].replace("Z", "")
            #print(rev)
                # finally, save the revisions we've seen to a varaible
            revisions.append(rev)

    return revisions

def countKey(revisions,key):
    total = 0
    if (revisions is not None):
        for rev in revisions:
            if (rev[key] == "True"):
                total= total+1
    return total

# %%
print('(i) what proportion of those edits were made by users without accounts ("anon")?')
for key in dict_wikipedia_titles:
    print(key)
    key_revisions=get_revision(dict_wikipedia_titles[key])
    print(key_revisions)
    #print(key_revisions)
    print(countKey(key_revisions,"anon"))
# Out:
# (i) what proportion of those edits were made by users without accounts ("anon")?
# The_Sims_4_expansion_packs#City_Living
# [{'revid': 1148145049, 'parentid': 1147767160, 'user': 'Mythdon', 'timestamp': '2023-04-04 10:25:15', 'size': 77647, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1147767160, 'parentid': 1147754627, 'user': 'DemonStalker', 'timestamp': '2023-04-02 01:39:37', 'size': 77651, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1147754627, 'parentid': 1145044037, 'user': '2600:4040:46C1:5300:883E:435E:E901:8CFA', 'anon': True, 'timestamp': '2023-04-01 23:58:32', 'size': 77615, 'title': 'The Sims 4 expansion packs', 'minor': False}, {'revid': 1145044037, 'parentid': 1145043978, 'user': 'FeFiFo', 'timestamp': '2023-03-17 00:04:24', 'size': 77557, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1145043978, 'parentid': 1145043849, 'user': 'FeFiFo', 'timestamp': '2023-03-17 00:04:00', 'size': 77558, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1145043849, 'parentid': 1142072327, 'user': 'FeFiFo', 'timestamp': '2023-03-17 00:03:15', 'size': 77560, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1142072327, 'parentid': 1142065725, 'user': 'Theknine2', 'timestamp': '2023-02-28 10:25:04', 'size': 77568, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1142065725, 'parentid': 1142065226, 'minor': True, 'user': 'Gabrielpedrosa88', 'timestamp': '2023-02-28 09:18:37', 'size': 77914, 'title': 'The Sims 4 expansion packs', 'anon': False}, {'revid': 1142065226, 'parentid': 1142064978, 'user': 'Gabrielpedrosa88', 'timestamp': '2023-02-28 09:13:40', 'size': 77839, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1142064978, 'parentid': 1142064935, 'minor': True, 'user': 'SunDawn', 'timestamp': '2023-02-28 09:11:34', 'size': 77568, 'title': 'The Sims 4 expansion packs', 'anon': False}, {'revid': 1142064935, 'parentid': 1141092143, 'user': 'Gabrielpedrosa88', 'timestamp': '2023-02-28 09:11:08', 'size': 77726, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1141092143, 'parentid': 1139213844, 'user': 'Theknine2', 'timestamp': '2023-02-23 08:48:44', 'size': 77568, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1139213844, 'parentid': 1137808678, 'user': 'Mobius Gerig', 'timestamp': '2023-02-13 23:46:07', 'size': 77272, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1137808678, 'parentid': 1137805760, 'minor': True, 'user': 'AnomieBOT', 'timestamp': '2023-02-06 15:37:44', 'size': 77201, 'title': 'The Sims 4 expansion packs', 'anon': False}, {'revid': 1137805760, 'parentid': 1137395376, 'user': 'Zerbu', 'timestamp': '2023-02-06 15:17:15', 'size': 77182, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1137395376, 'parentid': 1137393388, 'user': 'Theknine2', 'timestamp': '2023-02-04 11:44:31', 'size': 77165, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1137393388, 'parentid': 1137118039, 'user': 'Theknine2', 'timestamp': '2023-02-04 11:23:36', 'size': 76973, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1137118039, 'parentid': 1137091947, 'user': 'Secretlondon', 'timestamp': '2023-02-02 22:18:04', 'size': 76721, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1137091947, 'parentid': 1137088414, 'minor': True, 'user': 'K6ka', 'timestamp': '2023-02-02 19:28:13', 'size': 76336, 'title': 'The Sims 4 expansion packs', 'anon': False}, {'revid': 1137088414, 'parentid': 1137087651, 'user': 'Torskerognsvandhalløjsatilmigogdigsand', 'timestamp': '2023-02-02 19:03:49', 'size': 76340, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1137087651, 'parentid': 1137087590, 'minor': True, 'user': 'K6ka', 'timestamp': '2023-02-02 18:58:22', 'size': 76336, 'title': 'The Sims 4 expansio ...
# 0
# The_Sims_4_expansion_packs#Cats_&_Dogs
# [{'revid': 1148145049, 'parentid': 1147767160, 'user': 'Mythdon', 'timestamp': '2023-04-04 10:25:15', 'size': 77647, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1147767160, 'parentid': 1147754627, 'user': 'DemonStalker', 'timestamp': '2023-04-02 01:39:37', 'size': 77651, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1147754627, 'parentid': 1145044037, 'user': '2600:4040:46C1:5300:883E:435E:E901:8CFA', 'anon': True, 'timestamp': '2023-04-01 23:58:32', 'size': 77615, 'title': 'The Sims 4 expansion packs', 'minor': False}, {'revid': 1145044037, 'parentid': 1145043978, 'user': 'FeFiFo', 'timestamp': '2023-03-17 00:04:24', 'size': 77557, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1145043978, 'parentid': 1145043849, 'user': 'FeFiFo', 'timestamp': '2023-03-17 00:04:00', 'size': 77558, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1145043849, 'parentid': 1142072327, 'user': 'FeFiFo', 'timestamp': '2023-03-17 00:03:15', 'size': 77560, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1142072327, 'parentid': 1142065725, 'user': 'Theknine2', 'timestamp': '2023-02-28 10:25:04', 'size': 77568, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1142065725, 'parentid': 1142065226, 'minor': True, 'user': 'Gabrielpedrosa88', 'timestamp': '2023-02-28 09:18:37', 'size': 77914, 'title': 'The Sims 4 expansion packs', 'anon': False}, {'revid': 1142065226, 'parentid': 1142064978, 'user': 'Gabrielpedrosa88', 'timestamp': '2023-02-28 09:13:40', 'size': 77839, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1142064978, 'parentid': 1142064935, 'minor': True, 'user': 'SunDawn', 'timestamp': '2023-02-28 09:11:34', 'size': 77568, 'title': 'The Sims 4 expansion packs', 'anon': False}, {'revid': 1142064935, 'parentid': 1141092143, 'user': 'Gabrielpedrosa88', 'timestamp': '2023-02-28 09:11:08', 'size': 77726, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1141092143, 'parentid': 1139213844, 'user': 'Theknine2', 'timestamp': '2023-02-23 08:48:44', 'size': 77568, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1139213844, 'parentid': 1137808678, 'user': 'Mobius Gerig', 'timestamp': '2023-02-13 23:46:07', 'size': 77272, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1137808678, 'parentid': 1137805760, 'minor': True, 'user': 'AnomieBOT', 'timestamp': '2023-02-06 15:37:44', 'size': 77201, 'title': 'The Sims 4 expansion packs', 'anon': False}, {'revid': 1137805760, 'parentid': 1137395376, 'user': 'Zerbu', 'timestamp': '2023-02-06 15:17:15', 'size': 77182, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1137395376, 'parentid': 1137393388, 'user': 'Theknine2', 'timestamp': '2023-02-04 11:44:31', 'size': 77165, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1137393388, 'parentid': 1137118039, 'user': 'Theknine2', 'timestamp': '2023-02-04 11:23:36', 'size': 76973, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1137118039, 'parentid': 1137091947, 'user': 'Secretlondon', 'timestamp': '2023-02-02 22:18:04', 'size': 76721, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1137091947, 'parentid': 1137088414, 'minor': True, 'user': 'K6ka', 'timestamp': '2023-02-02 19:28:13', 'size': 76336, 'title': 'The Sims 4 expansion packs', 'anon': False}, {'revid': 1137088414, 'parentid': 1137087651, 'user': 'Torskerognsvandhalløjsatilmigogdigsand', 'timestamp': '2023-02-02 19:03:49', 'size': 76340, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1137087651, 'parentid': 1137087590, 'minor': True, 'user': 'K6ka', 'timestamp': '2023-02-02 18:58:22', 'size': 76336, 'title': 'The Sims 4 expansio ...
# 0
# The_Sims_4_expansion_packs#Seasons
# [{'revid': 1148145049, 'parentid': 1147767160, 'user': 'Mythdon', 'timestamp': '2023-04-04 10:25:15', 'size': 77647, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1147767160, 'parentid': 1147754627, 'user': 'DemonStalker', 'timestamp': '2023-04-02 01:39:37', 'size': 77651, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1147754627, 'parentid': 1145044037, 'user': '2600:4040:46C1:5300:883E:435E:E901:8CFA', 'anon': True, 'timestamp': '2023-04-01 23:58:32', 'size': 77615, 'title': 'The Sims 4 expansion packs', 'minor': False}, {'revid': 1145044037, 'parentid': 1145043978, 'user': 'FeFiFo', 'timestamp': '2023-03-17 00:04:24', 'size': 77557, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1145043978, 'parentid': 1145043849, 'user': 'FeFiFo', 'timestamp': '2023-03-17 00:04:00', 'size': 77558, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1145043849, 'parentid': 1142072327, 'user': 'FeFiFo', 'timestamp': '2023-03-17 00:03:15', 'size': 77560, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1142072327, 'parentid': 1142065725, 'user': 'Theknine2', 'timestamp': '2023-02-28 10:25:04', 'size': 77568, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1142065725, 'parentid': 1142065226, 'minor': True, 'user': 'Gabrielpedrosa88', 'timestamp': '2023-02-28 09:18:37', 'size': 77914, 'title': 'The Sims 4 expansion packs', 'anon': False}, {'revid': 1142065226, 'parentid': 1142064978, 'user': 'Gabrielpedrosa88', 'timestamp': '2023-02-28 09:13:40', 'size': 77839, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1142064978, 'parentid': 1142064935, 'minor': True, 'user': 'SunDawn', 'timestamp': '2023-02-28 09:11:34', 'size': 77568, 'title': 'The Sims 4 expansion packs', 'anon': False}, {'revid': 1142064935, 'parentid': 1141092143, 'user': 'Gabrielpedrosa88', 'timestamp': '2023-02-28 09:11:08', 'size': 77726, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1141092143, 'parentid': 1139213844, 'user': 'Theknine2', 'timestamp': '2023-02-23 08:48:44', 'size': 77568, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1139213844, 'parentid': 1137808678, 'user': 'Mobius Gerig', 'timestamp': '2023-02-13 23:46:07', 'size': 77272, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1137808678, 'parentid': 1137805760, 'minor': True, 'user': 'AnomieBOT', 'timestamp': '2023-02-06 15:37:44', 'size': 77201, 'title': 'The Sims 4 expansion packs', 'anon': False}, {'revid': 1137805760, 'parentid': 1137395376, 'user': 'Zerbu', 'timestamp': '2023-02-06 15:17:15', 'size': 77182, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1137395376, 'parentid': 1137393388, 'user': 'Theknine2', 'timestamp': '2023-02-04 11:44:31', 'size': 77165, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1137393388, 'parentid': 1137118039, 'user': 'Theknine2', 'timestamp': '2023-02-04 11:23:36', 'size': 76973, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1137118039, 'parentid': 1137091947, 'user': 'Secretlondon', 'timestamp': '2023-02-02 22:18:04', 'size': 76721, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1137091947, 'parentid': 1137088414, 'minor': True, 'user': 'K6ka', 'timestamp': '2023-02-02 19:28:13', 'size': 76336, 'title': 'The Sims 4 expansion packs', 'anon': False}, {'revid': 1137088414, 'parentid': 1137087651, 'user': 'Torskerognsvandhalløjsatilmigogdigsand', 'timestamp': '2023-02-02 19:03:49', 'size': 76340, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1137087651, 'parentid': 1137087590, 'minor': True, 'user': 'K6ka', 'timestamp': '2023-02-02 18:58:22', 'size': 76336, 'title': 'The Sims 4 expansio ...
# 0
# The_Sims_4_expansion_packs#Get_Famous
# [{'revid': 1148145049, 'parentid': 1147767160, 'user': 'Mythdon', 'timestamp': '2023-04-04 10:25:15', 'size': 77647, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1147767160, 'parentid': 1147754627, 'user': 'DemonStalker', 'timestamp': '2023-04-02 01:39:37', 'size': 77651, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1147754627, 'parentid': 1145044037, 'user': '2600:4040:46C1:5300:883E:435E:E901:8CFA', 'anon': True, 'timestamp': '2023-04-01 23:58:32', 'size': 77615, 'title': 'The Sims 4 expansion packs', 'minor': False}, {'revid': 1145044037, 'parentid': 1145043978, 'user': 'FeFiFo', 'timestamp': '2023-03-17 00:04:24', 'size': 77557, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1145043978, 'parentid': 1145043849, 'user': 'FeFiFo', 'timestamp': '2023-03-17 00:04:00', 'size': 77558, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1145043849, 'parentid': 1142072327, 'user': 'FeFiFo', 'timestamp': '2023-03-17 00:03:15', 'size': 77560, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1142072327, 'parentid': 1142065725, 'user': 'Theknine2', 'timestamp': '2023-02-28 10:25:04', 'size': 77568, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1142065725, 'parentid': 1142065226, 'minor': True, 'user': 'Gabrielpedrosa88', 'timestamp': '2023-02-28 09:18:37', 'size': 77914, 'title': 'The Sims 4 expansion packs', 'anon': False}, {'revid': 1142065226, 'parentid': 1142064978, 'user': 'Gabrielpedrosa88', 'timestamp': '2023-02-28 09:13:40', 'size': 77839, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1142064978, 'parentid': 1142064935, 'minor': True, 'user': 'SunDawn', 'timestamp': '2023-02-28 09:11:34', 'size': 77568, 'title': 'The Sims 4 expansion packs', 'anon': False}, {'revid': 1142064935, 'parentid': 1141092143, 'user': 'Gabrielpedrosa88', 'timestamp': '2023-02-28 09:11:08', 'size': 77726, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1141092143, 'parentid': 1139213844, 'user': 'Theknine2', 'timestamp': '2023-02-23 08:48:44', 'size': 77568, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1139213844, 'parentid': 1137808678, 'user': 'Mobius Gerig', 'timestamp': '2023-02-13 23:46:07', 'size': 77272, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1137808678, 'parentid': 1137805760, 'minor': True, 'user': 'AnomieBOT', 'timestamp': '2023-02-06 15:37:44', 'size': 77201, 'title': 'The Sims 4 expansion packs', 'anon': False}, {'revid': 1137805760, 'parentid': 1137395376, 'user': 'Zerbu', 'timestamp': '2023-02-06 15:17:15', 'size': 77182, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1137395376, 'parentid': 1137393388, 'user': 'Theknine2', 'timestamp': '2023-02-04 11:44:31', 'size': 77165, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1137393388, 'parentid': 1137118039, 'user': 'Theknine2', 'timestamp': '2023-02-04 11:23:36', 'size': 76973, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1137118039, 'parentid': 1137091947, 'user': 'Secretlondon', 'timestamp': '2023-02-02 22:18:04', 'size': 76721, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1137091947, 'parentid': 1137088414, 'minor': True, 'user': 'K6ka', 'timestamp': '2023-02-02 19:28:13', 'size': 76336, 'title': 'The Sims 4 expansion packs', 'anon': False}, {'revid': 1137088414, 'parentid': 1137087651, 'user': 'Torskerognsvandhalløjsatilmigogdigsand', 'timestamp': '2023-02-02 19:03:49', 'size': 76340, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1137087651, 'parentid': 1137087590, 'minor': True, 'user': 'K6ka', 'timestamp': '2023-02-02 18:58:22', 'size': 76336, 'title': 'The Sims 4 expansio ...
# 0
# The_Sims_4_expansion_packs#Island_Living
# [{'revid': 1148145049, 'parentid': 1147767160, 'user': 'Mythdon', 'timestamp': '2023-04-04 10:25:15', 'size': 77647, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1147767160, 'parentid': 1147754627, 'user': 'DemonStalker', 'timestamp': '2023-04-02 01:39:37', 'size': 77651, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1147754627, 'parentid': 1145044037, 'user': '2600:4040:46C1:5300:883E:435E:E901:8CFA', 'anon': True, 'timestamp': '2023-04-01 23:58:32', 'size': 77615, 'title': 'The Sims 4 expansion packs', 'minor': False}, {'revid': 1145044037, 'parentid': 1145043978, 'user': 'FeFiFo', 'timestamp': '2023-03-17 00:04:24', 'size': 77557, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1145043978, 'parentid': 1145043849, 'user': 'FeFiFo', 'timestamp': '2023-03-17 00:04:00', 'size': 77558, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1145043849, 'parentid': 1142072327, 'user': 'FeFiFo', 'timestamp': '2023-03-17 00:03:15', 'size': 77560, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1142072327, 'parentid': 1142065725, 'user': 'Theknine2', 'timestamp': '2023-02-28 10:25:04', 'size': 77568, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1142065725, 'parentid': 1142065226, 'minor': True, 'user': 'Gabrielpedrosa88', 'timestamp': '2023-02-28 09:18:37', 'size': 77914, 'title': 'The Sims 4 expansion packs', 'anon': False}, {'revid': 1142065226, 'parentid': 1142064978, 'user': 'Gabrielpedrosa88', 'timestamp': '2023-02-28 09:13:40', 'size': 77839, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1142064978, 'parentid': 1142064935, 'minor': True, 'user': 'SunDawn', 'timestamp': '2023-02-28 09:11:34', 'size': 77568, 'title': 'The Sims 4 expansion packs', 'anon': False}, {'revid': 1142064935, 'parentid': 1141092143, 'user': 'Gabrielpedrosa88', 'timestamp': '2023-02-28 09:11:08', 'size': 77726, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1141092143, 'parentid': 1139213844, 'user': 'Theknine2', 'timestamp': '2023-02-23 08:48:44', 'size': 77568, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1139213844, 'parentid': 1137808678, 'user': 'Mobius Gerig', 'timestamp': '2023-02-13 23:46:07', 'size': 77272, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1137808678, 'parentid': 1137805760, 'minor': True, 'user': 'AnomieBOT', 'timestamp': '2023-02-06 15:37:44', 'size': 77201, 'title': 'The Sims 4 expansion packs', 'anon': False}, {'revid': 1137805760, 'parentid': 1137395376, 'user': 'Zerbu', 'timestamp': '2023-02-06 15:17:15', 'size': 77182, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1137395376, 'parentid': 1137393388, 'user': 'Theknine2', 'timestamp': '2023-02-04 11:44:31', 'size': 77165, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1137393388, 'parentid': 1137118039, 'user': 'Theknine2', 'timestamp': '2023-02-04 11:23:36', 'size': 76973, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1137118039, 'parentid': 1137091947, 'user': 'Secretlondon', 'timestamp': '2023-02-02 22:18:04', 'size': 76721, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1137091947, 'parentid': 1137088414, 'minor': True, 'user': 'K6ka', 'timestamp': '2023-02-02 19:28:13', 'size': 76336, 'title': 'The Sims 4 expansion packs', 'anon': False}, {'revid': 1137088414, 'parentid': 1137087651, 'user': 'Torskerognsvandhalløjsatilmigogdigsand', 'timestamp': '2023-02-02 19:03:49', 'size': 76340, 'title': 'The Sims 4 expansion packs', 'anon': False, 'minor': False}, {'revid': 1137087651, 'parentid': 1137087590, 'minor': True, 'user': 'K6ka', 'timestamp': '2023-02-02 18:58:22', 'size': 76336, 'title': 'The Sims 4 expansio ...
# 0

# %%
print('(ii) what proportion of those edits were marked as "minor"?')
for key in dict_wikipedia_titles:
    print(key)
    key_revisions=get_revision(dict_wikipedia_titles[key])
    #print(key_revisions)
    #print(key_revisions)
    print(countKey(key_revisions,"minor"))
# Out:
# (ii) what proportion of those edits were marked as "minor"?
# The_Sims_4_expansion_packs#City_Living
# 0
# The_Sims_4_expansion_packs#Cats_&_Dogs
# 0
# The_Sims_4_expansion_packs#Seasons
# 0
# The_Sims_4_expansion_packs#Get_Famous
# 0
# The_Sims_4_expansion_packs#Island_Living
# 0

# %%
print('#(iii) make and share a visualization of the total number of edits across those 5 articles over time (I didnt do this in class but I made the TSV file would allow this).')
file_name = f"The_Sims_4_wikipedia_time_visualizations.tsv"
for key in dict_wikipedia_titles:
    print(key)
    with open(file_name, "w") as f:    
        print("title\ttimestamp", file=f)
        key_revisions=get_revision(dict_wikipedia_titles[key])
        #print(key_revisions)
        #print(key_revisions)
        for revision in key_revisions:
            timestamp = revision["timestamp"]
            print(key,"\t",timestamp, file=f)            
        
print(f"{file_name} created")
# Out:
# #(iii) make and share a visualization of the total number of edits across those 5 articles over time (I didnt do this in class but I made the TSV file would allow this).
# The_Sims_4_expansion_packs#City_Living
# The_Sims_4_expansion_packs#Cats_&_Dogs
# The_Sims_4_expansion_packs#Seasons
# The_Sims_4_expansion_packs#Get_Famous
# The_Sims_4_expansion_packs#Island_Living
# The_Sims_4_wikipedia_time_visualizations.tsv created

# %%
# dict_fandom_titles={'The_Sims_4:_City_Living':'',
#                     'The_Sims_4:_Cats_%26_Dogs':'',
#                     'The_Sims_4:_Seasons':'',
#                     'The_Sims_4:_Get_Famous':'',
#                     'The_Sims_4:_Island_Living':''}

for key in dict_fandom_titles:
    response = get_article_revision_json(key,"fandom")
    print(response)
    dict_fandom_titles[key] = json.dumps(response)
# Out:
# [{'batchcomplete': '', 'query': {'normalized': [{'from': 'The_Sims_4:_City_Living', 'to': 'The Sims 4: City Living'}], 'pages': {'163414': {'pageid': 163414, 'ns': 0, 'title': 'The Sims 4: City Living', 'revisions': [{'revid': 1024169, 'parentid': 1019848, 'user': 'Marica Di Campo', 'timestamp': '2023-04-12T08:49:41Z', 'size': 15559}, {'revid': 1019848, 'parentid': 1016140, 'minor': '', 'user': 'MasterTeska', 'timestamp': '2023-02-21T13:45:19Z', 'size': 15562}, {'revid': 1016140, 'parentid': 1016139, 'minor': '', 'user': 'K6ka', 'timestamp': '2022-12-29T17:55:09Z', 'size': 15527}, {'revid': 1016139, 'parentid': 968253, 'user': '80.229.18.148', 'anon': '', 'timestamp': '2022-12-29T17:52:11Z', 'size': 15527}, {'revid': 968253, 'parentid': 968251, 'user': 'AireDaleDogz', 'timestamp': '2022-07-21T15:43:54Z', 'size': 15527}, {'revid': 968251, 'parentid': 965178, 'user': '93.103.37.175', 'anon': '', 'timestamp': '2022-07-21T15:23:22Z', 'size': 15686}, {'revid': 965178, 'parentid': 952366, 'user': '203.62.28.67', 'anon': '', 'timestamp': '2022-06-10T01:38:50Z', 'size': 15527}, {'revid': 952366, 'parentid': 952365, 'user': 'Necromancer10', 'timestamp': '2021-09-10T06:55:05Z', 'size': 15516}, {'revid': 952365, 'parentid': 948554, 'user': '49.37.183.136', 'anon': '', 'timestamp': '2021-09-10T04:31:17Z', 'size': 15514}, {'revid': 948554, 'parentid': 948553, 'minor': '', 'user': 'AireDaleDogz', 'timestamp': '2021-07-12T09:23:17Z', 'size': 15516}, {'revid': 948553, 'parentid': 947183, 'user': 'AireDaleDogz', 'timestamp': '2021-07-12T09:22:49Z', 'size': 15517}, {'revid': 947183, 'parentid': 947182, 'user': 'Ryanfellowsfitts23', 'timestamp': '2021-06-20T04:26:18Z', 'size': 15679}, {'revid': 947182, 'parentid': 947181, 'user': 'Ryanfellowsfitts23', 'timestamp': '2021-06-20T04:25:43Z', 'size': 15649}, {'revid': 947181, 'parentid': 944188, 'user': 'Ryanfellowsfitts23', 'timestamp': '2021-06-20T04:23:42Z', 'size': 15449}, {'revid': 944188, 'parentid': 934561, 'minor': '', 'user': 'AireDaleDogz', 'timestamp': '2021-05-21T08:07:44Z', 'size': 15330}, {'revid': 934561, 'parentid': 934559, 'user': '120.148.165.34', 'anon': '', 'timestamp': '2020-11-30T02:21:33Z', 'size': 15289}, {'revid': 934559, 'parentid': 931913, 'user': '120.148.165.34', 'anon': '', 'timestamp': '2020-11-30T02:18:39Z', 'size': 15314}, {'revid': 931913, 'parentid': 931027, 'user': 'Ana Carolina Nascimento de Andrade', 'timestamp': '2020-11-10T16:14:01Z', 'size': 15295}, {'revid': 931027, 'parentid': 923392, 'user': 'Jeremia-Lecato', 'timestamp': '2020-10-30T18:56:28Z', 'size': 15295}, {'revid': 923392, 'parentid': 923391, 'user': 'ThePixel650', 'timestamp': '2020-07-12T21:53:07Z', 'size': 15301}, {'revid': 923391, 'parentid': 919518, 'user': 'Aespubic', 'timestamp': '2020-07-12T21:47:32Z', 'size': 412}, {'revid': 919518, 'parentid': 904697, 'user': 'Ryanfellowsfitts23', 'timestamp': '2020-06-06T01:23:16Z', 'size': 15301}, {'revid': 904697, 'parentid': 904696, 'minor': '', 'user': 'K6ka', 'timestamp': '2020-01-01T17:51:51Z', 'size': 15317}, {'revid': 904696, 'parentid': 897330, 'user': '177.236.67.190', 'anon': '', 'timestamp': '2020-01-01T17:43:18Z', 'size': 15329}, {'revid': 897330, 'parentid': 897323, 'user': 'K6ka', 'timestamp': '2019-10-07T10:23:35Z', 'size': 15317}, {'revid': 897323, 'parentid': 893839, 'user': '180.248.120.185', 'anon': '', 'timestamp': '2019-10-07T09:14:50Z', 'size': 15600}, {'revid': 893839, 'parentid': 893827, 'user': 'AireDaleDogz', 'timestamp': '2019-09-12T14:40:13Z', 'size': 15317}, {'revid': 893827, 'parentid': 892386, 'user': '188.161.44.127', 'anon': '', 'timestamp': '2019-09-12T13:48:05Z', 'size': 15329}, {'revid': 892386, 'parentid': 889953, 'minor': '', 'user': 'Simmietime', 'timestamp': '2019-09-04T16:38:34Z', 'size': 15317}, {'revid': 889953, 'parentid': 889951, 'user': 'SimDestroyer', 'timestamp': '2019-08-15T12:38:11Z', 'size': 15218}, {'revid': 889951, 'parentid': 889673, 'user': 'SimDestroyer', 'timestamp': '2019-08-15T12:37:57Z', 'size': 1 ...
# [{'batchcomplete': '', 'query': {'normalized': [{'from': 'The_Sims_4:_Seasons', 'to': 'The Sims 4: Seasons'}], 'pages': {'178196': {'pageid': 178196, 'ns': 0, 'title': 'The Sims 4: Seasons', 'revisions': [{'revid': 973627, 'parentid': 973626, 'user': 'TheSimsWiki', 'timestamp': '2022-10-28T09:48:20Z', 'size': 15625}, {'revid': 973626, 'parentid': 968503, 'user': 'TheSimsWiki', 'timestamp': '2022-10-28T09:47:18Z', 'size': 15604}, {'revid': 968503, 'parentid': 966587, 'user': 'MoneyBrozYT', 'timestamp': '2022-07-23T04:59:09Z', 'size': 15881}, {'revid': 966587, 'parentid': 966586, 'user': 'InstinctionGaming Minecraft Username InstinctionG', 'timestamp': '2022-06-29T23:31:47Z', 'size': 15880}, {'revid': 966586, 'parentid': 954399, 'user': 'InstinctionGaming Minecraft Username InstinctionG', 'timestamp': '2022-06-29T23:31:21Z', 'size': 15886}, {'revid': 954399, 'parentid': 954395, 'minor': '', 'user': 'K6ka', 'timestamp': '2021-10-24T00:19:05Z', 'size': 15879}, {'revid': 954395, 'parentid': 949955, 'user': '209.121.229.239', 'anon': '', 'timestamp': '2021-10-23T23:35:33Z', 'size': 15940}, {'revid': 949955, 'parentid': 949954, 'minor': '', 'user': 'K6ka', 'timestamp': '2021-07-30T22:13:33Z', 'size': 15879}, {'revid': 949954, 'parentid': 948547, 'user': 'Fawfawfwa', 'timestamp': '2021-07-30T21:46:36Z', 'size': 437}, {'revid': 948547, 'parentid': 947109, 'user': 'AireDaleDogz', 'timestamp': '2021-07-12T09:15:01Z', 'size': 15879}, {'revid': 947109, 'parentid': 944257, 'minor': '', 'user': 'Zenionith', 'timestamp': '2021-06-17T16:53:31Z', 'size': 15752}, {'revid': 944257, 'parentid': 944251, 'minor': '', 'user': 'LostInRiverview', 'timestamp': '2021-05-21T18:04:02Z', 'size': 15749}, {'revid': 944251, 'parentid': 944190, 'user': '173.23.71.147', 'anon': '', 'timestamp': '2021-05-21T18:01:30Z', 'size': 14941}, {'revid': 944190, 'parentid': 943919, 'minor': '', 'user': 'AireDaleDogz', 'timestamp': '2021-05-21T08:08:04Z', 'size': 15749}, {'revid': 943919, 'parentid': 943915, 'minor': '', 'user': 'K6ka', 'timestamp': '2021-05-18T18:38:47Z', 'size': 15668}, {'revid': 943915, 'parentid': 942092, 'user': '92.29.190.55', 'anon': '', 'timestamp': '2021-05-18T17:49:53Z', 'size': 15669}, {'revid': 942092, 'parentid': 942086, 'minor': '', 'user': 'Miss Toki', 'timestamp': '2021-04-07T21:18:15Z', 'size': 15646}, {'revid': 942086, 'parentid': 914923, 'user': 'ImunderageHAHAHAHAHA', 'timestamp': '2021-04-07T21:04:49Z', 'size': 645}, {'revid': 914923, 'parentid': 914920, 'minor': '', 'user': 'K6ka', 'timestamp': '2020-04-27T20:22:31Z', 'size': 15646}, {'revid': 914920, 'parentid': 911277, 'user': '73.180.245.115', 'anon': '', 'timestamp': '2020-04-27T19:57:14Z', 'size': 15645}, {'revid': 911277, 'parentid': 911276, 'minor': '', 'user': 'SimDestroyer', 'timestamp': '2020-03-25T08:24:42Z', 'size': 15646}, {'revid': 911276, 'parentid': 911275, 'user': '105.226.216.154', 'anon': '', 'timestamp': '2020-03-25T08:11:42Z', 'size': 15655}, {'revid': 911275, 'parentid': 897326, 'user': '105.226.216.154', 'anon': '', 'timestamp': '2020-03-25T08:00:32Z', 'size': 15655}, {'revid': 897326, 'parentid': 897319, 'user': 'K6ka', 'timestamp': '2019-10-07T10:22:51Z', 'size': 15646}, {'revid': 897319, 'parentid': 895969, 'user': '180.248.120.185', 'anon': '', 'timestamp': '2019-10-07T08:56:55Z', 'size': 15772}, {'revid': 895969, 'parentid': 889967, 'user': 'Carmen182', 'timestamp': '2019-09-25T02:19:56Z', 'size': 15646}, {'revid': 889967, 'parentid': 889692, 'user': 'SimDestroyer', 'timestamp': '2019-08-15T12:41:16Z', 'size': 15634}, {'revid': 889692, 'parentid': 887120, 'minor': '', 'user': 'Mechemik', 'timestamp': '2019-08-14T21:22:06Z', 'size': 15619}, {'revid': 887120, 'parentid': 885695, 'user': 'AireDaleDogz', 'timestamp': '2019-07-26T13:21:44Z', 'size': 15634}, {'revid': 885695, 'parentid': 885685, 'user': 'SimDestroyer', 'timestamp': '2019-07-17T10:50:31Z', 'size': 15615}, {'revid': 885685, 'parentid': 885661, 'user': 'AireDaleDogz', 'timestamp': '2019-07-17T10:48:4 ...
# [{'batchcomplete': '', 'query': {'normalized': [{'from': 'The_Sims_4:_Get_Famous', 'to': 'The Sims 4: Get Famous'}], 'pages': {'181638': {'pageid': 181638, 'ns': 0, 'title': 'The Sims 4: Get Famous', 'revisions': [{'revid': 1022624, 'parentid': 1019193, 'user': 'Marica Di Campo', 'timestamp': '2023-03-25T17:45:03Z', 'size': 12350}, {'revid': 1019193, 'parentid': 962063, 'user': 'Marica Di Campo', 'timestamp': '2023-02-11T15:38:50Z', 'size': 12351}, {'revid': 962063, 'parentid': 962062, 'minor': '', 'user': 'C.Syde65', 'timestamp': '2022-03-28T01:18:24Z', 'size': 12358}, {'revid': 962062, 'parentid': 953097, 'user': '67.181.27.200', 'anon': '', 'timestamp': '2022-03-28T00:55:17Z', 'size': 12249}, {'revid': 953097, 'parentid': 944191, 'user': 'Queenk1w3', 'timestamp': '2021-09-24T23:22:30Z', 'size': 12358}, {'revid': 944191, 'parentid': 941065, 'minor': '', 'user': 'AireDaleDogz', 'timestamp': '2021-05-21T08:08:14Z', 'size': 12358}, {'revid': 941065, 'parentid': 941063, 'user': 'Necromancer10', 'timestamp': '2021-03-20T22:09:55Z', 'size': 12284}, {'revid': 941063, 'parentid': 939261, 'user': '73.19.14.93', 'anon': '', 'timestamp': '2021-03-20T21:57:08Z', 'size': 12295}, {'revid': 939261, 'parentid': 937946, 'user': 'SimCity', 'timestamp': '2021-02-14T08:28:26Z', 'size': 12287}, {'revid': 937946, 'parentid': 937944, 'minor': '', 'user': 'K6ka', 'timestamp': '2021-01-27T02:54:05Z', 'size': 12262}, {'revid': 937944, 'parentid': 936770, 'user': '173.215.20.129', 'anon': '', 'timestamp': '2021-01-27T02:44:21Z', 'size': 12279}, {'revid': 936770, 'parentid': 936759, 'user': 'AireDaleDogz', 'timestamp': '2021-01-11T11:59:02Z', 'size': 12262}, {'revid': 936759, 'parentid': 931911, 'user': 'HarmonyBunny', 'timestamp': '2021-01-11T08:47:04Z', 'size': 12236}, {'revid': 931911, 'parentid': 921062, 'user': 'Ana Carolina Nascimento de Andrade', 'timestamp': '2020-11-10T16:12:28Z', 'size': 12262}, {'revid': 921062, 'parentid': 921061, 'minor': '', 'user': 'K6ka', 'timestamp': '2020-06-20T19:31:49Z', 'size': 12249}, {'revid': 921061, 'parentid': 916795, 'user': '200.109.59.65', 'anon': '', 'timestamp': '2020-06-20T19:10:00Z', 'size': 12347}, {'revid': 916795, 'parentid': 916781, 'minor': '', 'user': 'K6ka', 'timestamp': '2020-05-16T11:33:02Z', 'size': 12249}, {'revid': 916781, 'parentid': 915009, 'user': '37.239.106.33', 'anon': '', 'timestamp': '2020-05-16T06:49:06Z', 'size': 12256}, {'revid': 915009, 'parentid': 915008, 'minor': '', 'user': 'K6ka', 'timestamp': '2020-04-28T15:43:27Z', 'size': 12249}, {'revid': 915008, 'parentid': 912137, 'user': '212.112.150.204', 'anon': '', 'timestamp': '2020-04-28T15:36:48Z', 'size': 12272}, {'revid': 912137, 'parentid': 912136, 'user': '99.203.20.214', 'anon': '', 'timestamp': '2020-04-09T19:19:04Z', 'size': 12249}, {'revid': 912136, 'parentid': 899736, 'user': '99.203.20.214', 'anon': '', 'timestamp': '2020-04-09T19:17:08Z', 'size': 12253}, {'revid': 899736, 'parentid': 897325, 'user': 'AireDaleDogz', 'timestamp': '2019-11-09T18:52:38Z', 'size': 12250}, {'revid': 897325, 'parentid': 897318, 'user': 'K6ka', 'timestamp': '2019-10-07T10:22:41Z', 'size': 12298}, {'revid': 897318, 'parentid': 889968, 'user': '180.248.120.185', 'anon': '', 'timestamp': '2019-10-07T08:53:55Z', 'size': 12426}, {'revid': 889968, 'parentid': 889691, 'user': 'SimDestroyer', 'timestamp': '2019-08-15T12:41:25Z', 'size': 12298}, {'revid': 889691, 'parentid': 887887, 'minor': '', 'user': 'Mechemik', 'timestamp': '2019-08-14T21:21:51Z', 'size': 12283}, {'revid': 887887, 'parentid': 885698, 'minor': '', 'user': 'C.Syde65', 'timestamp': '2019-08-01T03:16:02Z', 'size': 12298}, {'revid': 885698, 'parentid': 880969, 'user': 'SimDestroyer', 'timestamp': '2019-07-17T10:52:09Z', 'size': 12323}, {'revid': 880969, 'parentid': 878747, 'user': 'SimDestroyer', 'timestamp': '2019-06-17T13:25:19Z', 'size': 12369}, {'revid': 878747, 'parentid': 878566, 'user': 'Simmietime', 'timestamp': '2019-06-08T21:52:07Z', 'size': 12504}, {'revid': 878566, 'parentid ...
# [{'batchcomplete': '', 'query': {'normalized': [{'from': 'The_Sims_4:_Island_Living', 'to': 'The Sims 4: Island Living'}], 'pages': {'188952': {'pageid': 188952, 'ns': 0, 'title': 'The Sims 4: Island Living', 'revisions': [{'revid': 1024645, 'parentid': 1024437, 'user': 'Marica Di Campo', 'timestamp': '2023-04-17T08:08:49Z', 'size': 13164}, {'revid': 1024437, 'parentid': 1024436, 'user': 'Marica Di Campo', 'timestamp': '2023-04-13T20:57:17Z', 'size': 13212}, {'revid': 1024436, 'parentid': 1015688, 'user': 'Marica Di Campo', 'timestamp': '2023-04-13T20:55:28Z', 'size': 13211}, {'revid': 1015688, 'parentid': 1015687, 'minor': '', 'user': 'K6ka', 'timestamp': '2022-12-18T17:25:06Z', 'size': 13232}, {'revid': 1015687, 'parentid': 973631, 'user': '73.139.62.85', 'anon': '', 'timestamp': '2022-12-18T15:57:32Z', 'size': 13241}, {'revid': 973631, 'parentid': 973625, 'minor': '', 'user': 'TheSimsWiki', 'timestamp': '2022-10-28T10:14:25Z', 'size': 13232}, {'revid': 973625, 'parentid': 960845, 'user': 'TheSimsWiki', 'timestamp': '2022-10-28T09:32:15Z', 'size': 13233}, {'revid': 960845, 'parentid': 958869, 'minor': '', 'user': 'AireDaleDogz', 'timestamp': '2022-02-22T17:51:05Z', 'size': 14628}, {'revid': 958869, 'parentid': 957605, 'user': '174.63.58.107', 'anon': '', 'timestamp': '2022-01-16T06:15:42Z', 'size': 14594}, {'revid': 957605, 'parentid': 957603, 'user': 'Ryanfellowsfitts23', 'timestamp': '2021-12-29T09:24:43Z', 'size': 14562}, {'revid': 957603, 'parentid': 954852, 'user': 'Ryanfellowsfitts23', 'timestamp': '2021-12-29T09:20:50Z', 'size': 14362}, {'revid': 954852, 'parentid': 954317, 'user': 'Ryanfellowsfitts23', 'timestamp': '2021-11-06T05:24:37Z', 'size': 14186}, {'revid': 954317, 'parentid': 945175, 'user': 'Ryanfellowsfitts23', 'timestamp': '2021-10-21T02:36:42Z', 'size': 14011}, {'revid': 945175, 'parentid': 944192, 'minor': '', 'user': 'Redmonrylee', 'timestamp': '2021-06-02T19:58:48Z', 'size': 14060}, {'revid': 944192, 'parentid': 943313, 'minor': '', 'user': 'AireDaleDogz', 'timestamp': '2021-05-21T08:08:23Z', 'size': 14244}, {'revid': 943313, 'parentid': 941448, 'user': 'Admiralwaffle4', 'timestamp': '2021-05-02T20:53:39Z', 'size': 14170}, {'revid': 941448, 'parentid': 941399, 'minor': '', 'user': 'K6ka', 'timestamp': '2021-03-26T02:01:54Z', 'size': 14008}, {'revid': 941399, 'parentid': 941398, 'minor': '', 'user': 'Ryleegail1234', 'timestamp': '2021-03-25T18:26:01Z', 'size': 14057}, {'revid': 941398, 'parentid': 941397, 'minor': '', 'user': 'Ryleegail1234', 'timestamp': '2021-03-25T18:25:37Z', 'size': 14103}, {'revid': 941397, 'parentid': 941396, 'minor': '', 'user': 'Ryleegail1234', 'timestamp': '2021-03-25T18:25:14Z', 'size': 14112}, {'revid': 941396, 'parentid': 941395, 'minor': '', 'user': 'Ryleegail1234', 'timestamp': '2021-03-25T18:24:56Z', 'size': 14112}, {'revid': 941395, 'parentid': 941394, 'minor': '', 'user': 'Ryleegail1234', 'timestamp': '2021-03-25T18:24:35Z', 'size': 14110}, {'revid': 941394, 'parentid': 940283, 'minor': '', 'user': 'Ryleegail1234', 'timestamp': '2021-03-25T18:22:22Z', 'size': 14056}, {'revid': 940283, 'parentid': 940205, 'minor': '', 'user': 'Simmietime', 'timestamp': '2021-03-02T01:51:32Z', 'size': 14008}, {'revid': 940205, 'parentid': 936694, 'minor': '', 'user': 'A random person363', 'timestamp': '2021-02-28T18:29:58Z', 'size': 14007}, {'revid': 936694, 'parentid': 936665, 'user': 'AireDaleDogz', 'timestamp': '2021-01-10T09:54:01Z', 'size': 14008}, {'revid': 936665, 'parentid': 935825, 'minor': '', 'user': 'Ryleegail1234', 'timestamp': '2021-01-09T20:14:23Z', 'size': 14058}, {'revid': 935825, 'parentid': 935065, 'user': 'Ryanfellowsfitts23', 'timestamp': '2020-12-26T06:11:33Z', 'size': 14008}, {'revid': 935065, 'parentid': 934718, 'user': 'Ryanfellowsfitts23', 'timestamp': '2020-12-11T02:01:20Z', 'size': 13810}, {'revid': 934718, 'parentid': 934715, 'minor': '', 'user': 'K6ka', 'timestamp': '2020-12-02T13:57:08Z', 'size': 13723}, {'revid': 934715, 'parentid': 924504, 'user': '208.104 ...

# %%
print('(i) what proportion of those edits were made by users without accounts ("anon")?')
for key in dict_fandom_titles:
    #print(dict_fandom_titles[key])
    key_revisions=get_revision(dict_fandom_titles[key])
    print(key)
    print(countKey(key_revisions,"anon"))
# Out:
# (i) what proportion of those edits were made by users without accounts ("anon")?
# The_Sims_4:_City_Living
# 0
# The_Sims_4:_Seasons
# 0
# The_Sims_4:_Get_Famous
# 0
# The_Sims_4:_Island_Living
# 0

# %%
print('(ii) what proportion of those edits were marked as "minor"?')
for key in dict_fandom_titles:
    print(key)
    key_revisions=get_revision(dict_fandom_titles[key])
    #print(key_revisions)
    #print(key_revisions)
    print(countKey(key_revisions,"minor"))
# Out:
# (ii) what proportion of those edits were marked as "minor"?
# The_Sims_4:_City_Living
# 0
# The_Sims_4:_Seasons
# 0
# The_Sims_4:_Get_Famous
# 0
# The_Sims_4:_Island_Living
# 0

# %%
print('#(iii) make and share a visualization of the total number of edits across those 5 articles over time (I didnt do this in class but I made the TSV file would allow this).')
file_name = f"The_Sims_4_fandom_time_visualizations.tsv"
for key in dict_fandom_titles:
    print(key)
    with open(file_name, "w") as f:    
        print("title\ttimestamp", file=f)
        key_revisions=get_revision(dict_fandom_titles[key])
        #print(key_revisions)
        #print(key_revisions)
        for revision in key_revisions:
            timestamp = revision["timestamp"]
            print(key,"\t",timestamp, file=f)            
        
print(f"{file_name} created")
# Out:
# #(iii) make and share a visualization of the total number of edits across those 5 articles over time (I didnt do this in class but I made the TSV file would allow this).
# The_Sims_4:_City_Living
# The_Sims_4:_Seasons
# The_Sims_4:_Get_Famous
# The_Sims_4:_Island_Living
# The_Sims_4_fandom_time_visualizations.tsv created

# %%
#Finally, choose either your Wikipedia or Fandom datasets as the data source for a visualization that shows how each of those articles have grown in length (as measured in characters or "bytes") over time. (Hint: you'll need to return "size" as one of the revision properties (rvprop) if you are not doing it already.)
file_name = f"The_Sims_4_fandom_size_visualizations.tsv"
for key in dict_fandom_titles:
    print(key)
    
    with open(file_name, "w") as f:    
        print("title\ttimestamp\tsize", file=f)
        key_revisions=get_revision(dict_fandom_titles[key])
        #print(key_revisions)
        #print(key_revisions)        
        for revision in key_revisions:
            timestamp = revision["timestamp"]
            size = revision["size"]
            print(key,"\t", timestamp,"\t",size, file=f)
        

print(f"{file_name} created")
# Out:
# The_Sims_4:_City_Living
# The_Sims_4:_Seasons
# The_Sims_4:_Get_Famous
# The_Sims_4:_Island_Living
# The_Sims_4_fandom_size_visualizations.tsv created
