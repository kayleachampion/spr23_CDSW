# %% [markdown]
# <b>Media Wiki API </b>

# %% [markdown]
# Identify a movie, television, video game, or other media property that has both (a) 5 or more related articles on Wikipedia and (b) 5 or more other articles on the same topic on a Fandom.com website. Any large entertainment franchise will definitely work but feel free to get creative! For example, you might choose 5 Wikipedia articles about the anime Naruto and 5 articles (pages) from the naruto.fandom.com site. You may notice that fandom.com has a top layer with staff-produced video content, but once you dig down into a particular fandom's wiki, you'll start to see a more familiar wiki style page. For example, compare the fandom.com page about the SpongeBob pilot episode 'Help Wanted' and the Wikipedia page about the same pilot episode.

# %% [markdown]
# 1. First modify the code from first sets of notebooks I used in the Community Data Science Course (Spring 2023)/Week 6 lecture to download data (and metadata) about revisions to the 5 articles you chose from Wikipedia. Be ready to share:<br>
# (i) what proportion of those edits were made by users without accounts ("anon"),<br>
# (ii) what proportion of those edits were marked as "minor", and<br>
# (iii) make and share a visualization of the total number of edits across those 5 articles over time (I didn't do this in class but I made the TSV file would allow this).

# %%
#(i) what proportion of those edits were made by users without accounts ("anon")
#(ii) what proportion of those edits were marked as "minor"

import requests
import json

# %%
def get_article_revision_json(title):
    api_answers = []
    wp_api_url = "http://en.wikipedia.org/w/api.php/"
    parameters = {'action' : 'query',
                  'titles' : title,
                  'prop' : 'revisions',
                  'rvprop' : 'flags|timestamp|user|size|ids',
                  'rvlimit' : 500,
                  'format' : 'json',
                   }
    while True:
        call = requests.get(wp_api_url, params=parameters)
        api_answer = call.json()
        api_answers.append(api_answer)
        if 'continue' in api_answer.keys():
            parameters.update(api_answer['continue'])
        else:
            break
        
    return(api_answers)

# %%
dict1 = {"website": "en.wikipedia.org", "page_title": "Finn_the_Human"}
dict2 = {"website": "en.wikipedia.org", "page_title": "Fionna_and_Cake"}
dict3 = {"website": "en.wikipedia.org", "page_title": "Jake_the_Dog"}
dict4 = {"website": "en.wikipedia.org", "page_title": "Marceline_the_Vampire_Queen"}
dict5 = {"website": "en.wikipedia.org", "page_title": "Princess_Bubblegum"}

dict_list = [dict1, dict2, dict3, dict4, dict5]

with open("AdventureTimeCharacters.jsonl", "w") as adventure_time_characters:
    json.dump(dict1, adventure_time_characters)
    adventure_time_characters.write('\n')
    json.dump(dict2, adventure_time_characters)
    adventure_time_characters.write('\n')
    json.dump(dict3, adventure_time_characters)
    adventure_time_characters.write('\n')
    json.dump(dict4, adventure_time_characters)
    adventure_time_characters.write('\n')
    json.dump(dict5, adventure_time_characters)

# %%
with open('AdventureTimeCharacters.jsonl', 'r') as input_file,\
    open("Adventure_Time_revisions.jsonl", 'w') as output_file:
    
    for line in input_file.readlines():
        line_dict = json.loads(line)
        page_title = line_dict["page_title"]
        
        print(f"now working on: {page_title}")
        api_answers = get_article_revision_json(page_title)
        for api_answer in api_answers:
            print(json.dumps(api_answer), file=output_file)
# Out:
# now working on: Finn_the_Human
# now working on: Fionna_and_Cake
# now working on: Jake_the_Dog
# now working on: Marceline_the_Vampire_Queen
# now working on: Princess_Bubblegum

# %%
revisions = []
minor_revisions_count = 0

with open("Adventure_Time_revisions.jsonl", 'r') as input_file:
    for line in input_file.readlines():
        api_answer = json.loads(line)
        
        pages = api_answer["query"]["pages"]

        for page_id in pages.keys():
            query_revisions = pages[page_id]["revisions"]
            title = pages[page_id]['title']

            for rev in query_revisions:
                if "userhidden" in rev.keys():
                    continue
                
                rev["title"] = title

                if "anon" in rev.keys():
                    rev["anon"] = True
                else:
                    rev["anon"] = False

                if "minor" in rev.keys():
                    rev["minor"] = True
                    minor_revisions_count += 1  # Increment minor revision count
                else:
                    rev["minor"] = False

                rev["timestamp"] = rev["timestamp"].replace("T", " ")
                rev["timestamp"] = rev["timestamp"].replace("Z", "")

                revisions.append(rev)
num_edits = len(revisions)
num_anon = 0

for rev in revisions:
    if rev["anon"]:
        num_anon = num_anon + 1

prop_anon = num_anon / num_edits
prop_minor = minor_revisions_count / num_edits

print(f"proportion anon: {prop_anon}")
print(f"proportion minor: {prop_minor}")
# Out:
# proportion anon: 0.38433153562304856
# proportion minor: 0.2015327845586148

# %%
#(iii) make and share a visualization of the total number of edits across those 5 articles over time 
#(I didn't do this in class but I made the TSV file would allow this).
edits_by_day = {}
for rev in revisions:
    day_string = rev['timestamp'][0:10]

    if day_string in edits_by_day.keys():
        edits_by_day[day_string] = edits_by_day[day_string] + 1
    else:
        edits_by_day[day_string] = 1

# %%
edits_by_day = {}

for rev in revisions:
    day_string = rev['timestamp'][0:10]
    title = rev['title']
    key = (day_string, title)

    if key in edits_by_day.keys():
        edits_by_day[key] += 1
    else:
        edits_by_day[key] = 1

# %%
edits_by_day
# Out:
# {('2023-05-04', 'Finn the Human'): 1,
#  ('2023-05-03', 'Finn the Human'): 3,
#  ('2023-04-28', 'Finn the Human'): 12,
#  ('2023-04-27', 'Finn the Human'): 10,
#  ('2023-04-24', 'Finn the Human'): 6,
#  ('2023-04-16', 'Finn the Human'): 1,
#  ('2023-04-14', 'Finn the Human'): 2,
#  ('2023-03-28', 'Finn the Human'): 1,
#  ('2023-02-27', 'Finn the Human'): 1,
#  ('2023-02-21', 'Finn the Human'): 1,
#  ('2023-01-24', 'Finn the Human'): 1,
#  ('2022-12-16', 'Finn the Human'): 5,
#  ('2022-12-03', 'Finn the Human'): 1,
#  ('2022-11-28', 'Finn the Human'): 3,
#  ('2022-11-07', 'Finn the Human'): 1,
#  ('2022-09-25', 'Finn the Human'): 1,
#  ('2022-09-13', 'Finn the Human'): 5,
#  ('2022-09-08', 'Finn the Human'): 2,
#  ('2022-09-04', 'Finn the Human'): 1,
#  ('2022-09-01', 'Finn the Human'): 1,
#  ('2022-08-29', 'Finn the Human'): 1,
#  ('2022-08-19', 'Finn the Human'): 1,
#  ('2022-08-06', 'Finn the Human'): 1,
#  ('2022-08-03', 'Finn the Human'): 1,
#  ('2022-07-28', 'Finn the Human'): 1,
#  ('2022-07-25', 'Finn the Human'): 1,
#  ('2022-06-26', 'Finn the Human'): 3,
#  ('2022-05-05', 'Finn the Human'): 1,
#  ('2022-04-28', 'Finn the Human'): 1,
#  ('2022-04-16', 'Finn the Human'): 2,
#  ('2022-03-28', 'Finn the Human'): 1,
#  ('2022-03-27', 'Finn the Human'): 7,
#  ('2022-03-10', 'Finn the Human'): 8,
#  ('2022-03-01', 'Finn the Human'): 1,
#  ('2022-02-15', 'Finn the Human'): 1,
#  ('2022-02-14', 'Finn the Human'): 8,
#  ('2022-02-13', 'Finn the Human'): 5,
#  ('2022-02-12', 'Finn the Human'): 1,
#  ('2022-02-10', 'Finn the Human'): 1,
#  ('2022-02-09', 'Finn the Human'): 3,
#  ('2022-02-08', 'Finn the Human'): 4,
#  ('2022-02-07', 'Finn the Human'): 5,
#  ('2022-02-06', 'Finn the Human'): 1,
#  ('2022-02-04', 'Finn the Human'): 2,
#  ('2022-02-03', 'Finn the Human'): 1,
#  ('2022-02-02', 'Finn the Human'): 5,
#  ('2022-02-01', 'Finn the Human'): 2,
#  ('2022-01-30', 'Finn the Human'): 1,
#  ('2022-01-29', 'Finn the Human'): 1,
#  ('2022-01-21', 'Finn the Human'): 5,
#  ('2022-01-19', 'Finn the Human'): 2,
#  ('2022-01-16', 'Finn the Human'): 5,
#  ('2022-01-15', 'Finn the Human'): 2,
#  ('2022-01-11', 'Finn the Human'): 2,
#  ('2022-01-10', 'Finn the Human'): 7,
#  ('2022-01-05', 'Finn the Human'): 5,
#  ('2022-01-01', 'Finn the Human'): 1,
#  ('2021-12-31', 'Finn the Human'): 1,
#  ('2021-12-29', 'Finn the Human'): 1,
#  ('2021-12-18', 'Finn the Human'): 2,
#  ('2021-12-17', 'Finn the Human'): 9,
#  ('2021-12-16', 'Finn the Human'): 4,
#  ('2021-11-22', 'Finn the Human'): 2,
#  ('2021-11-18', 'Finn the Human'): 1,
#  ('2021-11-15', 'Finn the Human'): 1,
#  ('2021-11-14', 'Finn the Human'): 1,
#  ('2021-11-04', 'Finn the Human'): 3,
#  ('2021-11-02', 'Finn the Human'): 1,
#  ('2021-10-27', 'Finn the Human'): 1,
#  ('2021-10-11', 'Finn the Human'): 1,
#  ('2021-10-10', 'Finn the Human'): 1,
#  ('2021-10-03', 'Finn the Human'): 1,
#  ('2021-09-26', 'Finn the Human'): 1,
#  ('2021-09-22', 'Finn the Human'): 3,
#  ('2021-09-16', 'Finn the Human'): 1,
#  ('2021-09-15', 'Finn the Human'): 1,
#  ('2021-09-13', 'Finn the Human'): 1,
#  ('2021-09-12', 'Finn the Human'): 4,
#  ('2021-09-11', 'Finn the Human'): 13,
#  ('2021-09-10', 'Finn the Human'): 3,
#  ('2021-09-05', 'Finn the Human'): 1,
#  ('2021-08-29', 'Finn the Human'): 2,
#  ('2021-07-25', 'Finn the Human'): 1,
#  ('2021-07-13', 'Finn the Human'): 3,
#  ('2021-06-01', 'Finn the Human'): 3,
#  ('2021-05-29', 'Finn the Human'): 2,
#  ('2021-05-22', 'Finn the Human'): 6,
#  ('2021-05-20', 'Finn the Human'): 3,
#  ('2021-05-17', 'Finn the Human'): 1,
#  ('2021-05-01', 'Finn the Human'): 2,
#  ('2021-04-29', 'Finn the Human'): 6,
#  ('2021-04-28', 'Finn the Human'): 1,
#  ('2021-04-26', 'Finn the Human'): 1,
#  ('2021-04-25', 'Finn the Human'): 2,
#  ('2021-04-24', 'Finn the Human'): 2,
#  ('2021-04-23', 'Finn the Human'): 1,
#  ('2021-04-22', 'Finn the Human'): 1,
#  ('2021-04-20', 'Finn the Human'): 3,
#  ('2021-04-19', 'Finn the Human'): 2,
#  ('2021-04-17', 'Finn the Human'): 2,
#  ('2021-04-15', 'Finn the Human'): 6,
#  ('2021-04-10', 'Finn the Human'): 2,
#  ('2021-03-01', 'Finn the Human'): 1,
#  ('2021-02-22', 'Finn the Human'): 1,
#  ('2021-01-18', 'Finn the Human'): 1,
#  ('2021-01-11', 'Finn the Human'): 1,
#  ('2020-12-19', 'Finn the Human'): 1,
#  ('2020-12-14', 'Finn the Human'): 1,
#  ('2020-12-02', 'Finn the Human'): 2,
#  ('2020-11-24', 'Finn the Human'): 1,
#  ('2020-11-20', 'Finn the Human'): 1,
#  ('2020-11-06', 'Finn the Human'): 1,
#  ('2020-11-05', 'Finn the Human'): 1,
#  ('2020-10-11', 'Finn the Human'): 2,
#  ('2020-10-10', 'Finn the Human'): 1,
#  ('2020-09-27', 'Finn the Human'): 1,
#  ('2020-09-16', 'Finn the Human'): 1,
#  ('2020-09-02', 'Finn the Human'): 3,
#  ('2020-09-01', 'Finn the Human'): 1,
#  ('2020-08-21', 'Finn the Human'): 1,
#  ('2020-08-15', 'Finn the Human'): 2,
#  ('2020-08-07', 'Finn the Human'): 4,
#  ('2020-08-03', 'Finn the Human'): 1,
#  ('2020-06-29', 'Finn the Human'): 1,
#  ('2020-05-01', 'Finn the Human'): 3,
#  ('2020-04-29', 'Finn the Human'): 2,
#  ('2020-04-19', 'Finn the Human'): 1,
#  ('2020-04-12', 'Finn the Human'): 1,
#  ('2020-04-05', 'Finn the Human'): 2,
#  ('2020-03-29', 'Finn the Human'): 1,
#  ('2020-03-26', 'Finn the Human'): 1,
#  ('2020-03-23', 'Finn the Human'): 1,
#  ('2020-03-10', 'Finn the Human'): 2,
#  ('2020-03-07', 'Finn the Human'): 1,
#  ('2020-02-28', 'Finn the Human'): 1,
#  ('2020-02-08', 'Finn the Human'): 1,
#  ('2020-02-05', 'Finn the Human'): 5,
#  ('2020-01-28', 'Finn the Human'): 1,
#  ('2019-12-16', 'Finn the Human'): 1,
#  ('2019-12-07', 'Finn the Human'): 2,
#  ('2019-10-24', 'Finn the Human'): 1,
#  ('2019-10-07', 'Finn the Human'): 1,
#  ('2019-10-02', 'Finn the Human'): 1,
#  ('2019-10-01', 'Finn the Human'): 6,
#  ('2019-09-07', 'Finn the Human'): 2,
#  ('2019-09-04', 'Finn the Human'): 1,
#  ('2019-08-17', 'Finn the Human'): 1,
#  ('2019-07-24', 'Finn the Human'): 1,
#  ('2019-07-23', 'Finn the Human'): 1,
#  ('2019-07-20', 'Finn the Human'): 1,
#  ('2019-07-17', 'Finn the Human'): 4,
#  ('2019-07-14', 'Finn the Human'): 3,
#  ('2019-07-13', 'Finn the Human'): 1,
#  ('2019-07-02', 'Finn the Human'): 1,
#  ('2019-06-17', 'Finn the Human'): 1,
#  ('2019-06-11', 'Finn the Human'): 1,
#  ('2019-06-02', 'Finn the Human'): 1,
#  ('2019-05-31', 'Finn the Human'): 3,
#  ('2019-03-29', 'Finn the Human'): 2,
#  ('2019-02-27', 'Finn the Human'): 5,
#  ('2019-02-25', 'Finn the Human'): 2,
#  ('2019-02-22', 'Finn the Human'): 2,
#  ('2019-02-18', 'Finn the Human'): 1,
#  ('2019-02-15', 'Finn the Human'): 2,
#  ('2019-02-02', 'Finn the Human'): 1,
#  ('2019-01-09', 'Finn the Human'): 1,
#  ('2018-12-27', 'Finn the Human'): 1,
#  ('2018-12-25', 'Finn the Human'): 1,
#  ('2018-12-19', 'Finn the Human'): 1,
#  ('2018-11-04', 'Finn the Human'): 5,
#  ('2018-10-30', 'Finn the Human'): 2,
#  ('2018-10-22', 'Finn the Human'): 1,
#  ('2018-09-12', 'Finn the Human'): 3,
#  ('2018-09-07', 'Finn the Human'): 1,
#  ('2018-09-06', 'Finn the Human'): 2,
#  ('2018-09-04', 'Finn the Human'): 2,
#  ('2018-08-25', 'Finn the Human'): 1,
#  ('2018-08-23', 'Finn the Human'): 2,
#  ('2018-07-31', 'Finn the Human'): 2,
#  ('2018-07-29', 'Finn the Human'): 5,
#  ('2018-07-21', 'Finn the Human'): 1,
#  ('2018-07-09', 'Finn the Human'): 1,
#  ('2018-07-03', 'Finn the Human'): 1,
#  ('2018-06-29', 'Finn the Human'): 1,
#  ('2018-06-09', 'Finn the Human'): 1,
#  ('2018-06-05', 'Finn the Human'): 3,
#  ('2018-05-19', 'Finn the Human'): 1,
#  ('2018-04-28', 'Finn the Human'): 1,
#  ('2018-04-23', 'Finn the Human'): 3,
#  ('2018-04-13', 'Finn the Human'): 1,
#  ('2018-04-02', 'Finn the Human'): 3,
#  ('2018-03-16', 'Finn the Human'): 7,
#  ('2018-03-12', 'Finn the Human'): 1,
#  ('2018-03-07', 'Finn the Human'): 1,
#  ('2018-02-03', 'Finn the Human'): 4,
#  ('2018-01-27', 'Finn the Human'): 1,
#  ('2018-01-24', 'Finn the Human'): 1,
#  ('2018-01-02', 'Finn the Human'): 1,
#  ('2017-12-26', 'Finn the Human'): 1,
#  ('2017-12-19', 'Finn the Human'): 2,
#  ('2017-12-18', 'Finn the Human'): 2,
#  ('2017-12-17', 'Finn the Human'): 2,
#  ('2017-12-09', 'Finn the Human'): 4,
#  ('2017-12-08', 'Finn the Human'): 3,
#  ('2017-11-30', 'Finn the Human'): 1,
#  ('2017-11-20', 'Finn the Human'): 3,
#  ('2017-10-26', 'Finn the Human'): 1,
#  ('2017-10-25', 'Finn the Human'): 5,
#  ('2017-10-17', 'Finn the Human'): 1,
#  ('2017-09-24', 'Finn the Human'): 1,
#  ('2017-08-30', 'Finn the Human'): 2,
#  ('2017-08-14', 'Finn the Human'): 2,
#  ('2017-07-18', 'Finn the Human'): 2,
#  ('2017-07-15', 'Finn the Human'): 1,
#  ('2017-07-09', 'Finn the Human'): 2,
#  ('2017-07-04', 'Finn the Human'): 1,
#  ('2017-06-26', 'Finn the Human'): 1,
#  ('2017-06-23', 'Finn the Human'): 1,
#  ('2017-06-22', 'Finn the Human'): 4,
#  ('2017-06-16', 'Finn the Human'): 2,
#  ('2017-06-01', 'Finn the Human'): 1,
#  ('2017-05-11', 'Finn the Human'): 1,
#  ('2017-05-10', 'Finn the Human'): 1,
#  ('2017-05-07', 'Finn the Human'): 1,
#  ('2017-05-04', 'Finn the Human'): 1,
#  ('2017-04-27', 'Finn the Human'): 1,
#  ('2017-04-25', 'Finn the Human'): 1,
#  ('2017-04-23', 'Finn the Human'): 3,
#  ('2017-04-14', 'Finn the Human'): 8,
#  ('2017-04-13', 'Finn the Human'): 1,
#  ('2017-04-12', 'Finn the Human'): 2,
#  ('2017-04-10', 'Finn the Human'): 2,
#  ('2017-04-03', 'Finn the Human'): 2,
#  ('2017-04-01', 'Finn the Human'): 1,
#  ('2017-03-29', 'Finn the Human'): 1,
#  ('2017-03-18', 'Finn the Human'): 1,
#  ('2017-03-17', 'Finn the Human'): 1,
#  ('2017-03-15', 'Finn the Human'): 2,
#  ('2017-03-12', 'Finn the Human'): 1,
#  ('2017-03-03', 'Finn the Human'): 1,
#  ('2017-03-02', 'Finn the Human'): 6,
#  ('2017-02-27', 'Finn the Human'): 1,
#  ('2017-02-26', 'Finn the Human'): 2,
#  ('2017-02-14', 'Finn the Human'): 2,
#  ('2017-02-08', 'Finn the Human'): 2,
#  ('2017-02-01', 'Finn the Human'): 1,
#  ('2017-01-31', 'Finn the Human'): 1,
#  ('2017-01-29', 'Finn the Human'): 2,
#  ('2017-01-28', 'Finn the Human'): 2,
#  ('2017-01-27', 'Finn the Human'): 3,
#  ('2017-01-26', 'Finn the Human'): 1,
#  ('2017-01-25', 'Finn the Human'): 1,
#  ('2017-01-23', 'Finn the Human'): 3,
#  ('2017-01-13', 'Finn the Human'): 1,
#  ('2017-01-11', 'Finn the Human'): 1,
#  ('2017-01-09', 'Finn the Human'): 2,
#  ('2017-01-04', 'Finn the Human'): 2,
#  ('2016-12-22', 'Finn the Human'): 1,
#  ('2016-12-12', 'Finn the Human'): 1,
#  ('2016-12-07', 'Finn the Human'): 2,
#  ('2016-12-06', 'Finn the Human'): 1,
#  ('2016-12-04', 'Finn the Human'): 4,
#  ('2016-11-05', 'Finn the Human'): 3,
#  ('2016-11-03', 'Finn the Human'): 1,
#  ('2016-11-01', 'Finn the Human'): 2,
#  ('2016-10-30', 'Finn the Human'): 1,
#  ('2016-10-24', 'Finn the Human'): 2,
#  ('2016-10-22', 'Finn the Human'): 1,
#  ('2016-10-13', 'Finn the Human'): 2,
#  ('2016-10-12', 'Finn the Human'): 1,
#  ('2016-09-22', 'Finn the Human'): 2,
#  ('2016-09-04', 'Finn the Human'): 1,
#  ('2016-08-24', 'Finn the Human'): 3,
#  ('2016-08-23', 'Finn the Human'): 1,
#  ('2016-08-16', 'Finn the Human'): 2,
#  ('2016-08-15', 'Finn the Human'): 2,
#  ('2016-08-02', 'Finn the Human'): 1,
#  ('2016-07-25', 'Finn the Human'): 3,
#  ('2016-06-29', 'Finn the Human'): 1,
#  ('2016-06-23', 'Finn the Human'): 1,
#  ('2016-06-19', 'Finn the Human'): 1,
#  ('2016-06-18', 'Finn the Human'): 2,
#  ('2016-06-10', 'Finn the Human'): 1,
#  ('2016-05-29', 'Finn the Human'): 1,
#  ('2016-05-15', 'Finn the Human'): 5,
#  ('2016-04-26', 'Finn the Human'): 3,
#  ('2016-04-19', 'Finn the Human'): 4,
#  ('2016-04-11', 'Finn the Human'): 1,
#  ('2016-04-08', 'Finn the Human'): 1,
#  ('2016-04-07', 'Finn the Human'): 1,
#  ('2016-04-04', 'Finn the Human'): 3,
#  ('2016-03-29', 'Finn the Human'): 1,
#  ('2016-03-15', 'Finn the Human'): 2,
#  ('2016-03-14', 'Finn the Human'): 1,
#  ('2016-03-12', 'Finn the Human'): 1,
#  ('2016-03-11', 'Finn the Human'): 1,
#  ('2016-03-09', 'Finn the Human'): 1,
#  ('2016-02-26', 'Finn the Human'): 1,
#  ('2016-01-11', 'Finn the Human'): 3,
#  ('2016-01-03', 'Finn the Human'): 5,
#  ('2015-12-21', 'Finn the Human'): 2,
#  ('2015-12-05', 'Finn the Human'): 1,
#  ('2015-11-19', 'Finn the Human'): 1,
#  ('2015-11-16', 'Finn the Human'): 1,
#  ('2015-10-18', 'Finn the Human'): 1,
#  ('2015-08-23', 'Finn the Human'): 3,
#  ('2015-08-21', 'Finn the Human'): 1,
#  ('2015-08-11', 'Finn the Human'): 1,
#  ('2015-07-31', 'Finn the Human'): 1,
#  ('2015-07-02', 'Finn the Human'): 1,
#  ('2015-06-26', 'Finn the Human'): 1,
#  ('2015-06-21', 'Finn the Human'): 1,
#  ('2015-06-20', 'Finn the Human'): 3,
#  ('2015-06-16', 'Finn the Human'): 2,
#  ('2015-06-15', 'Finn the Human'): 1,
#  ('2015-06-13', 'Finn the Human'): 1,
#  ('2015-06-12', 'Finn the Human'): 1,
#  ('2015-06-09', 'Finn the Human'): 2,
#  ('2015-06-08', 'Finn the Human'): 1,
#  ('2015-06-07', 'Finn the Human'): 1,
#  ('2015-06-06', 'Finn the Human'): 3,
#  ('2015-06-05', 'Finn the Human'): 1,
#  ('2015-06-01', 'Finn the Human'): 2,
#  ('2015-05-22', 'Finn the Human'): 1,
#  ('2015-05-21', 'Finn the Human'): 1,
#  ('2015-05-19', 'Finn the Human'): 2,
#  ('2015-05-17', 'Finn the Human'): 5,
#  ('2015-05-10', 'Finn the Human'): 2,
#  ('2015-05-04', 'Finn the Human'): 1,
#  ('2015-05-03', 'Finn the Human'): 1,
#  ('2015-05-02', 'Finn the Human'): 1,
#  ('2015-05-01', 'Finn the Human'): 2,
#  ('2015-04-19', 'Finn the Human'): 1,
#  ('2015-04-18', 'Finn the Human'): 2,
#  ('2015-04-12', 'Finn the Human'): 1,
#  ('2015-04-10', 'Finn the Human'): 1,
#  ('2015-03-26', 'Finn the Human'): 1,
#  ('2015-03-20', 'Finn the Human'): 4,
#  ('2015-03-16', 'Finn the Human'): 1,
#  ('2015-03-15', 'Finn the Human'): 7,
#  ('2015-03-14', 'Finn the Human'): 2,
#  ('2015-03-11', 'Finn the Human'): 1,
#  ('2015-02-28', 'Finn the Human'): 1,
#  ('2015-02-21', 'Finn the Human'): 4,
#  ('2015-02-20', 'Finn the Human'): 1,
#  ('2015-02-19', 'Finn the Human'): 4,
#  ('2015-02-17', 'Finn the Human'): 1,
#  ('2015-02-14', 'Finn the Human'): 2,
#  ('2015-02-05', 'Finn the Human'): 2,
#  ('2015-01-27', 'Finn the Human'): 1,
#  ('2015-01-19', 'Finn the Human'): 1,
#  ('2015-01-09', 'Finn the Human'): 1,
#  ('2014-12-27', 'Finn the Human'): 1,
#  ('2014-12-12', 'Finn the Human'): 1,
#  ('2014-12-10', 'Finn the Human'): 10,
#  ('2014-12-07', 'Finn the Human'): 4,
#  ('2014-11-30', 'Finn the Human'): 1,
#  ('2014-11-25', 'Finn the Human'): 1,
#  ('2014-11-22', 'Finn the Human'): 1,
#  ('2014-11-16', 'Finn the Human'): 1,
#  ('2014-11-07', 'Finn the Human'): 1,
#  ('2014-10-28', 'Finn the Human'): 1,
#  ('2014-10-27', 'Finn the Human'): 1,
#  ('2014-10-10', 'Finn the Human'): 1,
#  ('2014-10-09', 'Finn the Human'): 1,
#  ('2014-09-08', 'Finn the Human'): 2,
#  ('2014-09-03', 'Finn the Human'): 1,
#  ('2014-08-27', 'Finn the Human'): 3,
#  ('2014-08-24', 'Finn the Human'): 2,
#  ('2014-08-21', 'Finn the Human'): 2,
#  ('2014-08-20', 'Finn the Human'): 1,
#  ('2014-08-18', 'Finn the Human'): 5,
#  ('2014-08-12', 'Finn the Human'): 1,
#  ('2014-08-06', 'Finn the Human'): 2,
#  ('2014-08-05', 'Finn the Human'): 2,
#  ('2014-08-01', 'Finn the Human'): 1,
#  ('2014-07-30', 'Finn the Human'): 1,
#  ('2014-07-27', 'Finn the Human'): 5,
#  ('2014-07-26', 'Finn the Human'): 2,
#  ('2014-07-16', 'Finn the Human'): 2,
#  ('2014-07-09', 'Finn the Human'): 6,
#  ('2014-07-07', 'Finn the Human'): 9,
#  ('2014-06-19', 'Finn the Human'): 1,
#  ('2014-06-07', 'Finn the Human'): 2,
#  ('2014-06-06', 'Finn the Human'): 1,
#  ('2014-06-05', 'Finn the Human'): 5,
#  ('2014-05-30', 'Finn the Human'): 2,
#  ('2014-05-29', 'Finn the Human'): 6,
#  ('2014-05-28', 'Finn the Human'): 1,
#  ('2014-05-26', 'Finn the Human'): 2,
#  ('2014-05-21', 'Finn the Human'): 1,
#  ('2014-05-15', 'Finn the Human'): 1,
#  ('2014-05-11', 'Finn the Human'): 8,
#  ('2014-05-06', 'Finn the Human'): 2,
#  ('2014-04-28', 'Finn the Human'): 6,
#  ('2014-04-26', 'Finn the Human'): 2,
#  ('2014-04-23', 'Finn the Human'): 4,
#  ('2014-04-22', 'Finn the Human'): 6,
#  ('2014-04-21', 'Finn the Human'): 5,
#  ('2014-04-20', 'Finn the Human'): 1,
#  ('2014-04-19', 'Finn the Human'): 4,
#  ('2014-04-18', 'Finn the Human'): 1,
#  ('2014-04-14', 'Finn the Human'): 1,
#  ('2014-04-13', 'Finn the Human'): 2,
#  ('2014-04-11', 'Finn the Human'): 2,
#  ('2014-04-09', 'Finn the Human'): 2,
#  ('2014-04-08', 'Finn the Human'): 2,
#  ('2014-04-07', 'Finn the Human'): 6,
#  ('2014-04-06', 'Finn the Human'): 3,
#  ('2014-04-05', 'Finn the Human'): 3,
#  ('2014-04-04', 'Finn the Human'): 1,
#  ('2014-04-03', 'Finn the Human'): 3,
#  ('2014-04-02', 'Finn the Human'): 3,
#  ('2014-04-01', 'Finn the Human'): 2,
#  ('2014-03-31', 'Finn the Human'): 2,
#  ('2014-03-30', 'Finn the Human'): 4,
#  ('2014-03-29', 'Finn the Human'): 2,
#  ('2014-03-27', 'Finn the Human'): 3,
#  ('2014-03-26', 'Finn the Human'): 2,
#  ('2014-03-25', 'Finn the Human'): 5,
#  ('2014-03-24', 'Finn the Human'): 3,
#  ('2014-03-21', 'Finn the Human'): 4,
#  ('2014-03-20', 'Finn the Human'): 5,
#  ('2014-03-18', 'Finn the Human'): 8,
#  ('2014-03-16', 'Finn the Human'): 1,
#  ('2014-03-14', 'Finn the Human'): 4,
#  ('2014-03-13', 'Finn the Human'): 2,
#  ('2014-03-12', 'Finn the Human'): 4,
#  ('2014-03-11', 'Finn the Human'): 6,
#  ('2014-03-10', 'Finn the Human'): 2,
#  ('2014-03-09', 'Finn the Human'): 1,
#  ('2014-02-26', 'Finn the Human'): 2,
#  ('2014-02-25', 'Finn the Human'): 1,
#  ('2014-02-24', 'Finn the Human'): 1,
#  ('2014-02-09', 'Finn the Human'): 3,
#  ('2014-02-01', 'Finn the Human'): 2,
#  ('2014-01-29', 'Finn the Human'): 1,
#  ('2014-01-28', 'Finn the Human'): 1,
#  ('2014-01-19', 'Finn the Human'): 1,
#  ('2014-01-08', 'Finn the Human'): 1,
#  ('2014-01-02', 'Finn the Human'): 1,
#  ('2013-12-31', 'Finn the Human'): 2,
#  ('2013-12-26', 'Finn the Human'): 2,
#  ('2013-12-15', 'Finn the Human'): 1,
#  ('2013-12-12', 'Finn the Human'): 4,
#  ('2013-12-09', 'Finn the Human'): 1,
#  ('2013-12-02', 'Finn the Human'): 4,
#  ('2013-11-27', 'Finn the Human'): 1,
#  ('2013-11-14', 'Finn the Human'): 4,
#  ('2013-11-05', 'Finn the Human'): 3,
#  ('2013-11-04', 'Finn the Human'): 2,
#  ('2013-10-31', 'Finn the Human'): 2,
#  ('2013-10-23', 'Finn the Human'): 1,
#  ('2013-10-19', 'Finn the Human'): 1,
#  ('2013-10-14', 'Finn the Human'): 1,
#  ('2013-10-13', 'Finn the Human'): 2,
#  ('2013-10-08', 'Finn the Human'): 1,
#  ('2013-09-30', 'Finn the Human'): 2,
#  ('2013-09-27', 'Finn the Human'): 2,
#  ('2013-09-25', 'Finn the Human'): 1,
#  ('2013-09-22', 'Finn the Human'): 2,
#  ('2013-09-17', 'Finn the Human'): 1,
#  ('2013-09-16', 'Finn the Human'): 1,
#  ('2013-09-14', 'Finn the Human'): 1,
#  ('2013-09-10', 'Finn the Human'): 1,
#  ('2013-09-07', 'Finn the Human'): 2,
#  ('2013-09-04', 'Finn the Human'): 1,
#  ('2013-09-03', 'Finn the Human'): 2,
#  ('2013-08-30', 'Finn the Human'): 1,
#  ('2013-08-29', 'Finn the Human'): 6,
#  ('2013-08-25', 'Finn the Human'): 3,
#  ('2013-08-22', 'Finn the Human'): 1,
#  ('2013-08-21', 'Finn the Human'): 1,
#  ('2013-08-19', 'Finn the Human'): 2,
#  ('2013-08-13', 'Finn the Human'): 3,
#  ('2013-08-12', 'Finn the Human'): 5,
#  ('2013-08-06', 'Finn the Human'): 4,
#  ('2013-08-05', 'Finn the Human'): 1,
#  ('2013-08-03', 'Finn the Human'): 1,
#  ('2013-08-02', 'Finn the Human'): 1,
#  ('2013-08-01', 'Finn the Human'): 2,
#  ('2013-07-26', 'Finn the Human'): 2,
#  ('2013-07-17', 'Finn the Human'): 4,
#  ('2013-07-08', 'Finn the Human'): 2,
#  ('2013-06-19', 'Finn the Human'): 2,
#  ('2013-06-18', 'Finn the Human'): 1,
#  ('2013-06-17', 'Finn the Human'): 8,
#  ('2013-06-15', 'Finn the Human'): 1,
#  ('2013-06-11', 'Finn the Human'): 1,
#  ('2013-06-10', 'Finn the Human'): 1,
#  ('2013-06-09', 'Finn the Human'): 2,
#  ('2013-05-30', 'Finn the Human'): 1,
#  ('2013-05-26', 'Finn the Human'): 2,
#  ('2013-05-25', 'Finn the Human'): 4,
#  ('2013-05-23', 'Finn the Human'): 1,
#  ('2013-05-20', 'Finn the Human'): 2,
#  ('2013-05-18', 'Finn the Human'): 1,
#  ('2013-05-11', 'Finn the Human'): 1,
#  ('2013-05-10', 'Finn the Human'): 3,
#  ('2013-05-08', 'Finn the Human'): 1,
#  ('2013-05-05', 'Finn the Human'): 3,
#  ('2013-04-23', 'Finn the Human'): 1,
#  ('2013-04-19', 'Finn the Human'): 1,
#  ('2013-04-16', 'Finn the Human'): 3,
#  ('2013-04-15', 'Finn the Human'): 1,
#  ('2013-04-11', 'Finn the Human'): 2,
#  ('2013-04-07', 'Finn the Human'): 1,
#  ('2013-04-05', 'Finn the Human'): 2,
#  ('2013-04-04', 'Finn the Human'): 1,
#  ('2013-04-02', 'Finn the Human'): 1,
#  ('2013-04-01', 'Finn the Human'): 1,
#  ('2013-03-23', 'Finn the Human'): 1,
#  ('2013-03-22', 'Finn the Human'): 1,
#  ('2013-03-06', 'Finn the Human'): 1,
#  ('2013-03-03', 'Finn the Human'): 1,
#  ('2013-03-02', 'Finn the Human'): 1,
#  ('2013-02-24', 'Finn the Human'): 1,
#  ('2013-02-22', 'Finn the Human'): 1,
#  ('2013-02-19', 'Finn the Human'): 1,
#  ('2013-02-16', 'Finn the Human'): 1,
#  ('2013-02-11', 'Finn the Human'): 1,
#  ('2013-02-09', 'Finn the Human'): 1,
#  ('2013-02-08', 'Finn the Human'): 3,
#  ('2013-02-05', 'Finn the Human'): 1,
#  ('2013-01-31', 'Finn the Human'): 1,
#  ('2013-01-29', 'Finn the Human'): 2,
#  ('2013-01-27', 'Finn the Human'): 1,
#  ('2013-01-23', 'Finn the Human'): 1,
#  ('2013-01-22', 'Finn the Human'): 5,
#  ('2013-01-20', 'Finn the Human'): 1,
#  ('2013-01-19', 'Finn the Human'): 2,
#  ('2013-01-15', 'Finn the Human'): 2,
#  ('2013-01-13', 'Finn the Human'): 1,
#  ('2013-01-12', 'Finn the Human'): 5,
#  ('2013-01-11', 'Finn the Human'): 6,
#  ('2012-10-28', 'Finn the Human'): 4,
#  ('2012-08-24', 'Finn the Human'): 1,
#  ('2012-08-22', 'Finn the Human'): 9,
#  ('2012-08-21', 'Finn the Human'): 5,
#  ('2011-06-28', 'Finn the Human'): 1,
#  ('2011-06-14', 'Finn the Human'): 1,
#  ('2011-05-20', 'Finn the Human'): 1,
#  ('2023-04-15', 'Fionna and Cake'): 1,
#  ('2022-12-11', 'Fionna and Cake'): 1,
#  ('2022-11-10', 'Fionna and Cake'): 1,
#  ('2022-11-09', 'Fionna and Cake'): 2,
#  ('2022-10-19', 'Fionna and Cake'): 1,
#  ('2022-06-15', 'Fionna and Cake'): 2,
#  ('2022-02-03', 'Fionna and Cake'): 1,
#  ('2022-01-19', 'Fionna and Cake'): 1,
#  ('2021-12-19', 'Fionna and Cake'): 3,
#  ('2021-11-02', 'Fionna and Cake'): 1,
#  ('2021-10-29', 'Fionna and Cake'): 1,
#  ('2021-10-20', 'Fionna and Cake'): 1,
#  ('2021-08-29', 'Fionna and Cake'): 1,
#  ('2021-08-20', 'Fionna and Cake'): 1,
#  ('2021-08-19', 'Fionna and Cake'): 1,
#  ('2021-08-17', 'Fionna and Cake'): 1,
#  ('2021-05-10', 'Fionna and Cake'): 1,
#  ('2021-04-30', 'Fionna and Cake'): 1,
#  ('2021-04-18', 'Fionna and Cake'): 1,
#  ('2021-03-10', 'Fionna and Cake'): 2,
#  ('2021-01-02', 'Fionna and Cake'): 1,
#  ('2020-11-11', 'Fionna and Cake'): 1,
#  ('2020-09-15', 'Fionna and Cake'): 2,
#  ('2020-06-25', 'Fionna and Cake'): 1,
#  ('2020-05-08', 'Fionna and Cake'): 1,
#  ('2019-09-23', 'Fionna and Cake'): 1,
#  ('2019-09-20', 'Fionna and Cake'): 1,
#  ('2019-09-17', 'Fionna and Cake'): 1,
#  ('2019-09-03', 'Fionna and Cake'): 1,
#  ('2019-08-21', 'Fionna and Cake'): 1,
#  ('2019-02-27', 'Fionna and Cake'): 1,
#  ('2018-12-04', 'Fionna and Cake'): 1,
#  ('2018-12-03', 'Fionna and Cake'): 1,
#  ('2018-09-02', 'Fionna and Cake'): 2,
#  ('2018-08-22', 'Fionna and Cake'): 1,
#  ('2018-08-21', 'Fionna and Cake'): 7,
#  ('2018-08-12', 'Fionna and Cake'): 1,
#  ('2018-08-02', 'Fionna and Cake'): 1,
#  ('2018-08-01', 'Fionna and Cake'): 1,
#  ('2018-07-26', 'Fionna and Cake'): 2,
#  ('2018-03-02', 'Fionna and Cake'): 1,
#  ('2018-01-11', 'Fionna and Cake'): 1,
#  ('2017-10-07', 'Fionna and Cake'): 1,
#  ('2017-10-05', 'Fionna and Cake'): 1,
#  ('2017-10-01', 'Fionna and Cake'): 1,
#  ('2017-08-31', 'Fionna and Cake'): 1,
#  ('2017-07-26', 'Fionna and Cake'): 1,
#  ('2017-07-22', 'Fionna and Cake'): 1,
#  ('2017-04-21', 'Fionna and Cake'): 2,
#  ('2017-04-07', 'Fionna and Cake'): 3,
#  ('2017-03-31', 'Fionna and Cake'): 1,
#  ('2017-03-26', 'Fionna and Cake'): 1,
#  ('2017-03-16', 'Fionna and Cake'): 2,
#  ('2017-02-26', 'Fionna and Cake'): 2,
#  ('2017-02-11', 'Fionna and Cake'): 1,
#  ('2017-02-10', 'Fionna and Cake'): 1,
#  ('2017-02-03', 'Fionna and Cake'): 1,
#  ('2017-01-20', 'Fionna and Cake'): 1,
#  ('2016-08-01', 'Fionna and Cake'): 1,
#  ('2016-07-29', 'Fionna and Cake'): 1,
#  ('2016-03-20', 'Fionna and Cake'): 2,
#  ('2015-12-13', 'Fionna and Cake'): 2,
#  ('2015-12-04', 'Fionna and Cake'): 2,
#  ('2015-11-13', 'Fionna and Cake'): 1,
#  ('2015-11-03', 'Fionna and Cake'): 1,
#  ('2015-09-02', 'Fionna and Cake'): 1,
#  ('2015-08-15', 'Fionna and Cake'): 1,
#  ('2015-07-27', 'Fionna and Cake'): 2,
#  ('2015-06-07', 'Fionna and Cake'): 1,
#  ('2014-12-16', 'Fionna and Cake'): 2,
#  ('2014-06-08', 'Fionna and Cake'): 2,
#  ('2014-06-01', 'Fionna and Cake'): 1,
#  ('2014-03-30', 'Fionna and Cake'): 4,
#  ('2014-02-15', 'Fionna and Cake'): 1,
#  ('2014-02-04', 'Fionna and Cake'): 1,
#  ('2014-01-12', 'Fionna and Cake'): 3,
#  ('2014-01-01', 'Fionna and Cake'): 1,
#  ('2013-12-31', 'Fionna and Cake'): 1,
#  ('2013-12-28', 'Fionna and Cake'): 2,
#  ('2013-12-23', 'Fionna and Cake'): 1,
#  ('2013-12-20', 'Fionna and Cake'): 2,
#  ('2013-12-10', 'Fionna and Cake'): 1,
#  ('2013-12-09', 'Fionna and Cake'): 1,
#  ('2013-12-06', 'Fionna and Cake'): 4,
#  ('2013-12-04', 'Fionna and Cake'): 11,
#  ('2013-11-27', 'Fionna and Cake'): 1,
#  ('2013-10-23', 'Fionna and Cake'): 4,
#  ('2013-10-09', 'Fionna and Cake'): 1,
#  ('2013-09-29', 'Fionna and Cake'): 1,
#  ('2013-09-26', 'Fionna and Cake'): 1,
#  ('2013-09-22', 'Fionna and Cake'): 1,
#  ('2013-09-08', 'Fionna and Cake'): 3,
#  ('2012-06-05', 'Fionna and Cake'): 1,
#  ('2023-05-04', 'Jake the Dog'): 1,
#  ('2023-04-16', 'Jake the Dog'): 1,
#  ('2023-04-14', 'Jake the Dog'): 2,
#  ('2023-04-13', 'Jake the Dog'): 1,
#  ('2023-01-31', 'Jake the Dog'): 1,
#  ('2023-01-24', 'Jake the Dog'): 1,
#  ('2023-01-20', 'Jake the Dog'): 1,
#  ('2023-01-12', 'Jake the Dog'): 1,
#  ('2023-01-11', 'Jake the Dog'): 1,
#  ('2023-01-10', 'Jake the Dog'): 1,
#  ('2022-12-30', 'Jake the Dog'): 1,
#  ('2022-11-28', 'Jake the Dog'): 2,
#  ('2022-11-23', 'Jake the Dog'): 1,
#  ('2022-10-19', 'Jake the Dog'): 1,
#  ('2022-09-18', 'Jake the Dog'): 1,
#  ('2022-09-13', 'Jake the Dog'): 2,
#  ('2022-09-12', 'Jake the Dog'): 1,
#  ('2022-09-11', 'Jake the Dog'): 1,
#  ('2022-09-04', 'Jake the Dog'): 1,
#  ('2022-08-29', 'Jake the Dog'): 1,
#  ('2022-08-06', 'Jake the Dog'): 1,
#  ('2022-08-03', 'Jake the Dog'): 1,
#  ('2022-07-24', 'Jake the Dog'): 1,
#  ('2022-07-22', 'Jake the Dog'): 1,
#  ('2022-06-26', 'Jake the Dog'): 1,
#  ('2022-05-23', 'Jake the Dog'): 1,
#  ('2022-05-20', 'Jake the Dog'): 1,
#  ('2022-05-11', 'Jake the Dog'): 1,
#  ('2022-04-16', 'Jake the Dog'): 1,
#  ('2022-03-28', 'Jake the Dog'): 16,
#  ('2022-03-27', 'Jake the Dog'): 21,
#  ('2022-03-21', 'Jake the Dog'): 7,
#  ('2022-03-20', 'Jake the Dog'): 10,
#  ('2022-03-10', 'Jake the Dog'): 1,
#  ('2022-03-07', 'Jake the Dog'): 6,
#  ('2022-03-04', 'Jake the Dog'): 1,
#  ('2022-03-01', 'Jake the Dog'): 1,
#  ('2022-02-23', 'Jake the Dog'): 2,
#  ('2022-02-19', 'Jake the Dog'): 4,
#  ('2022-02-18', 'Jake the Dog'): 5,
#  ('2022-02-14', 'Jake the Dog'): 32,
#  ('2022-02-02', 'Jake the Dog'): 2,
#  ('2022-01-31', 'Jake the Dog'): 1,
#  ('2022-01-19', 'Jake the Dog'): 2,
#  ('2022-01-01', 'Jake the Dog'): 1,
#  ('2021-12-21', 'Jake the Dog'): 2,
#  ('2021-12-06', 'Jake the Dog'): 4,
#  ('2021-11-19', 'Jake the Dog'): 1,
#  ('2021-11-15', 'Jake the Dog'): 2,
#  ('2021-11-14', 'Jake the Dog'): 1,
#  ('2021-11-10', 'Jake the Dog'): 1,
#  ('2021-11-09', 'Jake the Dog'): 1,
#  ('2021-11-01', 'Jake the Dog'): 1,
#  ('2021-10-13', 'Jake the Dog'): 1,
#  ('2021-10-11', 'Jake the Dog'): 1,
#  ('2021-10-10', 'Jake the Dog'): 1,
#  ('2021-10-08', 'Jake the Dog'): 1,
#  ('2021-09-09', 'Jake the Dog'): 1,
#  ('2021-07-14', 'Jake the Dog'): 2,
#  ('2021-06-24', 'Jake the Dog'): 1,
#  ('2021-06-15', 'Jake the Dog'): 2,
#  ('2021-05-22', 'Jake the Dog'): 1,
#  ('2021-05-01', 'Jake the Dog'): 2,
#  ('2021-04-29', 'Jake the Dog'): 1,
#  ('2021-04-26', 'Jake the Dog'): 1,
#  ('2021-04-24', 'Jake the Dog'): 4,
#  ('2021-04-23', 'Jake the Dog'): 3,
#  ('2021-04-22', 'Jake the Dog'): 3,
#  ('2021-04-20', 'Jake the Dog'): 4,
#  ('2021-04-19', 'Jake the Dog'): 3,
#  ('2021-04-18', 'Jake the Dog'): 3,
#  ('2021-04-17', 'Jake the Dog'): 2,
#  ('2021-04-05', 'Jake the Dog'): 1,
#  ('2021-04-01', 'Jake the Dog'): 1,
#  ('2021-03-16', 'Jake the Dog'): 2,
#  ('2021-03-10', 'Jake the Dog'): 1,
#  ('2021-02-22', 'Jake the Dog'): 1,
#  ('2021-02-14', 'Jake the Dog'): 1,
#  ('2021-01-25', 'Jake the Dog'): 1,
#  ('2021-01-14', 'Jake the Dog'): 1,
#  ('2021-01-13', 'Jake the Dog'): 3,
#  ('2021-01-05', 'Jake the Dog'): 2,
#  ('2021-01-01', 'Jake the Dog'): 1,
#  ('2020-12-17', 'Jake the Dog'): 1,
#  ('2020-12-14', 'Jake the Dog'): 1,
#  ('2020-11-19', 'Jake the Dog'): 4,
#  ('2020-10-27', 'Jake the Dog'): 2,
#  ('2020-10-10', 'Jake the Dog'): 1,
#  ('2020-09-27', 'Jake the Dog'): 1,
#  ('2020-09-16', 'Jake the Dog'): 2,
#  ('2020-09-15', 'Jake the Dog'): 1,
#  ('2020-09-10', 'Jake the Dog'): 1,
#  ('2020-08-15', 'Jake the Dog'): 1,
#  ('2020-08-10', 'Jake the Dog'): 1,
#  ('2020-04-29', 'Jake the Dog'): 1,
#  ('2020-04-24', 'Jake the Dog'): 1,
#  ('2020-04-19', 'Jake the Dog'): 1,
#  ('2020-04-06', 'Jake the Dog'): 1,
#  ('2020-04-05', 'Jake the Dog'): 6,
#  ('2020-03-29', 'Jake the Dog'): 1,
#  ('2020-03-17', 'Jake the Dog'): 13,
#  ('2020-02-05', 'Jake the Dog'): 5,
#  ('2020-01-29', 'Jake the Dog'): 1,
#  ('2020-01-28', 'Jake the Dog'): 1,
#  ('2020-01-20', 'Jake the Dog'): 2,
#  ('2020-01-14', 'Jake the Dog'): 1,
#  ('2019-12-25', 'Jake the Dog'): 1,
#  ('2019-12-12', 'Jake the Dog'): 2,
#  ('2019-12-07', 'Jake the Dog'): 1,
#  ('2019-12-04', 'Jake the Dog'): 1,
#  ('2019-12-02', 'Jake the Dog'): 1,
#  ('2019-11-25', 'Jake the Dog'): 1,
#  ('2019-11-16', 'Jake the Dog'): 1,
#  ('2019-10-24', 'Jake the Dog'): 1,
#  ('2019-10-13', 'Jake the Dog'): 1,
#  ('2019-10-07', 'Jake the Dog'): 2,
#  ('2019-10-01', 'Jake the Dog'): 2,
#  ('2019-09-23', 'Jake the Dog'): 4,
#  ('2019-09-04', 'Jake the Dog'): 1,
#  ('2019-08-01', 'Jake the Dog'): 2,
#  ('2019-07-24', 'Jake the Dog'): 1,
#  ('2019-07-23', 'Jake the Dog'): 1,
#  ('2019-07-14', 'Jake the Dog'): 1,
#  ('2019-07-13', 'Jake the Dog'): 1,
#  ('2019-07-11', 'Jake the Dog'): 5,
#  ('2019-07-02', 'Jake the Dog'): 1,
#  ('2019-06-17', 'Jake the Dog'): 1,
#  ('2019-06-11', 'Jake the Dog'): 1,
#  ('2019-06-02', 'Jake the Dog'): 1,
#  ('2019-05-31', 'Jake the Dog'): 1,
#  ('2019-05-16', 'Jake the Dog'): 1,
#  ('2019-04-06', 'Jake the Dog'): 1,
#  ('2019-02-28', 'Jake the Dog'): 1,
#  ('2019-02-26', 'Jake the Dog'): 1,
#  ('2019-02-18', 'Jake the Dog'): 1,
#  ('2019-01-16', 'Jake the Dog'): 2,
#  ('2018-12-26', 'Jake the Dog'): 2,
#  ('2018-12-10', 'Jake the Dog'): 1,
#  ('2018-12-09', 'Jake the Dog'): 1,
#  ('2018-11-20', 'Jake the Dog'): 2,
#  ('2018-09-20', 'Jake the Dog'): 1,
#  ('2018-09-13', 'Jake the Dog'): 1,
#  ('2018-09-05', 'Jake the Dog'): 2,
#  ('2018-09-04', 'Jake the Dog'): 1,
#  ('2018-09-03', 'Jake the Dog'): 4,
#  ('2018-08-24', 'Jake the Dog'): 2,
#  ('2018-07-30', 'Jake the Dog'): 1,
#  ('2018-07-29', 'Jake the Dog'): 3,
#  ('2018-05-23', 'Jake the Dog'): 2,
#  ('2018-05-19', 'Jake the Dog'): 1,
#  ('2018-05-07', 'Jake the Dog'): 1,
#  ('2018-04-02', 'Jake the Dog'): 2,
#  ('2018-03-20', 'Jake the Dog'): 2,
#  ('2018-03-17', 'Jake the Dog'): 1,
#  ('2018-03-16', 'Jake the Dog'): 1,
#  ('2018-03-12', 'Jake the Dog'): 3,
#  ('2018-02-11', 'Jake the Dog'): 2,
#  ('2018-01-25', 'Jake the Dog'): 4,
#  ('2018-01-24', 'Jake the Dog'): 2,
#  ('2018-01-19', 'Jake the Dog'): 1,
#  ('2017-12-27', 'Jake the Dog'): 1,
#  ('2017-12-25', 'Jake the Dog'): 1,
#  ('2017-12-18', 'Jake the Dog'): 1,
#  ('2017-12-11', 'Jake the Dog'): 1,
#  ('2017-11-26', 'Jake the Dog'): 1,
#  ('2017-11-20', 'Jake the Dog'): 1,
#  ('2017-11-05', 'Jake the Dog'): 1,
#  ('2017-10-30', 'Jake the Dog'): 1,
#  ('2017-09-02', 'Jake the Dog'): 1,
#  ('2017-08-23', 'Jake the Dog'): 3,
#  ('2017-08-18', 'Jake the Dog'): 2,
#  ('2017-08-15', 'Jake the Dog'): 1,
#  ('2017-08-14', 'Jake the Dog'): 1,
#  ('2017-06-30', 'Jake the Dog'): 2,
#  ('2017-06-20', 'Jake the Dog'): 1,
#  ('2017-06-16', 'Jake the Dog'): 1,
#  ('2017-06-15', 'Jake the Dog'): 2,
#  ('2017-05-25', 'Jake the Dog'): 2,
#  ('2017-05-02', 'Jake the Dog'): 2,
#  ('2017-04-23', 'Jake the Dog'): 2,
#  ('2017-04-06', 'Jake the Dog'): 4,
#  ('2017-02-08', 'Jake the Dog'): 2,
#  ('2017-01-02', 'Jake the Dog'): 1,
#  ('2016-12-27', 'Jake the Dog'): 2,
#  ('2016-12-10', 'Jake the Dog'): 1,
#  ('2016-12-04', 'Jake the Dog'): 1,
#  ('2016-09-23', 'Jake the Dog'): 1,
#  ('2016-08-08', 'Jake the Dog'): 1,
#  ('2016-06-19', 'Jake the Dog'): 3,
#  ('2016-06-14', 'Jake the Dog'): 1,
#  ('2016-06-01', 'Jake the Dog'): 2,
#  ('2016-04-28', 'Jake the Dog'): 1,
#  ('2016-04-26', 'Jake the Dog'): 3,
#  ('2016-04-09', 'Jake the Dog'): 1,
#  ('2016-04-04', 'Jake the Dog'): 1,
#  ('2016-03-29', 'Jake the Dog'): 2,
#  ('2016-03-12', 'Jake the Dog'): 1,
#  ('2016-03-11', 'Jake the Dog'): 1,
#  ('2016-03-05', 'Jake the Dog'): 2,
#  ('2016-02-29', 'Jake the Dog'): 1,
#  ('2016-02-28', 'Jake the Dog'): 1,
#  ('2016-02-23', 'Jake the Dog'): 2,
#  ('2016-02-17', 'Jake the Dog'): 3,
#  ('2016-02-15', 'Jake the Dog'): 1,
#  ('2016-02-13', 'Jake the Dog'): 1,
#  ('2016-01-25', 'Jake the Dog'): 1,
#  ('2016-01-22', 'Jake the Dog'): 1,
#  ('2016-01-13', 'Jake the Dog'): 1,
#  ('2016-01-01', 'Jake the Dog'): 2,
#  ('2015-12-30', 'Jake the Dog'): 1,
#  ('2015-12-25', 'Jake the Dog'): 1,
#  ('2015-12-12', 'Jake the Dog'): 1,
#  ('2015-12-05', 'Jake the Dog'): 1,
#  ('2015-11-28', 'Jake the Dog'): 10,
#  ('2015-11-21', 'Jake the Dog'): 2,
#  ('2015-10-22', 'Jake the Dog'): 1,
#  ('2015-10-14', 'Jake the Dog'): 1,
#  ('2015-10-06', 'Jake the Dog'): 1,
#  ('2015-09-13', 'Jake the Dog'): 1,
#  ('2015-07-30', 'Jake the Dog'): 5,
#  ('2015-07-20', 'Jake the Dog'): 4,
#  ('2015-07-15', 'Jake the Dog'): 3,
#  ('2015-07-12', 'Jake the Dog'): 1,
#  ('2015-07-09', 'Jake the Dog'): 1,
#  ('2015-07-08', 'Jake the Dog'): 1,
#  ('2015-06-15', 'Jake the Dog'): 1,
#  ('2015-06-11', 'Jake the Dog'): 1,
#  ('2015-06-10', 'Jake the Dog'): 1,
#  ('2015-06-09', 'Jake the Dog'): 1,
#  ('2015-05-10', 'Jake the Dog'): 2,
#  ('2015-05-06', 'Jake the Dog'): 2,
#  ('2015-05-03', 'Jake the Dog'): 1,
#  ('2015-02-16', 'Jake the Dog'): 2,
#  ('2015-02-09', 'Jake the Dog'): 1,
#  ('2015-02-06', 'Jake the Dog'): 2,
#  ('2015-01-23', 'Jake the Dog'): 1,
#  ('2015-01-22', 'Jake the Dog'): 3,
#  ('2015-01-21', 'Jake the Dog'): 6,
#  ('2015-01-20', 'Jake the Dog'): 2,
#  ('2015-01-03', 'Jake the Dog'): 2,
#  ('2014-12-27', 'Jake the Dog'): 2,
#  ('2014-12-07', 'Jake the Dog'): 3,
#  ('2014-10-10', 'Jake the Dog'): 2,
#  ('2014-10-01', 'Jake the Dog'): 1,
#  ('2014-09-03', 'Jake the Dog'): 1,
#  ('2014-09-01', 'Jake the Dog'): 1,
#  ('2014-08-26', 'Jake the Dog'): 2,
#  ('2014-08-23', 'Jake the Dog'): 2,
#  ('2014-08-21', 'Jake the Dog'): 3,
#  ('2014-08-18', 'Jake the Dog'): 1,
#  ('2014-08-16', 'Jake the Dog'): 1,
#  ('2014-08-15', 'Jake the Dog'): 1,
#  ('2014-07-13', 'Jake the Dog'): 1,
#  ('2014-04-07', 'Jake the Dog'): 2,
#  ('2014-04-05', 'Jake the Dog'): 1,
#  ('2014-04-04', 'Jake the Dog'): 1,
#  ('2014-04-02', 'Jake the Dog'): 5,
#  ('2014-03-21', 'Jake the Dog'): 3,
#  ('2014-02-15', 'Jake the Dog'): 1,
#  ('2014-01-27', 'Jake the Dog'): 1,
#  ('2014-01-20', 'Jake the Dog'): 1,
#  ('2014-01-02', 'Jake the Dog'): 1,
#  ('2013-12-31', 'Jake the Dog'): 1,
#  ('2013-12-27', 'Jake the Dog'): 1,
#  ('2013-12-11', 'Jake the Dog'): 1,
#  ('2013-11-24', 'Jake the Dog'): 1,
#  ('2013-10-31', 'Jake the Dog'): 2,
#  ('2013-10-30', 'Jake the Dog'): 1,
#  ('2013-10-24', 'Jake the Dog'): 1,
#  ('2013-10-13', 'Jake the Dog'): 2,
#  ('2013-10-06', 'Jake the Dog'): 2,
#  ('2013-10-03', 'Jake the Dog'): 1,
#  ('2013-10-02', 'Jake the Dog'): 1,
#  ('2013-09-22', 'Jake the Dog'): 2,
#  ('2013-09-16', 'Jake the Dog'): 2,
#  ('2013-09-10', 'Jake the Dog'): 1,
#  ('2013-09-05', 'Jake the Dog'): 2,
#  ('2013-08-30', 'Jake the Dog'): 1,
#  ('2013-08-24', 'Jake the Dog'): 2,
#  ('2013-08-13', 'Jake the Dog'): 1,
#  ('2013-08-06', 'Jake the Dog'): 2,
#  ('2013-08-03', 'Jake the Dog'): 1,
#  ('2013-08-02', 'Jake the Dog'): 1,
#  ('2013-07-20', 'Jake the Dog'): 1,
#  ('2013-07-10', 'Jake the Dog'): 2,
#  ('2013-06-18', 'Jake the Dog'): 3,
#  ('2013-06-17', 'Jake the Dog'): 6,
#  ('2013-05-30', 'Jake the Dog'): 1,
#  ('2013-05-23', 'Jake the Dog'): 1,
#  ('2013-05-07', 'Jake the Dog'): 2,
#  ('2013-05-06', 'Jake the Dog'): 2,
#  ('2013-05-05', 'Jake the Dog'): 2,
#  ('2013-04-23', 'Jake the Dog'): 1,
#  ('2013-04-09', 'Jake the Dog'): 1,
#  ('2013-03-22', 'Jake the Dog'): 1,
#  ('2013-03-20', 'Jake the Dog'): 1,
#  ('2013-03-17', 'Jake the Dog'): 2,
#  ('2013-03-03', 'Jake the Dog'): 1,
#  ('2013-03-02', 'Jake the Dog'): 1,
#  ('2013-02-28', 'Jake the Dog'): 2,
#  ('2013-02-23', 'Jake the Dog'): 1,
#  ('2013-02-20', 'Jake the Dog'): 2,
#  ('2013-02-19', 'Jake the Dog'): 1,
#  ('2013-02-18', 'Jake the Dog'): 2,
#  ('2013-02-16', 'Jake the Dog'): 1,
#  ('2013-02-15', 'Jake the Dog'): 1,
#  ('2013-02-09', 'Jake the Dog'): 3,
#  ('2013-02-07', 'Jake the Dog'): 1,
#  ('2013-01-31', 'Jake the Dog'): 2,
#  ('2013-01-30', 'Jake the Dog'): 1,
#  ('2013-01-28', 'Jake the Dog'): 1,
#  ('2013-01-27', 'Jake the Dog'): 3,
#  ('2013-01-25', 'Jake the Dog'): 1,
#  ('2013-01-24', 'Jake the Dog'): 4,
#  ('2013-01-13', 'Jake the Dog'): 1,
#  ('2013-01-11', 'Jake the Dog'): 12,
#  ('2012-10-28', 'Jake the Dog'): 4,
#  ('2012-08-24', 'Jake the Dog'): 1,
#  ('2012-08-22', 'Jake the Dog'): 7,
#  ('2012-08-21', 'Jake the Dog'): 8,
#  ('2011-06-14', 'Jake the Dog'): 1,
#  ('2011-05-20', 'Jake the Dog'): 1,
#  ('2023-04-20', 'Marceline the Vampire Queen'): 2,
#  ('2023-04-19', 'Marceline the Vampire Queen'): 2,
#  ('2023-04-07', 'Marceline the Vampire Queen'): 2,
#  ('2023-03-18', 'Marceline the Vampire Queen'): 1,
#  ('2023-03-17', 'Marceline the Vampire Queen'): 1,
#  ('2023-02-26', 'Marceline the Vampire Queen'): 1,
#  ('2023-02-23', 'Marceline the Vampire Queen'): 1,
#  ('2023-02-05', 'Marceline the Vampire Queen'): 1,
#  ('2022-12-08', 'Marceline the Vampire Queen'): 2,
#  ('2022-10-17', 'Marceline the Vampire Queen'): 1,
#  ('2022-09-13', 'Marceline the Vampire Queen'): 1,
#  ('2022-08-21', 'Marceline the Vampire Queen'): 1,
#  ('2022-08-19', 'Marceline the Vampire Queen'): 1,
#  ('2022-06-22', 'Marceline the Vampire Queen'): 2,
#  ('2022-06-06', 'Marceline the Vampire Queen'): 1,
#  ('2022-05-05', 'Marceline the Vampire Queen'): 2,
#  ('2022-04-28', 'Marceline the Vampire Queen'): 1,
#  ('2022-04-15', 'Marceline the Vampire Queen'): 1,
#  ('2022-04-11', 'Marceline the Vampire Queen'): 6,
#  ('2022-03-13', 'Marceline the Vampire Queen'): 1,
#  ('2022-03-09', 'Marceline the Vampire Queen'): 1,
#  ('2022-03-08', 'Marceline the Vampire Queen'): 1,
#  ('2022-02-05', 'Marceline the Vampire Queen'): 1,
#  ('2022-02-04', 'Marceline the Vampire Queen'): 1,
#  ('2022-01-23', 'Marceline the Vampire Queen'): 1,
#  ('2022-01-22', 'Marceline the Vampire Queen'): 1,
#  ('2022-01-14', 'Marceline the Vampire Queen'): 1,
#  ('2022-01-10', 'Marceline the Vampire Queen'): 1,
#  ('2022-01-01', 'Marceline the Vampire Queen'): 1,
#  ('2021-11-09', 'Marceline the Vampire Queen'): 2,
#  ('2021-09-24', 'Marceline the Vampire Queen'): 2,
#  ('2021-09-22', 'Marceline the Vampire Queen'): 2,
#  ('2021-09-14', 'Marceline the Vampire Queen'): 2,
#  ('2021-09-06', 'Marceline the Vampire Queen'): 2,
#  ('2021-08-13', 'Marceline the Vampire Queen'): 1,
#  ('2021-08-04', 'Marceline the Vampire Queen'): 1,
#  ('2021-07-22', 'Marceline the Vampire Queen'): 1,
#  ('2021-05-15', 'Marceline the Vampire Queen'): 2,
#  ('2021-05-01', 'Marceline the Vampire Queen'): 2,
#  ('2021-04-29', 'Marceline the Vampire Queen'): 2,
#  ('2021-04-27', 'Marceline the Vampire Queen'): 2,
#  ('2021-04-22', 'Marceline the Vampire Queen'): 4,
#  ('2021-04-17', 'Marceline the Vampire Queen'): 6,
#  ...}

# %%
with open("Adventure_Time_edits_by_day.tsv", "w", encoding='utf-8') as output_file:
    # write a header with three columns
    print("title\tdate\tedits", file=output_file)

    # iterate through every day and title and print out data into the file
    for key in edits_by_day.keys():
        title = key[1]
        day_string = key[0]
        print("\t".join([title, day_string, str(edits_by_day[key])]), file=output_file)

# %% [markdown]
# https://docs.google.com/spreadsheets/d/1zGd-TfhISpTmsMm1N6fC68doyCI7X1n_Gt3v1psJNE0/edit?usp=sharing

# %% [markdown]
# 2. Now grab data for the 5 articles you chose from the Fandom.com wiki you identified and grab revision/edit data from there. (Hint: Your wikipedia work will give you lots of clues here: for example, the fandom API endpoint for The Wire is https://thewire.fandom.com/api.php and the Fandom API, as I said in class, is the same as the Wikipedia API). Produce answers to the same three questions (i, ii, and iii) above but using this dataset.

# %% [markdown]
# Finally, choose either your Wikipedia or Fandom datasets as the data source for a visualization that shows how each of those articles have grown in length (as measured in characters or "bytes") over time. (Hint: you'll need to return "size" as one of the revision properties (rvprop) if you are not doing it already.)
