# %% [markdown]
# import json
# import pandas as pd
# #building our function
# def build_songs_dataframe(audio_features_filename):
#
#     songs = []
#     with open(audio_features_filename, "r") as input_file:
#         for line in input_file.readlines():
#             song_features = json.loads(line)[0]
#             songs.append(song_features)
#
#     return pd.DataFrame(songs)

# %%
from build_songs_dataframe import *
df_songs = build_songs_dataframe("2021_playlist_audio_features.jsonl")
df_songs["year"]=2021

# %%
print("danceability mean", df_songs['danceability'].mean())
# Out:
# danceability mean 0.6923900000000001

# %%
print("energy mean", df_songs['energy'].mean())
# Out:
# energy mean 0.6145

# %%
print("loudness mean", df_songs['loudness'].mean())

#The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire trackand are useful for
#comparing relative loudness of tracks. Loudness is the quality of a sound that is
#the primary psychological correlate of physical strength (amplitude).
#Values typically range between -60 and 0 db.
# Out:
# loudness mean -6.412909999999999

# %%
print("mode mean", df_songs['mode'].mean())
# Out:
# mode mean 0.61

# %%
print("speechiness mean", df_songs['speechiness'].mean())
# Out:
# speechiness mean 0.10080599999999999

# %%
print("acousticness mean", df_songs['acousticness'].mean())
# Out:
# acousticness mean 0.2104863

# %%
print("instrumentalness mean", df_songs['instrumentalness'].mean())
# Out:
# instrumentalness mean 0.0060931204

# %%
print("liveness mean", df_songs['liveness'].mean())
# Out:
# liveness mean 0.16212700000000002

# %%
print("valence mean", df_songs['valence'].mean())
# Out:
# valence mean 0.48895000000000005

# %%
print("tempo mean", df_songs['tempo'].mean())
# Out:
# tempo mean 119.38212000000001

# %%
print("time_signature mean", df_songs['time_signature'].mean())
# Out:
# time_signature mean 3.97

# %%
df_songs["key"].hist()
# Out:
# <Axes: >

# %%
df_songs["mode"].hist()
# Out:
# <Axes: >

# %%
df_songs["time_signature"].hist()
# Out:
# <Axes: >

# %%
df_songs.describe()
# Out:
#        danceability      energy        key    loudness        mode  \
# count    100.000000  100.000000  100.00000  100.000000  100.000000
# mean       0.692390    0.614500    4.75000   -6.412910    0.610000
# std        0.132634    0.146345    3.84123    1.991806    0.490207
# min        0.311000    0.225000    0.00000  -14.007000    0.000000
# 25%        0.629750    0.522500    1.00000   -7.896250    0.000000
# 50%        0.713500    0.617500    4.00000   -6.351000    1.000000
# 75%        0.781000    0.730250    8.00000   -4.770750    1.000000
# max        0.965000    0.897000   11.00000   -2.724000    1.000000
#
#        speechiness  acousticness  instrumentalness    liveness     valence  \
# count   100.000000    100.000000        100.000000  100.000000  100.000000
# mean      0.100806      0.210486          0.006093    0.162127    0.488950
# std       0.088261      0.229572          0.037599    0.113424    0.232789
# min       0.026200      0.001200          0.000000    0.042400    0.062800
# 25%       0.039825      0.021425          0.000000    0.094800    0.295750
# 50%       0.068450      0.148000          0.000000    0.121500    0.476000
# 75%       0.118250      0.301000          0.000054    0.187000    0.665000
# max       0.420000      0.937000          0.352000    0.688000    0.958000
#
#             tempo    duration_ms  time_signature    year
# count  100.000000     100.000000      100.000000   100.0
# mean   119.382120  196633.550000        3.970000  2021.0
# std     27.729688   54750.293218        0.171447     0.0
# min     71.944000  122174.000000        3.000000  2021.0
# 25%     94.762750  168543.750000        4.000000  2021.0
# 50%    118.071000  189182.000000        4.000000  2021.0
# 75%    139.990250  213048.750000        4.000000  2021.0
# max    188.700000  613027.000000        4.000000  2021.0
