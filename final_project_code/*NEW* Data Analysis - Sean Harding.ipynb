# %%
import pandas as pd
import datetime

# %%
articlesdf = pd.read_pickle('articlesdf.pkl')

# %%
articlesdf
# Out:
#             id                date  \
# 0            1 2006-09-08 18:26:39
# 1            2 2006-09-08 18:29:19
# 2            3 2006-09-08 18:31:24
# 3            4 2006-09-08 18:33:52
# 4            5 2006-09-08 18:36:52
# ...        ...                 ...
# 203345  267030 2023-05-25 16:13:55
# 203346  267031 2023-05-25 16:39:33
# 203347  267032 2023-05-25 16:33:32
# 203348  267033 2023-05-25 16:46:17
# 203349  267035 2023-05-25 18:32:13
#
#                                                     title administration  \
# 0                  Army releases new interrogation manual           Bush
# 1       AKO to video stream Army's home opener vs. Ken...           Bush
# 2       9/11 Remembrance: NYPD cyclists begin fifth ri...           Bush
# 3       Freedom Walks to commemorate 9/11, honor veterans           Bush
# 4       Guarding information is everyone's responsibility           Bush
# ...                                                   ...            ...
# ...

# %%
articlesdf[articlesdf['body'].str.contains('', case = False)] 
#articlesdf[articlesdf['body'] == ''] 
#case=False

# %%
#upper/lower string searches?

# %%
articlesdf["administration"].hist(log=True)

# %%
bushdf =  articlesdf[articlesdf['administration'].str.contains('Bush')]
obamadf1 =  articlesdf[articlesdf['administration'].str.contains('Obama 1')]
obamadf2 =  articlesdf[articlesdf['administration'].str.contains('Obama 2')]
trumpdf =  articlesdf[articlesdf['administration'].str.contains('Trump')]
bidendf =  articlesdf[articlesdf['administration'].str.contains('Biden')]

# %%
# print(len(bushdf))
# print(len(obamadf1))
# print(len(obamadf2))
# print(len(trumpdf))
# print(len(bidendf))

# %%
#len(obamadf1[obamadf1['body'].str.contains('Ukraine', case = False)])
len(obamadf2[obamadf2['body'].str.contains('Ukraine', case = False)])
# Out:
# 466

# %%
len(bushdf[bushdf['body'].str.contains('Ukraine', case = False)])
# Out:
# 20

# %%
#trumpdf[trumpdf['body'].str.contains('Ukraine')]
len(trumpdf[trumpdf['body'].str.contains('Putin', case = False)])
# Out:
# 303

# %%
bidendf[bidendf['body'].str.contains('Ukraine', case = False)]
# Out:
#             id                date  \
# 180721  242737 2021-01-25 08:33:54
# 181002  243038 2021-02-16 12:00:00
# 181098  243166 2021-02-09 06:14:17
# 181132  243205 2021-02-09 11:38:00
# 181718  243835 2021-03-02 09:36:31
# ...        ...                 ...
# 203217  266897 2023-05-22 18:49:21
# 203246  266926 2023-05-23 08:47:41
# 203248  266929 2023-05-23 08:49:45
# 203270  266952 2023-05-23 15:55:17
# 203345  267030 2023-05-25 16:13:55
#
#                                                     title administration  \
# 180721  Task Force Illini expands Ukraine mission to Kyiv          Biden
# 181002  Cash is King: Units Must Incorporate Cash Oper...          Biden
# 181098  Regional Health Command Europe conducts Global...          Biden
# 181132  Task Force Illini advisors oversee Ukrainian w...          Biden
# 181718                              Rooting out extremism          Biden
# ...                                                   ...            ...
# ...
