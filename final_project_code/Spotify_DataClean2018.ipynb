# %%
import json
import pandas as pd

# %%
songs = []
with open("2018_playlist_audio_features.jsonl", "r") as input_file:
    for line in input_file.readlines():
        song_features = json.loads(line)[0]
        songs.append(song_features)

# %%
songs
# Out:
# [{'danceability': 0.754,
#   'energy': 0.449,
#   'key': 7,
#   'loudness': -9.211,
#   'mode': 1,
#   'speechiness': 0.109,
#   'acousticness': 0.0332,
#   'instrumentalness': 8.29e-05,
#   'liveness': 0.552,
#   'valence': 0.357,
#   'tempo': 77.169,
#   'type': 'audio_features',
#   'id': '6DCZcSspjsKoFjzjrWoCdn',
#   'uri': 'spotify:track:6DCZcSspjsKoFjzjrWoCdn',
#   'track_href': 'https://api.spotify.com/v1/tracks/6DCZcSspjsKoFjzjrWoCdn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6DCZcSspjsKoFjzjrWoCdn',
#   'duration_ms': 198973,
#   'time_signature': 4},
#  {'danceability': 0.585,
#   'energy': 0.52,
#   'key': 5,
#   'loudness': -6.136,
#   'mode': 0,
#   'speechiness': 0.0712,
#   'acousticness': 0.124,
#   'instrumentalness': 7.01e-05,
#   'liveness': 0.131,
#   'valence': 0.129,
#   'tempo': 159.801,
#   'type': 'audio_features',
#   'id': '0e7ipj03S05BNilyu5bRzt',
#   'uri': 'spotify:track:0e7ipj03S05BNilyu5bRzt',
#   'track_href': 'https://api.spotify.com/v1/tracks/0e7ipj03S05BNilyu5bRzt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0e7ipj03S05BNilyu5bRzt',
#   'duration_ms': 218147,
#   'time_signature': 4},
#  {'danceability': 0.351,
#   'energy': 0.296,
#   'key': 4,
#   'loudness': -10.109,
#   'mode': 0,
#   'speechiness': 0.0333,
#   'acousticness': 0.934,
#   'instrumentalness': 0,
#   'liveness': 0.095,
#   'valence': 0.12,
#   'tempo': 115.284,
#   'type': 'audio_features',
#   'id': '0u2P5u6lvoDfwTYjAADbn4',
#   'uri': 'spotify:track:0u2P5u6lvoDfwTYjAADbn4',
#   'track_href': 'https://api.spotify.com/v1/tracks/0u2P5u6lvoDfwTYjAADbn4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0u2P5u6lvoDfwTYjAADbn4',
#   'duration_ms': 200186,
#   'time_signature': 4},
#  {'danceability': 0.461,
#   'energy': 0.593,
#   'key': 1,
#   'loudness': -4.954,
#   'mode': 1,
#   'speechiness': 0.0356,
#   'acousticness': 0.17,
#   'instrumentalness': 0,
#   'liveness': 0.307,
#   'valence': 0.175,
#   'tempo': 134.17,
#   'type': 'audio_features',
#   'id': '09mEdoA6zrmBPgTEN5qXmN',
#   'uri': 'spotify:track:09mEdoA6zrmBPgTEN5qXmN',
#   'track_href': 'https://api.spotify.com/v1/tracks/09mEdoA6zrmBPgTEN5qXmN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/09mEdoA6zrmBPgTEN5qXmN',
#   'duration_ms': 228373,
#   'time_signature': 3},
#  {'danceability': 0.698,
#   'energy': 0.633,
#   'key': 8,
#   'loudness': -4.946,
#   'mode': 1,
#   'speechiness': 0.0597,
#   'acousticness': 0.0605,
#   'instrumentalness': 0.000194,
#   'liveness': 0.0926,
#   'valence': 0.552,
#   'tempo': 96.924,
#   'type': 'audio_features',
#   'id': '3GCdLUSnKSMJhs4Tj6CV3s',
#   'uri': 'spotify:track:3GCdLUSnKSMJhs4Tj6CV3s',
#   'track_href': 'https://api.spotify.com/v1/tracks/3GCdLUSnKSMJhs4Tj6CV3s',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3GCdLUSnKSMJhs4Tj6CV3s',
#   'duration_ms': 232187,
#   'time_signature': 4},
#  {'danceability': 0.511,
#   'energy': 0.566,
#   'key': 6,
#   'loudness': -7.23,
#   'mode': 0,
#   'speechiness': 0.2,
#   'acousticness': 0.349,
#   'instrumentalness': 0,
#   'liveness': 0.34,
#   'valence': 0.218,
#   'tempo': 83.903,
#   'type': 'audio_features',
#   'id': '285pBltuF7vW8TeWk8hdRR',
#   'uri': 'spotify:track:285pBltuF7vW8TeWk8hdRR',
#   'track_href': 'https://api.spotify.com/v1/tracks/285pBltuF7vW8TeWk8hdRR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/285pBltuF7vW8TeWk8hdRR',
#   'duration_ms': 239836,
#   'time_signature': 4},
#  {'danceability': 0.753,
#   'energy': 0.657,
#   'key': 7,
#   'loudness': -3.061,
#   'mode': 1,
#   'speechiness': 0.0449,
#   'acousticness': 0.171,
#   'instrumentalness': 0,
#   'liveness': 0.112,
#   'valence': 0.437,
#   'tempo': 107.01,
#   'type': 'audio_features',
#   'id': '09IStsImFySgyp0pIQdqAc',
#   'uri': 'spotify:track:09IStsImFySgyp0pIQdqAc',
#   'track_href': 'https://api.spotify.com/v1/tracks/09IStsImFySgyp0pIQdqAc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/09IStsImFySgyp0pIQdqAc',
#   'duration_ms': 184732,
#   'time_signature': 4},
#  {'danceability': 0.626,
#   'energy': 0.88,
#   'key': 9,
#   'loudness': -2.384,
#   'mode': 0,
#   'speechiness': 0.0504,
#   'acousticness': 0.205,
#   'instrumentalness': 0,
#   'liveness': 0.128,
#   'valence': 0.534,
#   'tempo': 95.079,
#   'type': 'audio_features',
#   'id': '08bNPGLD8AhKpnnERrAc6G',
#   'uri': 'spotify:track:08bNPGLD8AhKpnnERrAc6G',
#   'track_href': 'https://api.spotify.com/v1/tracks/08bNPGLD8AhKpnnERrAc6G',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/08bNPGLD8AhKpnnERrAc6G',
#   'duration_ms': 202621,
#   'time_signature': 4},
#  {'danceability': 0.816,
#   'energy': 0.726,
#   'key': 5,
#   'loudness': -3.998,
#   'mode': 0,
#   'speechiness': 0.129,
#   'acousticness': 0.099,
#   'instrumentalness': 0,
#   'liveness': 0.372,
#   'valence': 0.65,
#   'tempo': 136.048,
#   'type': 'audio_features',
#   'id': '58q2HKrzhC3ozto2nDdN4z',
#   'uri': 'spotify:track:58q2HKrzhC3ozto2nDdN4z',
#   'track_href': 'https://api.spotify.com/v1/tracks/58q2HKrzhC3ozto2nDdN4z',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/58q2HKrzhC3ozto2nDdN4z',
#   'duration_ms': 253390,
#   'time_signature': 4},
#  {'danceability': 0.834,
#   'energy': 0.73,
#   'key': 8,
#   'loudness': -3.714,
#   'mode': 1,
#   'speechiness': 0.222,
#   'acousticness': 0.00513,
#   'instrumentalness': 0,
#   'liveness': 0.124,
#   'valence': 0.446,
#   'tempo': 155.008,
#   'type': 'audio_features',
#   'id': '2xLMifQCjDGFmkHkpNLD9h',
#   'uri': 'spotify:track:2xLMifQCjDGFmkHkpNLD9h',
#   'track_href': 'https://api.spotify.com/v1/tracks/2xLMifQCjDGFmkHkpNLD9h',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2xLMifQCjDGFmkHkpNLD9h',
#   'duration_ms': 312820,
#   'time_signature': 4},
#  {'danceability': 0.699,
#   'energy': 0.713,
#   'key': 9,
#   'loudness': -5.507,
#   'mode': 0,
#   'speechiness': 0.0594,
#   'acousticness': 0.04,
#   'instrumentalness': 3.11e-06,
#   'liveness': 0.294,
#   'valence': 0.354,
#   'tempo': 121.993,
#   'type': 'audio_features',
#   'id': '2qT1uLXPVPzGgFOx4jtEuo',
#   'uri': 'spotify:track:2qT1uLXPVPzGgFOx4jtEuo',
#   'track_href': 'https://api.spotify.com/v1/tracks/2qT1uLXPVPzGgFOx4jtEuo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2qT1uLXPVPzGgFOx4jtEuo',
#   'duration_ms': 205920,
#   'time_signature': 4},
#  {'danceability': 0.566,
#   'energy': 0.366,
#   'key': 7,
#   'loudness': -12.808,
#   'mode': 1,
#   'speechiness': 0.028,
#   'acousticness': 0.113,
#   'instrumentalness': 0.181,
#   'liveness': 0.155,
#   'valence': 0.237,
#   'tempo': 129.96,
#   'type': 'audio_features',
#   'id': '6IPwKM3fUUzlElbvKw2sKl',
#   'uri': 'spotify:track:6IPwKM3fUUzlElbvKw2sKl',
#   'track_href': 'https://api.spotify.com/v1/tracks/6IPwKM3fUUzlElbvKw2sKl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6IPwKM3fUUzlElbvKw2sKl',
#   'duration_ms': 184154,
#   'time_signature': 4},
#  {'danceability': 0.791,
#   'energy': 0.862,
#   'key': 9,
#   'loudness': -3.24,
#   'mode': 0,
#   'speechiness': 0.11,
#   'acousticness': 0.037,
#   'instrumentalness': 2.19e-05,
#   'liveness': 0.0814,
#   'valence': 0.592,
#   'tempo': 123.994,
#   'type': 'audio_features',
#   'id': '7ef4DlsgrMEH11cDZd32M6',
#   'uri': 'spotify:track:7ef4DlsgrMEH11cDZd32M6',
#   'track_href': 'https://api.spotify.com/v1/tracks/7ef4DlsgrMEH11cDZd32M6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7ef4DlsgrMEH11cDZd32M6',
#   'duration_ms': 214847,
#   'time_signature': 4},
#  {'danceability': 0.88,
#   'energy': 0.428,
#   'key': 9,
#   'loudness': -8.28,
#   'mode': 1,
#   'speechiness': 0.206,
#   'acousticness': 0.149,
#   'instrumentalness': 5.05e-05,
#   'liveness': 0.114,
#   'valence': 0.333,
#   'tempo': 100.007,
#   'type': 'audio_features',
#   'id': '7sO5G9EABYOXQKNPNiE9NR',
#   'uri': 'spotify:track:7sO5G9EABYOXQKNPNiE9NR',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sO5G9EABYOXQKNPNiE9NR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sO5G9EABYOXQKNPNiE9NR',
#   'duration_ms': 172800,
#   'time_signature': 4},
#  {'danceability': 0.8,
#   'energy': 0.585,
#   'key': 10,
#   'loudness': -7.343,
#   'mode': 1,
#   'speechiness': 0.0924,
#   'acousticness': 0.264,
#   'instrumentalness': 0,
#   'liveness': 0.153,
#   'valence': 0.779,
#   'tempo': 126.058,
#   'type': 'audio_features',
#   'id': '6PGoSes0D9eUDeeAafB2As',
#   'uri': 'spotify:track:6PGoSes0D9eUDeeAafB2As',
#   'track_href': 'https://api.spotify.com/v1/tracks/6PGoSes0D9eUDeeAafB2As',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6PGoSes0D9eUDeeAafB2As',
#   'duration_ms': 213400,
#   'time_signature': 4},
#  {'danceability': 0.75,
#   'energy': 0.404,
#   'key': 9,
#   'loudness': -10.178,
#   'mode': 0,
#   'speechiness': 0.0682,
#   'acousticness': 0.216,
#   'instrumentalness': 0.000357,
#   'liveness': 0.0911,
#   'valence': 0.0499,
#   'tempo': 95.045,
#   'type': 'audio_features',
#   'id': '6NFyWDv5CjfwuzoCkw47Xf',
#   'uri': 'spotify:track:6NFyWDv5CjfwuzoCkw47Xf',
#   'track_href': 'https://api.spotify.com/v1/tracks/6NFyWDv5CjfwuzoCkw47Xf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6NFyWDv5CjfwuzoCkw47Xf',
#   'duration_ms': 232253,
#   'time_signature': 4},
#  {'danceability': 0.687,
#   'energy': 0.792,
#   'key': 5,
#   'loudness': -2.749,
#   'mode': 1,
#   'speechiness': 0.0452,
#   'acousticness': 0.191,
#   'instrumentalness': 0,
#   'liveness': 0.167,
#   'valence': 0.671,
#   'tempo': 100.015,
#   'type': 'audio_features',
#   'id': '2dpaYNEQHiRxtZbfNsse99',
#   'uri': 'spotify:track:2dpaYNEQHiRxtZbfNsse99',
#   'track_href': 'https://api.spotify.com/v1/tracks/2dpaYNEQHiRxtZbfNsse99',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2dpaYNEQHiRxtZbfNsse99',
#   'duration_ms': 214290,
#   'time_signature': 4},
#  {'danceability': 0.921,
#   'energy': 0.537,
#   'key': 9,
#   'loudness': -5.723,
#   'mode': 0,
#   'speechiness': 0.0804,
#   'acousticness': 0.556,
#   'instrumentalness': 0.00404,
#   'liveness': 0.102,
#   'valence': 0.711,
#   'tempo': 128.009,
#   'type': 'audio_features',
#   'id': '0JP9xo3adEtGSdUEISiszL',
#   'uri': 'spotify:track:0JP9xo3adEtGSdUEISiszL',
#   'track_href': 'https://api.spotify.com/v1/tracks/0JP9xo3adEtGSdUEISiszL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0JP9xo3adEtGSdUEISiszL',
#   'duration_ms': 135090,
#   'time_signature': 4},
#  {'danceability': 0.963,
#   'energy': 0.346,
#   'key': 5,
#   'loudness': -9.309,
#   'mode': 0,
#   'speechiness': 0.53,
#   'acousticness': 0.0355,
#   'instrumentalness': 0,
#   'liveness': 0.108,
#   'valence': 0.562,
#   'tempo': 119.957,
#   'type': 'audio_features',
#   'id': '6vN77lE9LK6HP2DewaN6HZ',
#   'uri': 'spotify:track:6vN77lE9LK6HP2DewaN6HZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/6vN77lE9LK6HP2DewaN6HZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6vN77lE9LK6HP2DewaN6HZ',
#   'duration_ms': 142273,
#   'time_signature': 4},
#  {'danceability': 0.753,
#   'energy': 0.505,
#   'key': 9,
#   'loudness': -7.621,
#   'mode': 1,
#   'speechiness': 0.255,
#   'acousticness': 0.534,
#   'instrumentalness': 2.58e-06,
#   'liveness': 0.104,
#   'valence': 0.419,
#   'tempo': 91.972,
#   'type': 'audio_features',
#   'id': '0EcQcdcbQeVJn9fknj44Be',
#   'uri': 'spotify:track:0EcQcdcbQeVJn9fknj44Be',
#   'track_href': 'https://api.spotify.com/v1/tracks/0EcQcdcbQeVJn9fknj44Be',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0EcQcdcbQeVJn9fknj44Be',
#   'duration_ms': 197437,
#   'time_signature': 4},
#  {'danceability': 0.68,
#   'energy': 0.578,
#   'key': 10,
#   'loudness': -5.804,
#   'mode': 1,
#   'speechiness': 0.04,
#   'acousticness': 0.331,
#   'instrumentalness': 0,
#   'liveness': 0.135,
#   'valence': 0.341,
#   'tempo': 145.038,
#   'type': 'audio_features',
#   'id': '7dt6x5M1jzdTEt8oCbisTK',
#   'uri': 'spotify:track:7dt6x5M1jzdTEt8oCbisTK',
#   'track_href': 'https://api.spotify.com/v1/tracks/7dt6x5M1jzdTEt8oCbisTK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7dt6x5M1jzdTEt8oCbisTK',
#   'duration_ms': 231267,
#   'time_signature': 4},
#  {'danceability': 0.704,
#   'energy': 0.611,
#   'key': 2,
#   'loudness': -6.112,
#   'mode': 1,
#   'speechiness': 0.0409,
#   'acousticness': 0.217,
#   'instrumentalness': 0,
#   'liveness': 0.0812,
#   'valence': 0.22,
#   'tempo': 100.0,
#   'type': 'audio_features',
#   'id': '2FY7b99s15jUprqC0M5NCT',
#   'uri': 'spotify:track:2FY7b99s15jUprqC0M5NCT',
#   'track_href': 'https://api.spotify.com/v1/tracks/2FY7b99s15jUprqC0M5NCT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2FY7b99s15jUprqC0M5NCT',
#   'duration_ms': 189467,
#   'time_signature': 4},
#  {'danceability': 0.662,
#   'energy': 0.714,
#   'key': 5,
#   'loudness': -5.68,
#   'mode': 0,
#   'speechiness': 0.121,
#   'acousticness': 0.312,
#   'instrumentalness': 0,
#   'liveness': 0.179,
#   'valence': 0.464,
#   'tempo': 147.997,
#   'type': 'audio_features',
#   'id': '52okn5MNA47tk87PeZJLEL',
#   'uri': 'spotify:track:52okn5MNA47tk87PeZJLEL',
#   'track_href': 'https://api.spotify.com/v1/tracks/52okn5MNA47tk87PeZJLEL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/52okn5MNA47tk87PeZJLEL',
#   'duration_ms': 212120,
#   'time_signature': 4},
#  {'danceability': 0.697,
#   'energy': 0.683,
#   'key': 1,
#   'loudness': -2.881,
#   'mode': 0,
#   'speechiness': 0.117,
#   'acousticness': 0.0372,
#   'instrumentalness': 0,
#   'liveness': 0.137,
#   'valence': 0.603,
#   'tempo': 96.133,
#   'type': 'audio_features',
#   'id': '2BgEsaKNfHUdlh97KmvFyo',
#   'uri': 'spotify:track:2BgEsaKNfHUdlh97KmvFyo',
#   'track_href': 'https://api.spotify.com/v1/tracks/2BgEsaKNfHUdlh97KmvFyo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2BgEsaKNfHUdlh97KmvFyo',
#   'duration_ms': 186987,
#   'time_signature': 4},
#  {'danceability': 0.52,
#   'energy': 0.761,
#   'key': 4,
#   'loudness': -3.093,
#   'mode': 1,
#   'speechiness': 0.0853,
#   'acousticness': 0.256,
#   'instrumentalness': 4.96e-06,
#   'liveness': 0.17,
#   'valence': 0.286,
#   'tempo': 141.971,
#   'type': 'audio_features',
#   'id': '7vGuf3Y35N4wmASOKLUVVU',
#   'uri': 'spotify:track:7vGuf3Y35N4wmASOKLUVVU',
#   'track_href': 'https://api.spotify.com/v1/tracks/7vGuf3Y35N4wmASOKLUVVU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7vGuf3Y35N4wmASOKLUVVU',
#   'duration_ms': 180823,
#   'time_signature': 4},
#  {'danceability': 0.74,
#   'energy': 0.613,
#   'key': 8,
#   'loudness': -4.88,
#   'mode': 1,
#   'speechiness': 0.145,
#   'acousticness': 0.258,
#   'instrumentalness': 0.00372,
#   'liveness': 0.123,
#   'valence': 0.473,
#   'tempo': 75.023,
#   'type': 'audio_features',
#   'id': '3ee8Jmje8o58CHK66QrVC2',
#   'uri': 'spotify:track:3ee8Jmje8o58CHK66QrVC2',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ee8Jmje8o58CHK66QrVC2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ee8Jmje8o58CHK66QrVC2',
#   'duration_ms': 166606,
#   'time_signature': 4},
#  {'danceability': 0.724,
#   'energy': 0.804,
#   'key': 11,
#   'loudness': -4.614,
#   'mode': 0,
#   'speechiness': 0.0448,
#   'acousticness': 0.124,
#   'instrumentalness': 0,
#   'liveness': 0.204,
#   'valence': 0.306,
#   'tempo': 124.987,
#   'type': 'audio_features',
#   'id': '0tBbt8CrmxbjRP0pueQkyU',
#   'uri': 'spotify:track:0tBbt8CrmxbjRP0pueQkyU',
#   'track_href': 'https://api.spotify.com/v1/tracks/0tBbt8CrmxbjRP0pueQkyU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0tBbt8CrmxbjRP0pueQkyU',
#   'duration_ms': 197993,
#   'time_signature': 4},
#  {'danceability': 0.836,
#   'energy': 0.544,
#   'key': 7,
#   'loudness': -5.975,
#   'mode': 1,
#   'speechiness': 0.0943,
#   'acousticness': 0.0403,
#   'instrumentalness': 0,
#   'liveness': 0.0824,
#   'valence': 0.51,
#   'tempo': 97.028,
#   'type': 'audio_features',
#   'id': '76cy1WJvNGJTj78UqeA5zr',
#   'uri': 'spotify:track:76cy1WJvNGJTj78UqeA5zr',
#   'track_href': 'https://api.spotify.com/v1/tracks/76cy1WJvNGJTj78UqeA5zr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/76cy1WJvNGJTj78UqeA5zr',
#   'duration_ms': 217947,
#   'time_signature': 4},
#  {'danceability': 0.729,
#   'energy': 0.625,
#   'key': 4,
#   'loudness': -5.266,
#   'mode': 1,
#   'speechiness': 0.0315,
#   'acousticness': 0.194,
#   'instrumentalness': 0.00986,
#   'liveness': 0.248,
#   'valence': 0.261,
#   'tempo': 146.034,
#   'type': 'audio_features',
#   'id': '1xzBco0xcoJEDXktl7Jxrr',
#   'uri': 'spotify:track:1xzBco0xcoJEDXktl7Jxrr',
#   'track_href': 'https://api.spotify.com/v1/tracks/1xzBco0xcoJEDXktl7Jxrr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1xzBco0xcoJEDXktl7Jxrr',
#   'duration_ms': 183907,
#   'time_signature': 4},
#  {'danceability': 0.553,
#   'energy': 0.586,
#   'key': 11,
#   'loudness': -6.319,
#   'mode': 1,
#   'speechiness': 0.0362,
#   'acousticness': 0.697,
#   'instrumentalness': 0,
#   'liveness': 0.0813,
#   'valence': 0.443,
#   'tempo': 126.684,
#   'type': 'audio_features',
#   'id': '3EPXxR3ImUwfayaurPi3cm',
#   'uri': 'spotify:track:3EPXxR3ImUwfayaurPi3cm',
#   'track_href': 'https://api.spotify.com/v1/tracks/3EPXxR3ImUwfayaurPi3cm',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3EPXxR3ImUwfayaurPi3cm',
#   'duration_ms': 196373,
#   'time_signature': 4},
#  {'danceability': 0.912,
#   'energy': 0.412,
#   'key': 7,
#   'loudness': -8.074,
#   'mode': 1,
#   'speechiness': 0.123,
#   'acousticness': 0.0165,
#   'instrumentalness': 0.0126,
#   'liveness': 0.104,
#   'valence': 0.423,
#   'tempo': 154.983,
#   'type': 'audio_features',
#   'id': '0TlLq3lA83rQOYtrqBqSct',
#   'uri': 'spotify:track:0TlLq3lA83rQOYtrqBqSct',
#   'track_href': 'https://api.spotify.com/v1/tracks/0TlLq3lA83rQOYtrqBqSct',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0TlLq3lA83rQOYtrqBqSct',
#   'duration_ms': 238614,
#   'time_signature': 4},
#  {'danceability': 0.694,
#   'energy': 0.77,
#   'key': 6,
#   'loudness': -5.335,
#   'mode': 1,
#   'speechiness': 0.149,
#   'acousticness': 0.176,
#   'instrumentalness': 1.1e-05,
#   'liveness': 0.118,
#   'valence': 0.163,
#   'tempo': 125.905,
#   'type': 'audio_features',
#   'id': '0E9ZjEAyAwOXZ7wJC0PD33',
#   'uri': 'spotify:track:0E9ZjEAyAwOXZ7wJC0PD33',
#   'track_href': 'https://api.spotify.com/v1/tracks/0E9ZjEAyAwOXZ7wJC0PD33',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0E9ZjEAyAwOXZ7wJC0PD33',
#   'duration_ms': 184560,
#   'time_signature': 4},
#  {'danceability': 0.669,
#   'energy': 0.308,
#   'key': 11,
#   'loudness': -10.068,
#   'mode': 1,
#   'speechiness': 0.029,
#   'acousticness': 0.883,
#   'instrumentalness': 0,
#   'liveness': 0.0984,
#   'valence': 0.52,
#   'tempo': 64.934,
#   'type': 'audio_features',
#   'id': '7AFASza1mXqntmGtbxXprO',
#   'uri': 'spotify:track:7AFASza1mXqntmGtbxXprO',
#   'track_href': 'https://api.spotify.com/v1/tracks/7AFASza1mXqntmGtbxXprO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7AFASza1mXqntmGtbxXprO',
#   'duration_ms': 121887,
#   'time_signature': 4},
#  {'danceability': 0.602,
#   'energy': 0.658,
#   'key': 1,
#   'loudness': -5.934,
#   'mode': 1,
#   'speechiness': 0.0558,
#   'acousticness': 0.0233,
#   'instrumentalness': 6e-05,
#   'liveness': 0.237,
#   'valence': 0.268,
#   'tempo': 145.031,
#   'type': 'audio_features',
#   'id': '5OCJzvD7sykQEKHH7qAC3C',
#   'uri': 'spotify:track:5OCJzvD7sykQEKHH7qAC3C',
#   'track_href': 'https://api.spotify.com/v1/tracks/5OCJzvD7sykQEKHH7qAC3C',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5OCJzvD7sykQEKHH7qAC3C',
#   'duration_ms': 197547,
#   'time_signature': 4},
#  {'danceability': 0.75,
#   'energy': 0.56,
#   'key': 8,
#   'loudness': -8.094,
#   'mode': 1,
#   'speechiness': 0.105,
#   'acousticness': 0.546,
#   'instrumentalness': 0,
#   'liveness': 0.111,
#   'valence': 0.459,
#   'tempo': 140.06,
#   'type': 'audio_features',
#   'id': '3swc6WTsr7rl9DqQKQA55C',
#   'uri': 'spotify:track:3swc6WTsr7rl9DqQKQA55C',
#   'track_href': 'https://api.spotify.com/v1/tracks/3swc6WTsr7rl9DqQKQA55C',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3swc6WTsr7rl9DqQKQA55C',
#   'duration_ms': 221440,
#   'time_signature': 4},
#  {'danceability': 0.585,
#   'energy': 0.909,
#   'key': 8,
#   'loudness': -6.474,
#   'mode': 1,
#   'speechiness': 0.0707,
#   'acousticness': 0.0891,
#   'instrumentalness': 9.7e-05,
#   'liveness': 0.119,
#   'valence': 0.758,
#   'tempo': 93.372,
#   'type': 'audio_features',
#   'id': '3CA9pLiwRIGtUBiMjbZmRw',
#   'uri': 'spotify:track:3CA9pLiwRIGtUBiMjbZmRw',
#   'track_href': 'https://api.spotify.com/v1/tracks/3CA9pLiwRIGtUBiMjbZmRw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3CA9pLiwRIGtUBiMjbZmRw',
#   'duration_ms': 210747,
#   'time_signature': 4},
#  {'danceability': 0.673,
#   'energy': 0.735,
#   'key': 5,
#   'loudness': -4.733,
#   'mode': 1,
#   'speechiness': 0.0457,
#   'acousticness': 0.286,
#   'instrumentalness': 0,
#   'liveness': 0.242,
#   'valence': 0.754,
#   'tempo': 115.744,
#   'type': 'audio_features',
#   'id': '4ofwffwvvnbSkrMSCKQDaC',
#   'uri': 'spotify:track:4ofwffwvvnbSkrMSCKQDaC',
#   'track_href': 'https://api.spotify.com/v1/tracks/4ofwffwvvnbSkrMSCKQDaC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4ofwffwvvnbSkrMSCKQDaC',
#   'duration_ms': 201287,
#   'time_signature': 4},
#  {'danceability': 0.681,
#   'energy': 0.788,
#   'key': 1,
#   'loudness': -4.323,
#   'mode': 1,
#   'speechiness': 0.0785,
#   'acousticness': 0.0482,
#   'instrumentalness': 0,
#   'liveness': 0.0753,
#   'valence': 0.839,
#   'tempo': 170.019,
#   'type': 'audio_features',
#   'id': '1j6xOGusnyXq3l6IryKF3G',
#   'uri': 'spotify:track:1j6xOGusnyXq3l6IryKF3G',
#   'track_href': 'https://api.spotify.com/v1/tracks/1j6xOGusnyXq3l6IryKF3G',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1j6xOGusnyXq3l6IryKF3G',
#   'duration_ms': 220117,
#   'time_signature': 4},
#  {'danceability': 0.589,
#   'energy': 0.731,
#   'key': 2,
#   'loudness': -6.343,
#   'mode': 1,
#   'speechiness': 0.0868,
#   'acousticness': 0.0534,
#   'instrumentalness': 0,
#   'liveness': 0.308,
#   'valence': 0.191,
#   'tempo': 87.908,
#   'type': 'audio_features',
#   'id': '5k38wzpLb15YgncyWdTZE4',
#   'uri': 'spotify:track:5k38wzpLb15YgncyWdTZE4',
#   'track_href': 'https://api.spotify.com/v1/tracks/5k38wzpLb15YgncyWdTZE4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5k38wzpLb15YgncyWdTZE4',
#   'duration_ms': 268867,
#   'time_signature': 4},
#  {'danceability': 0.842,
#   'energy': 0.801,
#   'key': 8,
#   'loudness': -4.167,
#   'mode': 0,
#   'speechiness': 0.228,
#   'acousticness': 0.157,
#   'instrumentalness': 4.82e-06,
#   'liveness': 0.0642,
#   'valence': 0.617,
#   'tempo': 95.881,
#   'type': 'audio_features',
#   'id': '4w8niZpiMy6qz1mntFA5uM',
#   'uri': 'spotify:track:4w8niZpiMy6qz1mntFA5uM',
#   'track_href': 'https://api.spotify.com/v1/tracks/4w8niZpiMy6qz1mntFA5uM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4w8niZpiMy6qz1mntFA5uM',
#   'duration_ms': 212500,
#   'time_signature': 4},
#  {'danceability': 0.903,
#   'energy': 0.675,
#   'key': 11,
#   'loudness': -3.445,
#   'mode': 0,
#   'speechiness': 0.214,
#   'acousticness': 0.542,
#   'instrumentalness': 1.28e-05,
#   'liveness': 0.0595,
#   'valence': 0.442,
#   'tempo': 96.507,
#   'type': 'audio_features',
#   'id': '3V8UKqhEK5zBkBb6d6ub8i',
#   'uri': 'spotify:track:3V8UKqhEK5zBkBb6d6ub8i',
#   'track_href': 'https://api.spotify.com/v1/tracks/3V8UKqhEK5zBkBb6d6ub8i',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3V8UKqhEK5zBkBb6d6ub8i',
#   'duration_ms': 417920,
#   'time_signature': 4},
#  {'danceability': 0.618,
#   'energy': 0.837,
#   'key': 1,
#   'loudness': -5.338,
#   'mode': 1,
#   'speechiness': 0.0304,
#   'acousticness': 0.000254,
#   'instrumentalness': 0.000378,
#   'liveness': 0.0618,
#   'valence': 0.526,
#   'tempo': 121.227,
#   'type': 'audio_features',
#   'id': '3TgMcrV32NUKjEG2ujn9eh',
#   'uri': 'spotify:track:3TgMcrV32NUKjEG2ujn9eh',
#   'track_href': 'https://api.spotify.com/v1/tracks/3TgMcrV32NUKjEG2ujn9eh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3TgMcrV32NUKjEG2ujn9eh',
#   'duration_ms': 248336,
#   'time_signature': 4},
#  {'danceability': 0.56,
#   'energy': 0.68,
#   'key': 6,
#   'loudness': -7.648,
#   'mode': 0,
#   'speechiness': 0.321,
#   'acousticness': 0.555,
#   'instrumentalness': 0,
#   'liveness': 0.116,
#   'valence': 0.319,
#   'tempo': 89.391,
#   'type': 'audio_features',
#   'id': '0d2iYfpKoM0QCKvcLCkBao',
#   'uri': 'spotify:track:0d2iYfpKoM0QCKvcLCkBao',
#   'track_href': 'https://api.spotify.com/v1/tracks/0d2iYfpKoM0QCKvcLCkBao',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0d2iYfpKoM0QCKvcLCkBao',
#   'duration_ms': 173800,
#   'time_signature': 4},
#  {'danceability': 0.664,
#   'energy': 0.708,
#   'key': 8,
#   'loudness': -4.154,
#   'mode': 1,
#   'speechiness': 0.0474,
#   'acousticness': 0.0337,
#   'instrumentalness': 0,
#   'liveness': 0.0841,
#   'valence': 0.742,
#   'tempo': 103.07,
#   'type': 'audio_features',
#   'id': '5Gu0PDLN4YJeW75PpBSg9p',
#   'uri': 'spotify:track:5Gu0PDLN4YJeW75PpBSg9p',
#   'track_href': 'https://api.spotify.com/v1/tracks/5Gu0PDLN4YJeW75PpBSg9p',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5Gu0PDLN4YJeW75PpBSg9p',
#   'duration_ms': 174800,
#   'time_signature': 4},
#  {'danceability': 0.6,
#   'energy': 0.688,
#   'key': 5,
#   'loudness': -8.339,
#   'mode': 0,
#   'speechiness': 0.201,
#   'acousticness': 0.159,
#   'instrumentalness': 1.29e-05,
#   'liveness': 0.409,
#   'valence': 0.0793,
#   'tempo': 99.977,
#   'type': 'audio_features',
#   'id': '63SevszngYpZOwf63o61K4',
#   'uri': 'spotify:track:63SevszngYpZOwf63o61K4',
#   'track_href': 'https://api.spotify.com/v1/tracks/63SevszngYpZOwf63o61K4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/63SevszngYpZOwf63o61K4',
#   'duration_ms': 156600,
#   'time_signature': 4},
#  {'danceability': 0.754,
#   'energy': 0.805,
#   'key': 6,
#   'loudness': -4.249,
#   'mode': 1,
#   'speechiness': 0.0752,
#   'acousticness': 0.315,
#   'instrumentalness': 0,
#   'liveness': 0.203,
#   'valence': 0.555,
#   'tempo': 93.982,
#   'type': 'audio_features',
#   'id': '48zFZh27QU5qsrBjn4C2FA',
#   'uri': 'spotify:track:48zFZh27QU5qsrBjn4C2FA',
#   'track_href': 'https://api.spotify.com/v1/tracks/48zFZh27QU5qsrBjn4C2FA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/48zFZh27QU5qsrBjn4C2FA',
#   'duration_ms': 176133,
#   'time_signature': 4},
#  {'danceability': 0.817,
#   'energy': 0.816,
#   'key': 2,
#   'loudness': -5.402,
#   'mode': 1,
#   'speechiness': 0.269,
#   'acousticness': 0.00263,
#   'instrumentalness': 0,
#   'liveness': 0.159,
#   'valence': 0.508,
#   'tempo': 181.982,
#   'type': 'audio_features',
#   'id': '2UVbBKQOdFAekPTRsnkzcf',
#   'uri': 'spotify:track:2UVbBKQOdFAekPTRsnkzcf',
#   'track_href': 'https://api.spotify.com/v1/tracks/2UVbBKQOdFAekPTRsnkzcf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2UVbBKQOdFAekPTRsnkzcf',
#   'duration_ms': 190288,
#   'time_signature': 4},
#  {'danceability': 0.752,
#   'energy': 0.764,
#   'key': 1,
#   'loudness': -4.399,
#   'mode': 1,
#   'speechiness': 0.038,
#   'acousticness': 0.0476,
#   'instrumentalness': 9.44e-05,
#   'liveness': 0.0543,
#   'valence': 0.582,
#   'tempo': 121.958,
#   'type': 'audio_features',
#   'id': '21RzyxY3EFaxVy6K4RqaU9',
#   'uri': 'spotify:track:21RzyxY3EFaxVy6K4RqaU9',
#   'track_href': 'https://api.spotify.com/v1/tracks/21RzyxY3EFaxVy6K4RqaU9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/21RzyxY3EFaxVy6K4RqaU9',
#   'duration_ms': 163216,
#   'time_signature': 4},
#  {'danceability': 0.835,
#   'energy': 0.626,
#   'key': 1,
#   'loudness': -5.833,
#   'mode': 1,
#   'speechiness': 0.125,
#   'acousticness': 0.0589,
#   'instrumentalness': 6e-05,
#   'liveness': 0.396,
#   'valence': 0.35,
#   'tempo': 91.03,
#   'type': 'audio_features',
#   'id': '2G7V7zsVDxg1yRsu7Ew9RJ',
#   'uri': 'spotify:track:2G7V7zsVDxg1yRsu7Ew9RJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/2G7V7zsVDxg1yRsu7Ew9RJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2G7V7zsVDxg1yRsu7Ew9RJ',
#   'duration_ms': 217925,
#   'time_signature': 4},
#  {'danceability': 0.71,
#   'energy': 0.789,
#   'key': 4,
#   'loudness': -3.874,
#   'mode': 1,
#   'speechiness': 0.0722,
#   'acousticness': 0.0161,
#   'instrumentalness': 2.77e-06,
#   'liveness': 0.451,
#   'valence': 0.717,
#   'tempo': 142.929,
#   'type': 'audio_features',
#   'id': '7uzmGiiJyRfuViKKK3lVmR',
#   'uri': 'spotify:track:7uzmGiiJyRfuViKKK3lVmR',
#   'track_href': 'https://api.spotify.com/v1/tracks/7uzmGiiJyRfuViKKK3lVmR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7uzmGiiJyRfuViKKK3lVmR',
#   'duration_ms': 131064,
#   'time_signature': 4},
#  {'danceability': 0.594,
#   'energy': 0.749,
#   'key': 9,
#   'loudness': -5.298,
#   'mode': 0,
#   'speechiness': 0.056,
#   'acousticness': 0.0338,
#   'instrumentalness': 0.00106,
#   'liveness': 0.3,
#   'valence': 0.694,
#   'tempo': 179.968,
#   'type': 'audio_features',
#   'id': '5YUyW9opqNsMSEzzecZih1',
#   'uri': 'spotify:track:5YUyW9opqNsMSEzzecZih1',
#   'track_href': 'https://api.spotify.com/v1/tracks/5YUyW9opqNsMSEzzecZih1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5YUyW9opqNsMSEzzecZih1',
#   'duration_ms': 172854,
#   'time_signature': 4},
#  {'danceability': 0.643,
#   'energy': 0.783,
#   'key': 10,
#   'loudness': -6.458,
#   'mode': 1,
#   'speechiness': 0.0856,
#   'acousticness': 0.047,
#   'instrumentalness': 0,
#   'liveness': 0.083,
#   'valence': 0.579,
#   'tempo': 154.084,
#   'type': 'audio_features',
#   'id': '7iDa6hUg2VgEL1o1HjmfBn',
#   'uri': 'spotify:track:7iDa6hUg2VgEL1o1HjmfBn',
#   'track_href': 'https://api.spotify.com/v1/tracks/7iDa6hUg2VgEL1o1HjmfBn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7iDa6hUg2VgEL1o1HjmfBn',
#   'duration_ms': 163870,
#   'time_signature': 4},
#  {'danceability': 0.622,
#   'energy': 0.712,
#   'key': 5,
#   'loudness': -7.321,
#   'mode': 1,
#   'speechiness': 0.066,
#   'acousticness': 0.0573,
#   'instrumentalness': 0,
#   'liveness': 0.13,
#   'valence': 0.487,
#   'tempo': 140.025,
#   'type': 'audio_features',
#   'id': '2QZ7WLBE8h2y1Y5Fb8RYbH',
#   'uri': 'spotify:track:2QZ7WLBE8h2y1Y5Fb8RYbH',
#   'track_href': 'https://api.spotify.com/v1/tracks/2QZ7WLBE8h2y1Y5Fb8RYbH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2QZ7WLBE8h2y1Y5Fb8RYbH',
#   'duration_ms': 211360,
#   'time_signature': 4},
#  {'danceability': 0.477,
#   'energy': 0.61,
#   'key': 11,
#   'loudness': -5.628,
#   'mode': 0,
#   'speechiness': 0.144,
#   'acousticness': 0.225,
#   'instrumentalness': 0,
#   'liveness': 0.107,
#   'valence': 0.358,
#   'tempo': 79.882,
#   'type': 'audio_features',
#   'id': '6CTWathupIiDs7U4InHnDA',
#   'uri': 'spotify:track:6CTWathupIiDs7U4InHnDA',
#   'track_href': 'https://api.spotify.com/v1/tracks/6CTWathupIiDs7U4InHnDA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6CTWathupIiDs7U4InHnDA',
#   'duration_ms': 213993,
#   'time_signature': 4},
#  {'danceability': 0.675,
#   'energy': 0.751,
#   'key': 0,
#   'loudness': -3.539,
#   'mode': 1,
#   'speechiness': 0.0296,
#   'acousticness': 0.0604,
#   'instrumentalness': 0,
#   'liveness': 0.0893,
#   'valence': 0.612,
#   'tempo': 118.384,
#   'type': 'audio_features',
#   'id': '7y9iMe8SOB6z3NoHE2OfXl',
#   'uri': 'spotify:track:7y9iMe8SOB6z3NoHE2OfXl',
#   'track_href': 'https://api.spotify.com/v1/tracks/7y9iMe8SOB6z3NoHE2OfXl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7y9iMe8SOB6z3NoHE2OfXl',
#   'duration_ms': 181279,
#   'time_signature': 4},
#  {'danceability': 0.704,
#   'energy': 0.859,
#   'key': 5,
#   'loudness': -4.877,
#   'mode': 0,
#   'speechiness': 0.0996,
#   'acousticness': 0.0185,
#   'instrumentalness': 0,
#   'liveness': 0.0215,
#   'valence': 0.926,
#   'tempo': 105.115,
#   'type': 'audio_features',
#   'id': '3Vo4wInECJQuz9BIBMOu8i',
#   'uri': 'spotify:track:3Vo4wInECJQuz9BIBMOu8i',
#   'track_href': 'https://api.spotify.com/v1/tracks/3Vo4wInECJQuz9BIBMOu8i',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Vo4wInECJQuz9BIBMOu8i',
#   'duration_ms': 217289,
#   'time_signature': 4},
#  {'danceability': 0.907,
#   'energy': 0.633,
#   'key': 2,
#   'loudness': -5.145,
#   'mode': 1,
#   'speechiness': 0.184,
#   'acousticness': 0.0876,
#   'instrumentalness': 2.6e-06,
#   'liveness': 0.106,
#   'valence': 0.395,
#   'tempo': 145.914,
#   'type': 'audio_features',
#   'id': '6n4U3TlzUGhdSFbUUhTvLP',
#   'uri': 'spotify:track:6n4U3TlzUGhdSFbUUhTvLP',
#   'track_href': 'https://api.spotify.com/v1/tracks/6n4U3TlzUGhdSFbUUhTvLP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6n4U3TlzUGhdSFbUUhTvLP',
#   'duration_ms': 276147,
#   'time_signature': 4},
#  {'danceability': 0.918,
#   'energy': 0.58,
#   'key': 10,
#   'loudness': -7.501,
#   'mode': 1,
#   'speechiness': 0.322,
#   'acousticness': 0.00108,
#   'instrumentalness': 6.12e-05,
#   'liveness': 0.106,
#   'valence': 0.611,
#   'tempo': 139.977,
#   'type': 'audio_features',
#   'id': '6HJ34Zyw6bg8yGm28AxLXf',
#   'uri': 'spotify:track:6HJ34Zyw6bg8yGm28AxLXf',
#   'track_href': 'https://api.spotify.com/v1/tracks/6HJ34Zyw6bg8yGm28AxLXf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6HJ34Zyw6bg8yGm28AxLXf',
#   'duration_ms': 181415,
#   'time_signature': 4},
#  {'danceability': 0.708,
#   'energy': 0.648,
#   'key': 6,
#   'loudness': -5.626,
#   'mode': 1,
#   'speechiness': 0.0449,
#   'acousticness': 0.0956,
#   'instrumentalness': 0,
#   'liveness': 0.134,
#   'valence': 0.338,
#   'tempo': 143.955,
#   'type': 'audio_features',
#   'id': '45Egmo7icyopuzJN0oMEdk',
#   'uri': 'spotify:track:45Egmo7icyopuzJN0oMEdk',
#   'track_href': 'https://api.spotify.com/v1/tracks/45Egmo7icyopuzJN0oMEdk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/45Egmo7icyopuzJN0oMEdk',
#   'duration_ms': 201707,
#   'time_signature': 4},
#  {'danceability': 0.684,
#   'energy': 0.619,
#   'key': 10,
#   'loudness': -7.005,
#   'mode': 1,
#   'speechiness': 0.0386,
#   'acousticness': 0.0716,
#   'instrumentalness': 0,
#   'liveness': 0.122,
#   'valence': 0.284,
#   'tempo': 125.046,
#   'type': 'audio_features',
#   'id': '630sXRhIcfwr2e4RdNtjKN',
#   'uri': 'spotify:track:630sXRhIcfwr2e4RdNtjKN',
#   'track_href': 'https://api.spotify.com/v1/tracks/630sXRhIcfwr2e4RdNtjKN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/630sXRhIcfwr2e4RdNtjKN',
#   'duration_ms': 217440,
#   'time_signature': 4},
#  {'danceability': 0.845,
#   'energy': 0.561,
#   'key': 1,
#   'loudness': -5.253,
#   'mode': 0,
#   'speechiness': 0.0778,
#   'acousticness': 0.211,
#   'instrumentalness': 3.49e-06,
#   'liveness': 0.0383,
#   'valence': 0.811,
#   'tempo': 109.974,
#   'type': 'audio_features',
#   'id': '6wmAHw1szh5RCKSRjiXhPe',
#   'uri': 'spotify:track:6wmAHw1szh5RCKSRjiXhPe',
#   'track_href': 'https://api.spotify.com/v1/tracks/6wmAHw1szh5RCKSRjiXhPe',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6wmAHw1szh5RCKSRjiXhPe',
#   'duration_ms': 200853,
#   'time_signature': 4},
#  {'danceability': 0.653,
#   'energy': 0.809,
#   'key': 0,
#   'loudness': -4.057,
#   'mode': 1,
#   'speechiness': 0.0474,
#   'acousticness': 0.194,
#   'instrumentalness': 0,
#   'liveness': 0.165,
#   'valence': 0.55,
#   'tempo': 92.213,
#   'type': 'audio_features',
#   'id': '5CLGzJsGqhCEECcpnFQA8x',
#   'uri': 'spotify:track:5CLGzJsGqhCEECcpnFQA8x',
#   'track_href': 'https://api.spotify.com/v1/tracks/5CLGzJsGqhCEECcpnFQA8x',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5CLGzJsGqhCEECcpnFQA8x',
#   'duration_ms': 210773,
#   'time_signature': 4},
#  {'danceability': 0.926,
#   'energy': 0.703,
#   'key': 11,
#   'loudness': -6.337,
#   'mode': 0,
#   'speechiness': 0.103,
#   'acousticness': 0.0659,
#   'instrumentalness': 0,
#   'liveness': 0.231,
#   'valence': 0.485,
#   'tempo': 125.022,
#   'type': 'audio_features',
#   'id': '6KBYefIoo7KydImq1uUQlL',
#   'uri': 'spotify:track:6KBYefIoo7KydImq1uUQlL',
#   'track_href': 'https://api.spotify.com/v1/tracks/6KBYefIoo7KydImq1uUQlL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6KBYefIoo7KydImq1uUQlL',
#   'duration_ms': 223713,
#   'time_signature': 4},
#  {'danceability': 0.748,
#   'energy': 0.749,
#   'key': 8,
#   'loudness': -5.916,
#   'mode': 0,
#   'speechiness': 0.516,
#   'acousticness': 0.142,
#   'instrumentalness': 0,
#   'liveness': 0.0713,
#   'valence': 0.659,
#   'tempo': 90.09,
#   'type': 'audio_features',
#   'id': '1cS0TgbR263ey9jn0MwD2s',
#   'uri': 'spotify:track:1cS0TgbR263ey9jn0MwD2s',
#   'track_href': 'https://api.spotify.com/v1/tracks/1cS0TgbR263ey9jn0MwD2s',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1cS0TgbR263ey9jn0MwD2s',
#   'duration_ms': 221013,
#   'time_signature': 4},
#  {'danceability': 0.575,
#   'energy': 0.571,
#   'key': 1,
#   'loudness': -7.906,
#   'mode': 1,
#   'speechiness': 0.0439,
#   'acousticness': 0.0558,
#   'instrumentalness': 0,
#   'liveness': 0.0912,
#   'valence': 0.449,
#   'tempo': 105.049,
#   'type': 'audio_features',
#   'id': '4NBTZtAt1F13VvlSKe6KTl',
#   'uri': 'spotify:track:4NBTZtAt1F13VvlSKe6KTl',
#   'track_href': 'https://api.spotify.com/v1/tracks/4NBTZtAt1F13VvlSKe6KTl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4NBTZtAt1F13VvlSKe6KTl',
#   'duration_ms': 197947,
#   'time_signature': 4},
#  {'danceability': 0.687,
#   'energy': 0.785,
#   'key': 1,
#   'loudness': -4.65,
#   'mode': 1,
#   'speechiness': 0.0333,
#   'acousticness': 0.327,
#   'instrumentalness': 0,
#   'liveness': 0.203,
#   'valence': 0.655,
#   'tempo': 106.046,
#   'type': 'audio_features',
#   'id': '5ZSl6gDoV6bPPxzmLeneV9',
#   'uri': 'spotify:track:5ZSl6gDoV6bPPxzmLeneV9',
#   'track_href': 'https://api.spotify.com/v1/tracks/5ZSl6gDoV6bPPxzmLeneV9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5ZSl6gDoV6bPPxzmLeneV9',
#   'duration_ms': 194408,
#   'time_signature': 4},
#  {'danceability': 0.586,
#   'energy': 0.624,
#   'key': 5,
#   'loudness': -5.946,
#   'mode': 1,
#   'speechiness': 0.113,
#   'acousticness': 0.0153,
#   'instrumentalness': 1.78e-06,
#   'liveness': 0.133,
#   'valence': 0.267,
#   'tempo': 68.976,
#   'type': 'audio_features',
#   'id': '6lOWoTqVnAWXchddtTH31W',
#   'uri': 'spotify:track:6lOWoTqVnAWXchddtTH31W',
#   'track_href': 'https://api.spotify.com/v1/tracks/6lOWoTqVnAWXchddtTH31W',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6lOWoTqVnAWXchddtTH31W',
#   'duration_ms': 185863,
#   'time_signature': 4},
#  {'danceability': 0.637,
#   'energy': 0.713,
#   'key': 0,
#   'loudness': -4.333,
#   'mode': 1,
#   'speechiness': 0.0747,
#   'acousticness': 0.181,
#   'instrumentalness': 0.000637,
#   'liveness': 0.137,
#   'valence': 0.243,
#   'tempo': 129.923,
#   'type': 'audio_features',
#   'id': '4eWQlBRaTjPPUlzacqEeoQ',
#   'uri': 'spotify:track:4eWQlBRaTjPPUlzacqEeoQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/4eWQlBRaTjPPUlzacqEeoQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4eWQlBRaTjPPUlzacqEeoQ',
#   'duration_ms': 226973,
#   'time_signature': 4},
#  {'danceability': 0.489,
#   'energy': 0.581,
#   'key': 11,
#   'loudness': -5.731,
#   'mode': 1,
#   'speechiness': 0.0281,
#   'acousticness': 0.0312,
#   'instrumentalness': 0,
#   'liveness': 0.132,
#   'valence': 0.494,
#   'tempo': 86.016,
#   'type': 'audio_features',
#   'id': '42fw0rxRO2xbesF6mJfd4Y',
#   'uri': 'spotify:track:42fw0rxRO2xbesF6mJfd4Y',
#   'track_href': 'https://api.spotify.com/v1/tracks/42fw0rxRO2xbesF6mJfd4Y',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/42fw0rxRO2xbesF6mJfd4Y',
#   'duration_ms': 196747,
#   'time_signature': 4},
#  {'danceability': 0.737,
#   'energy': 0.408,
#   'key': 5,
#   'loudness': -7.941,
#   'mode': 1,
#   'speechiness': 0.104,
#   'acousticness': 0.802,
#   'instrumentalness': 0,
#   'liveness': 0.171,
#   'valence': 0.374,
#   'tempo': 127.918,
#   'type': 'audio_features',
#   'id': '6I0KEvFfWszVJiCy5hum4V',
#   'uri': 'spotify:track:6I0KEvFfWszVJiCy5hum4V',
#   'track_href': 'https://api.spotify.com/v1/tracks/6I0KEvFfWszVJiCy5hum4V',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6I0KEvFfWszVJiCy5hum4V',
#   'duration_ms': 190348,
#   'time_signature': 4},
#  {'danceability': 0.375,
#   'energy': 0.574,
#   'key': 7,
#   'loudness': -5.305,
#   'mode': 1,
#   'speechiness': 0.0315,
#   'acousticness': 0.143,
#   'instrumentalness': 0,
#   'liveness': 0.11,
#   'valence': 0.406,
#   'tempo': 132.025,
#   'type': 'audio_features',
#   'id': '6EGAfJaLUFzhS4zRBIEQ2J',
#   'uri': 'spotify:track:6EGAfJaLUFzhS4zRBIEQ2J',
#   'track_href': 'https://api.spotify.com/v1/tracks/6EGAfJaLUFzhS4zRBIEQ2J',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6EGAfJaLUFzhS4zRBIEQ2J',
#   'duration_ms': 196800,
#   'time_signature': 3},
#  {'danceability': 0.362,
#   'energy': 0.882,
#   'key': 3,
#   'loudness': -3.717,
#   'mode': 1,
#   'speechiness': 0.0973,
#   'acousticness': 0.0791,
#   'instrumentalness': 0,
#   'liveness': 0.15,
#   'valence': 0.864,
#   'tempo': 199.811,
#   'type': 'audio_features',
#   'id': '4L9Ds4mpD3SuYoWwFUlv16',
#   'uri': 'spotify:track:4L9Ds4mpD3SuYoWwFUlv16',
#   'track_href': 'https://api.spotify.com/v1/tracks/4L9Ds4mpD3SuYoWwFUlv16',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4L9Ds4mpD3SuYoWwFUlv16',
#   'duration_ms': 185200,
#   'time_signature': 4},
#  {'danceability': 0.777,
#   'energy': 0.782,
#   'key': 0,
#   'loudness': -4.435,
#   'mode': 0,
#   'speechiness': 0.0907,
#   'acousticness': 0.0505,
#   'instrumentalness': 0,
#   'liveness': 0.64,
#   'valence': 0.773,
#   'tempo': 94.023,
#   'type': 'audio_features',
#   'id': '4ggiDYAkJ7Yk8d5xOr7Xjo',
#   'uri': 'spotify:track:4ggiDYAkJ7Yk8d5xOr7Xjo',
#   'track_href': 'https://api.spotify.com/v1/tracks/4ggiDYAkJ7Yk8d5xOr7Xjo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4ggiDYAkJ7Yk8d5xOr7Xjo',
#   'duration_ms': 221653,
#   'time_signature': 4},
#  {'danceability': 0.6,
#   'energy': 0.683,
#   'key': 6,
#   'loudness': -6.271,
#   'mode': 1,
#   'speechiness': 0.0493,
#   'acousticness': 0.0984,
#   'instrumentalness': 1.26e-06,
#   'liveness': 0.11,
#   'valence': 0.494,
#   'tempo': 102.036,
#   'type': 'audio_features',
#   'id': '514rhnksEwHUh6LxXsQ4Y9',
#   'uri': 'spotify:track:514rhnksEwHUh6LxXsQ4Y9',
#   'track_href': 'https://api.spotify.com/v1/tracks/514rhnksEwHUh6LxXsQ4Y9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/514rhnksEwHUh6LxXsQ4Y9',
#   'duration_ms': 210240,
#   'time_signature': 4},
#  {'danceability': 0.417,
#   'energy': 0.824,
#   'key': 11,
#   'loudness': -7.36,
#   'mode': 0,
#   'speechiness': 0.105,
#   'acousticness': 0.000239,
#   'instrumentalness': 0.0545,
#   'liveness': 0.0725,
#   'valence': 0.4,
#   'tempo': 157.92,
#   'type': 'audio_features',
#   'id': '4ylWMuGbMXNDgDd8lErEle',
#   'uri': 'spotify:track:4ylWMuGbMXNDgDd8lErEle',
#   'track_href': 'https://api.spotify.com/v1/tracks/4ylWMuGbMXNDgDd8lErEle',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4ylWMuGbMXNDgDd8lErEle',
#   'duration_ms': 302147,
#   'time_signature': 4},
#  {'danceability': 0.884,
#   'energy': 0.559,
#   'key': 0,
#   'loudness': -7.442,
#   'mode': 1,
#   'speechiness': 0.12,
#   'acousticness': 0.0236,
#   'instrumentalness': 0,
#   'liveness': 0.101,
#   'valence': 0.342,
#   'tempo': 97.994,
#   'type': 'audio_features',
#   'id': '5IaHrVsrferBYDm0bDyABy',
#   'uri': 'spotify:track:5IaHrVsrferBYDm0bDyABy',
#   'track_href': 'https://api.spotify.com/v1/tracks/5IaHrVsrferBYDm0bDyABy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5IaHrVsrferBYDm0bDyABy',
#   'duration_ms': 232959,
#   'time_signature': 4},
#  {'danceability': 0.747,
#   'energy': 0.834,
#   'key': 3,
#   'loudness': -2.867,
#   'mode': 0,
#   'speechiness': 0.045,
#   'acousticness': 0.374,
#   'instrumentalness': 0,
#   'liveness': 0.0586,
#   'valence': 0.687,
#   'tempo': 128.005,
#   'type': 'audio_features',
#   'id': '4kWO6O1BUXcZmaxitpVUwp',
#   'uri': 'spotify:track:4kWO6O1BUXcZmaxitpVUwp',
#   'track_href': 'https://api.spotify.com/v1/tracks/4kWO6O1BUXcZmaxitpVUwp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4kWO6O1BUXcZmaxitpVUwp',
#   'duration_ms': 215760,
#   'time_signature': 4},
#  {'danceability': 0.653,
#   'energy': 0.718,
#   'key': 3,
#   'loudness': -5.232,
#   'mode': 0,
#   'speechiness': 0.213,
#   'acousticness': 0.00413,
#   'instrumentalness': 0,
#   'liveness': 0.0537,
#   'valence': 0.216,
#   'tempo': 82.034,
#   'type': 'audio_features',
#   'id': '0OI7AFifLSoGzpb8bdBLLV',
#   'uri': 'spotify:track:0OI7AFifLSoGzpb8bdBLLV',
#   'track_href': 'https://api.spotify.com/v1/tracks/0OI7AFifLSoGzpb8bdBLLV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0OI7AFifLSoGzpb8bdBLLV',
#   'duration_ms': 202805,
#   'time_signature': 4},
#  {'danceability': 0.735,
#   'energy': 0.677,
#   'key': 2,
#   'loudness': -4.979,
#   'mode': 1,
#   'speechiness': 0.093,
#   'acousticness': 0.0762,
#   'instrumentalness': 2.17e-05,
#   'liveness': 0.111,
#   'valence': 0.188,
#   'tempo': 100.584,
#   'type': 'audio_features',
#   'id': '77UjLW8j5UAGAGVGhR5oUK',
#   'uri': 'spotify:track:77UjLW8j5UAGAGVGhR5oUK',
#   'track_href': 'https://api.spotify.com/v1/tracks/77UjLW8j5UAGAGVGhR5oUK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/77UjLW8j5UAGAGVGhR5oUK',
#   'duration_ms': 211440,
#   'time_signature': 4},
#  {'danceability': 0.546,
#   'energy': 0.822,
#   'key': 7,
#   'loudness': -4.483,
#   'mode': 1,
#   'speechiness': 0.151,
#   'acousticness': 0.0145,
#   'instrumentalness': 0,
#   'liveness': 0.742,
#   'valence': 0.615,
#   'tempo': 150.06,
#   'type': 'audio_features',
#   'id': '6VrCmhRBFnuGKmtNfk4jDs',
#   'uri': 'spotify:track:6VrCmhRBFnuGKmtNfk4jDs',
#   'track_href': 'https://api.spotify.com/v1/tracks/6VrCmhRBFnuGKmtNfk4jDs',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6VrCmhRBFnuGKmtNfk4jDs',
#   'duration_ms': 177600,
#   'time_signature': 4},
#  {'danceability': 0.792,
#   'energy': 0.895,
#   'key': 1,
#   'loudness': -3.112,
#   'mode': 0,
#   'speechiness': 0.0589,
#   'acousticness': 0.165,
#   'instrumentalness': 0,
#   'liveness': 0.0501,
#   'valence': 0.794,
#   'tempo': 94.968,
#   'type': 'audio_features',
#   'id': '4QtiVmuA88tPQiCOHZuQ5b',
#   'uri': 'spotify:track:4QtiVmuA88tPQiCOHZuQ5b',
#   'track_href': 'https://api.spotify.com/v1/tracks/4QtiVmuA88tPQiCOHZuQ5b',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4QtiVmuA88tPQiCOHZuQ5b',
#   'duration_ms': 201526,
#   'time_signature': 4},
#  {'danceability': 0.904,
#   'energy': 0.518,
#   'key': 2,
#   'loudness': -5.32,
#   'mode': 1,
#   'speechiness': 0.183,
#   'acousticness': 0.0305,
#   'instrumentalness': 0,
#   'liveness': 0.325,
#   'valence': 0.188,
#   'tempo': 137.996,
#   'type': 'audio_features',
#   'id': '4wFjTWCunQFKtukqrNijEt',
#   'uri': 'spotify:track:4wFjTWCunQFKtukqrNijEt',
#   'track_href': 'https://api.spotify.com/v1/tracks/4wFjTWCunQFKtukqrNijEt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4wFjTWCunQFKtukqrNijEt',
#   'duration_ms': 303077,
#   'time_signature': 4},
#  {'danceability': 0.931,
#   'energy': 0.387,
#   'key': 1,
#   'loudness': -9.127,
#   'mode': 1,
#   'speechiness': 0.412,
#   'acousticness': 0.088,
#   'instrumentalness': 0,
#   'liveness': 0.136,
#   'valence': 0.375,
#   'tempo': 125.978,
#   'type': 'audio_features',
#   'id': '1M6SuEJZJkZf2S419vIPkB',
#   'uri': 'spotify:track:1M6SuEJZJkZf2S419vIPkB',
#   'track_href': 'https://api.spotify.com/v1/tracks/1M6SuEJZJkZf2S419vIPkB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1M6SuEJZJkZf2S419vIPkB',
#   'duration_ms': 179405,
#   'time_signature': 4},
#  {'danceability': 0.854,
#   'energy': 0.463,
#   'key': 5,
#   'loudness': -6.159,
#   'mode': 1,
#   'speechiness': 0.137,
#   'acousticness': 0.117,
#   'instrumentalness': 0,
#   'liveness': 0.354,
#   'valence': 0.549,
#   'tempo': 120.024,
#   'type': 'audio_features',
#   'id': '0b9oOr2ZgvyQu88wzixux9',
#   'uri': 'spotify:track:0b9oOr2ZgvyQu88wzixux9',
#   'track_href': 'https://api.spotify.com/v1/tracks/0b9oOr2ZgvyQu88wzixux9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0b9oOr2ZgvyQu88wzixux9',
#   'duration_ms': 225773,
#   'time_signature': 4},
#  {'danceability': 0.783,
#   'energy': 0.84,
#   'key': 1,
#   'loudness': -3.416,
#   'mode': 1,
#   'speechiness': 0.051,
#   'acousticness': 0.174,
#   'instrumentalness': 0,
#   'liveness': 0.412,
#   'valence': 0.839,
#   'tempo': 95.001,
#   'type': 'audio_features',
#   'id': '6KuqAtoeVzxAYOaMveLNpH',
#   'uri': 'spotify:track:6KuqAtoeVzxAYOaMveLNpH',
#   'track_href': 'https://api.spotify.com/v1/tracks/6KuqAtoeVzxAYOaMveLNpH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6KuqAtoeVzxAYOaMveLNpH',
#   'duration_ms': 200480,
#   'time_signature': 4},
#  {'danceability': 0.707,
#   'energy': 0.632,
#   'key': 10,
#   'loudness': -7.031,
#   'mode': 1,
#   'speechiness': 0.0789,
#   'acousticness': 0.103,
#   'instrumentalness': 1.09e-05,
#   'liveness': 0.0841,
#   'valence': 0.372,
#   'tempo': 97.04,
#   'type': 'audio_features',
#   'id': '1LhMopPAallLeaeNutqbgS',
#   'uri': 'spotify:track:1LhMopPAallLeaeNutqbgS',
#   'track_href': 'https://api.spotify.com/v1/tracks/1LhMopPAallLeaeNutqbgS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1LhMopPAallLeaeNutqbgS',
#   'duration_ms': 278893,
#   'time_signature': 4},
#  {'danceability': 0.876,
#   'energy': 0.519,
#   'key': 11,
#   'loudness': -6.531,
#   'mode': 1,
#   'speechiness': 0.143,
#   'acousticness': 0.202,
#   'instrumentalness': 0,
#   'liveness': 0.108,
#   'valence': 0.158,
#   'tempo': 94.981,
#   'type': 'audio_features',
#   'id': '1ZAyjvIk9YiD76yYy0TEG6',
#   'uri': 'spotify:track:1ZAyjvIk9YiD76yYy0TEG6',
#   'track_href': 'https://api.spotify.com/v1/tracks/1ZAyjvIk9YiD76yYy0TEG6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1ZAyjvIk9YiD76yYy0TEG6',
#   'duration_ms': 175230,
#   'time_signature': 4},
#  {'danceability': 0.637,
#   'energy': 0.864,
#   'key': 8,
#   'loudness': -4.381,
#   'mode': 1,
#   'speechiness': 0.0468,
#   'acousticness': 0.484,
#   'instrumentalness': 0,
#   'liveness': 0.222,
#   'valence': 0.706,
#   'tempo': 99.995,
#   'type': 'audio_features',
#   'id': '2RiBogNRfulkNf7fVbPOrJ',
#   'uri': 'spotify:track:2RiBogNRfulkNf7fVbPOrJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/2RiBogNRfulkNf7fVbPOrJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2RiBogNRfulkNf7fVbPOrJ',
#   'duration_ms': 214720,
#   'time_signature': 4},
#  {'danceability': 0.6,
#   'energy': 0.535,
#   'key': 4,
#   'loudness': -7.043,
#   'mode': 1,
#   'speechiness': 0.107,
#   'acousticness': 0.648,
#   'instrumentalness': 4.7e-06,
#   'liveness': 0.162,
#   'valence': 0.269,
#   'tempo': 71.912,
#   'type': 'audio_features',
#   'id': '0CZ8lquoTX2Dkg7Ak2inwA',
#   'uri': 'spotify:track:0CZ8lquoTX2Dkg7Ak2inwA',
#   'track_href': 'https://api.spotify.com/v1/tracks/0CZ8lquoTX2Dkg7Ak2inwA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0CZ8lquoTX2Dkg7Ak2inwA',
#   'duration_ms': 225133,
#   'time_signature': 4},
#  {'danceability': 0.755,
#   'energy': 0.599,
#   'key': 8,
#   'loudness': -5.042,
#   'mode': 1,
#   'speechiness': 0.224,
#   'acousticness': 0.147,
#   'instrumentalness': 0,
#   'liveness': 0.109,
#   'valence': 0.755,
#   'tempo': 133.123,
#   'type': 'audio_features',
#   'id': '10Igtw8bSDyyFs7KIsKngZ',
#   'uri': 'spotify:track:10Igtw8bSDyyFs7KIsKngZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/10Igtw8bSDyyFs7KIsKngZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/10Igtw8bSDyyFs7KIsKngZ',
#   'duration_ms': 216632,
#   'time_signature': 4},
#  {'danceability': 0.737,
#   'energy': 0.636,
#   'key': 11,
#   'loudness': -4.546,
#   'mode': 0,
#   'speechiness': 0.0437,
#   'acousticness': 0.0441,
#   'instrumentalness': 6.66e-05,
#   'liveness': 0.35,
#   'valence': 0.565,
#   'tempo': 105.005,
#   'type': 'audio_features',
#   'id': '6kPJZM97LwdG9QIsT7khp6',
#   'uri': 'spotify:track:6kPJZM97LwdG9QIsT7khp6',
#   'track_href': 'https://api.spotify.com/v1/tracks/6kPJZM97LwdG9QIsT7khp6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6kPJZM97LwdG9QIsT7khp6',
#   'duration_ms': 222653,
#   'time_signature': 4},
#  {'danceability': 0.645,
#   'energy': 0.705,
#   'key': 1,
#   'loudness': -5.008,
#   'mode': 1,
#   'speechiness': 0.299,
#   'acousticness': 0.000813,
#   'instrumentalness': 0,
#   'liveness': 0.128,
#   'valence': 0.376,
#   'tempo': 137.133,
#   'type': 'audio_features',
#   'id': '51rXHuKN8Loc4sUlKPODgH',
#   'uri': 'spotify:track:51rXHuKN8Loc4sUlKPODgH',
#   'track_href': 'https://api.spotify.com/v1/tracks/51rXHuKN8Loc4sUlKPODgH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/51rXHuKN8Loc4sUlKPODgH',
#   'duration_ms': 229670,
#   'time_signature': 4},
#  {'danceability': 0.722,
#   'energy': 0.738,
#   'key': 9,
#   'loudness': -6.073,
#   'mode': 0,
#   'speechiness': 0.247,
#   'acousticness': 0.328,
#   'instrumentalness': 1.47e-05,
#   'liveness': 0.198,
#   'valence': 0.748,
#   'tempo': 198.075,
#   'type': 'audio_features',
#   'id': '5cepAtqnEQ6yVG6088zMMu',
#   'uri': 'spotify:track:5cepAtqnEQ6yVG6088zMMu',
#   'track_href': 'https://api.spotify.com/v1/tracks/5cepAtqnEQ6yVG6088zMMu',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5cepAtqnEQ6yVG6088zMMu',
#   'duration_ms': 184720,
#   'time_signature': 4},
#  {'danceability': 0.82,
#   'energy': 0.568,
#   'key': 6,
#   'loudness': -8.23,
#   'mode': 0,
#   'speechiness': 0.411,
#   'acousticness': 0.0256,
#   'instrumentalness': 0,
#   'liveness': 0.0952,
#   'valence': 0.535,
#   'tempo': 152.279,
#   'type': 'audio_features',
#   'id': '2Yl4OmDby9iitgNWZPwxkd',
#   'uri': 'spotify:track:2Yl4OmDby9iitgNWZPwxkd',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Yl4OmDby9iitgNWZPwxkd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Yl4OmDby9iitgNWZPwxkd',
#   'duration_ms': 210787,
#   'time_signature': 4},
#  {'danceability': 0.791,
#   'energy': 0.745,
#   'key': 11,
#   'loudness': -3.695,
#   'mode': 0,
#   'speechiness': 0.0464,
#   'acousticness': 0.354,
#   'instrumentalness': 2.93e-05,
#   'liveness': 0.104,
#   'valence': 0.82,
#   'tempo': 94.014,
#   'type': 'audio_features',
#   'id': '2ijef6ni2amuunRoKTlgww',
#   'uri': 'spotify:track:2ijef6ni2amuunRoKTlgww',
#   'track_href': 'https://api.spotify.com/v1/tracks/2ijef6ni2amuunRoKTlgww',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2ijef6ni2amuunRoKTlgww',
#   'duration_ms': 188560,
#   'time_signature': 4},
#  {'danceability': 0.596,
#   'energy': 0.854,
#   'key': 7,
#   'loudness': -5.114,
#   'mode': 0,
#   'speechiness': 0.463,
#   'acousticness': 0.0169,
#   'instrumentalness': 0,
#   'liveness': 0.124,
#   'valence': 0.152,
#   'tempo': 120.274,
#   'type': 'audio_features',
#   'id': '55S2PQgSMYAhgoTCcGCDfw',
#   'uri': 'spotify:track:55S2PQgSMYAhgoTCcGCDfw',
#   'track_href': 'https://api.spotify.com/v1/tracks/55S2PQgSMYAhgoTCcGCDfw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/55S2PQgSMYAhgoTCcGCDfw',
#   'duration_ms': 203418,
#   'time_signature': 4},
#  {'danceability': 0.642,
#   'energy': 0.881,
#   'key': 11,
#   'loudness': -3.537,
#   'mode': 1,
#   'speechiness': 0.0393,
#   'acousticness': 0.209,
#   'instrumentalness': 0,
#   'liveness': 0.21,
#   'valence': 0.913,
#   'tempo': 138.03,
#   'type': 'audio_features',
#   'id': '38zwkK6TtTjIW9tpYBfZ3D',
#   'uri': 'spotify:track:38zwkK6TtTjIW9tpYBfZ3D',
#   'track_href': 'https://api.spotify.com/v1/tracks/38zwkK6TtTjIW9tpYBfZ3D',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/38zwkK6TtTjIW9tpYBfZ3D',
#   'duration_ms': 222045,
#   'time_signature': 4},
#  {'danceability': 0.899,
#   'energy': 0.586,
#   'key': 11,
#   'loudness': -7.866,
#   'mode': 0,
#   'speechiness': 0.343,
#   'acousticness': 0.279,
#   'instrumentalness': 0,
#   'liveness': 0.0836,
#   'valence': 0.492,
#   'tempo': 150.002,
#   'type': 'audio_features',
#   'id': '3qN5qMTKyEEmiTZD38BNTT',
#   'uri': 'spotify:track:3qN5qMTKyEEmiTZD38BNTT',
#   'track_href': 'https://api.spotify.com/v1/tracks/3qN5qMTKyEEmiTZD38BNTT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3qN5qMTKyEEmiTZD38BNTT',
#   'duration_ms': 214467,
#   'time_signature': 4},
#  {'danceability': 0.856,
#   'energy': 0.632,
#   'key': 6,
#   'loudness': -3.692,
#   'mode': 0,
#   'speechiness': 0.074,
#   'acousticness': 0.193,
#   'instrumentalness': 0,
#   'liveness': 0.0688,
#   'valence': 0.697,
#   'tempo': 112.009,
#   'type': 'audio_features',
#   'id': '1lsBTdE6MGsKeZCD6llNu7',
#   'uri': 'spotify:track:1lsBTdE6MGsKeZCD6llNu7',
#   'track_href': 'https://api.spotify.com/v1/tracks/1lsBTdE6MGsKeZCD6llNu7',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1lsBTdE6MGsKeZCD6llNu7',
#   'duration_ms': 180493,
#   'time_signature': 4},
#  {'danceability': 0.693,
#   'energy': 0.624,
#   'key': 0,
#   'loudness': -7.482,
#   'mode': 0,
#   'speechiness': 0.0448,
#   'acousticness': 0.299,
#   'instrumentalness': 7.64e-06,
#   'liveness': 0.0955,
#   'valence': 0.369,
#   'tempo': 105.002,
#   'type': 'audio_features',
#   'id': '0Ult84lvFuqNvbyXwyRQ58',
#   'uri': 'spotify:track:0Ult84lvFuqNvbyXwyRQ58',
#   'track_href': 'https://api.spotify.com/v1/tracks/0Ult84lvFuqNvbyXwyRQ58',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0Ult84lvFuqNvbyXwyRQ58',
#   'duration_ms': 205987,
#   'time_signature': 4}]

# %%
pd.DataFrame(songs) #save this as a function.
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.754   0.449    7    -9.211     1       0.1090        0.0332
# 1          0.585   0.520    5    -6.136     0       0.0712        0.1240
# 2          0.351   0.296    4   -10.109     0       0.0333        0.9340
# 3          0.461   0.593    1    -4.954     1       0.0356        0.1700
# 4          0.698   0.633    8    -4.946     1       0.0597        0.0605
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.596   0.854    7    -5.114     0       0.4630        0.0169
# 96         0.642   0.881   11    -3.537     1       0.0393        0.2090
# 97         0.899   0.586   11    -7.866     0       0.3430        0.2790
# 98         0.856   0.632    6    -3.692     0       0.0740        0.1930
# 99         0.693   0.624    0    -7.482     0       0.0448        0.2990
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000083    0.5520    0.357   77.169  audio_features
# 1           0.000070    0.1310    0.129  159.801  audio_features
# 2           0.000000    0.0950    0.120  115.284  audio_features
# 3           0.000000    0.3070    0.175  134.170  audio_features
# 4           0.000194    0.0926    0.552   96.924  audio_features
# ..               ...       ...      ...      ...             ...
# 95          0.000000    0.1240    0.152  120.274  audio_features
# 96          0.000000    0.2100    0.913  138.030  audio_features
# 97          0.000000    0.0836    0.492  150.002  audio_features
# 98          0.000000    0.0688    0.697  112.009  audio_features
# 99          0.000008    0.0955    0.369  105.002  audio_features
#
#                         id                                   uri  \
# 0   6DCZcSspjsKoFjzjrWoCdn  spotify:track:6DCZcSspjsKoFjzjrWoCdn
# 1   0e7ipj03S05BNilyu5bRzt  spotify:track:0e7ipj03S05BNilyu5bRzt
# 2   0u2P5u6lvoDfwTYjAADbn4  spotify:track:0u2P5u6lvoDfwTYjAADbn4
# 3   09mEdoA6zrmBPgTEN5qXmN  spotify:track:09mEdoA6zrmBPgTEN5qXmN
# 4   3GCdLUSnKSMJhs4Tj6CV3s  spotify:track:3GCdLUSnKSMJhs4Tj6CV3s
# ..                     ...                                   ...
# 95  55S2PQgSMYAhgoTCcGCDfw  spotify:track:55S2PQgSMYAhgoTCcGCDfw
# 96  38zwkK6TtTjIW9tpYBfZ3D  spotify:track:38zwkK6TtTjIW9tpYBfZ3D
# 97  3qN5qMTKyEEmiTZD38BNTT  spotify:track:3qN5qMTKyEEmiTZD38BNTT
# 98  1lsBTdE6MGsKeZCD6llNu7  spotify:track:1lsBTdE6MGsKeZCD6llNu7
# 99  0Ult84lvFuqNvbyXwyRQ58  spotify:track:0Ult84lvFuqNvbyXwyRQ58
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/6DCZcSspjsKo...
# 1   https://api.spotify.com/v1/tracks/0e7ipj03S05B...
# 2   https://api.spotify.com/v1/tracks/0u2P5u6lvoDf...
# 3   https://api.spotify.com/v1/tracks/09mEdoA6zrmB...
# 4   https://api.spotify.com/v1/tracks/3GCdLUSnKSMJ...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/55S2PQgSMYAh...
# 96  https://api.spotify.com/v1/tracks/38zwkK6TtTjI...
# 97  https://api.spotify.com/v1/tracks/3qN5qMTKyEEm...
# 98  https://api.spotify.com/v1/tracks/1lsBTdE6MGsK...
# 99  https://api.spotify.com/v1/tracks/0Ult84lvFuqN...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/6DCZ...       198973
# 1   https://api.spotify.com/v1/audio-analysis/0e7i...       218147
# 2   https://api.spotify.com/v1/audio-analysis/0u2P...       200186
# 3   https://api.spotify.com/v1/audio-analysis/09mE...       228373
# 4   https://api.spotify.com/v1/audio-analysis/3GCd...       232187
# ..                                                ...          ...
# 95  https://api.spotify.com/v1/audio-analysis/55S2...       203418
# 96  https://api.spotify.com/v1/audio-analysis/38zw...       222045
# 97  https://api.spotify.com/v1/audio-analysis/3qN5...       214467
# 98  https://api.spotify.com/v1/audio-analysis/1lsB...       180493
# 99  https://api.spotify.com/v1/audio-analysis/0Ult...       205987
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                3
# 4                4
# ..             ...
# 95               4
# 96               4
# 97               4
# 98               4
# 99               4
#
# [100 rows x 18 columns]

# %%
import json
import pandas as pd

file_name = "2018_playlist_audio_features.jsonl"
songs = []
with open(file_name, "r") as input_file:
    for line in input_file.readlines():
        song_features = json.loads(line)[0]
        songs.append(song_features)
        
songs_dataframe = pd.DataFrame(songs)

# %%
songs_dataframe
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.754   0.449    7    -9.211     1       0.1090        0.0332
# 1          0.585   0.520    5    -6.136     0       0.0712        0.1240
# 2          0.351   0.296    4   -10.109     0       0.0333        0.9340
# 3          0.461   0.593    1    -4.954     1       0.0356        0.1700
# 4          0.698   0.633    8    -4.946     1       0.0597        0.0605
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.596   0.854    7    -5.114     0       0.4630        0.0169
# 96         0.642   0.881   11    -3.537     1       0.0393        0.2090
# 97         0.899   0.586   11    -7.866     0       0.3430        0.2790
# 98         0.856   0.632    6    -3.692     0       0.0740        0.1930
# 99         0.693   0.624    0    -7.482     0       0.0448        0.2990
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000083    0.5520    0.357   77.169  audio_features
# 1           0.000070    0.1310    0.129  159.801  audio_features
# 2           0.000000    0.0950    0.120  115.284  audio_features
# 3           0.000000    0.3070    0.175  134.170  audio_features
# 4           0.000194    0.0926    0.552   96.924  audio_features
# ..               ...       ...      ...      ...             ...
# 95          0.000000    0.1240    0.152  120.274  audio_features
# 96          0.000000    0.2100    0.913  138.030  audio_features
# 97          0.000000    0.0836    0.492  150.002  audio_features
# 98          0.000000    0.0688    0.697  112.009  audio_features
# 99          0.000008    0.0955    0.369  105.002  audio_features
#
#                         id                                   uri  \
# 0   6DCZcSspjsKoFjzjrWoCdn  spotify:track:6DCZcSspjsKoFjzjrWoCdn
# 1   0e7ipj03S05BNilyu5bRzt  spotify:track:0e7ipj03S05BNilyu5bRzt
# 2   0u2P5u6lvoDfwTYjAADbn4  spotify:track:0u2P5u6lvoDfwTYjAADbn4
# 3   09mEdoA6zrmBPgTEN5qXmN  spotify:track:09mEdoA6zrmBPgTEN5qXmN
# 4   3GCdLUSnKSMJhs4Tj6CV3s  spotify:track:3GCdLUSnKSMJhs4Tj6CV3s
# ..                     ...                                   ...
# 95  55S2PQgSMYAhgoTCcGCDfw  spotify:track:55S2PQgSMYAhgoTCcGCDfw
# 96  38zwkK6TtTjIW9tpYBfZ3D  spotify:track:38zwkK6TtTjIW9tpYBfZ3D
# 97  3qN5qMTKyEEmiTZD38BNTT  spotify:track:3qN5qMTKyEEmiTZD38BNTT
# 98  1lsBTdE6MGsKeZCD6llNu7  spotify:track:1lsBTdE6MGsKeZCD6llNu7
# 99  0Ult84lvFuqNvbyXwyRQ58  spotify:track:0Ult84lvFuqNvbyXwyRQ58
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/6DCZcSspjsKo...
# 1   https://api.spotify.com/v1/tracks/0e7ipj03S05B...
# 2   https://api.spotify.com/v1/tracks/0u2P5u6lvoDf...
# 3   https://api.spotify.com/v1/tracks/09mEdoA6zrmB...
# 4   https://api.spotify.com/v1/tracks/3GCdLUSnKSMJ...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/55S2PQgSMYAh...
# 96  https://api.spotify.com/v1/tracks/38zwkK6TtTjI...
# 97  https://api.spotify.com/v1/tracks/3qN5qMTKyEEm...
# 98  https://api.spotify.com/v1/tracks/1lsBTdE6MGsK...
# 99  https://api.spotify.com/v1/tracks/0Ult84lvFuqN...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/6DCZ...       198973
# 1   https://api.spotify.com/v1/audio-analysis/0e7i...       218147
# 2   https://api.spotify.com/v1/audio-analysis/0u2P...       200186
# 3   https://api.spotify.com/v1/audio-analysis/09mE...       228373
# 4   https://api.spotify.com/v1/audio-analysis/3GCd...       232187
# ..                                                ...          ...
# 95  https://api.spotify.com/v1/audio-analysis/55S2...       203418
# 96  https://api.spotify.com/v1/audio-analysis/38zw...       222045
# 97  https://api.spotify.com/v1/audio-analysis/3qN5...       214467
# 98  https://api.spotify.com/v1/audio-analysis/1lsB...       180493
# 99  https://api.spotify.com/v1/audio-analysis/0Ult...       205987
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                3
# 4                4
# ..             ...
# 95               4
# 96               4
# 97               4
# 98               4
# 99               4
#
# [100 rows x 18 columns]

# %%
import json
import pandas as pd
#building our function
def build_songs_dataframe(audio_features_filename):

    songs = []
    with open(audio_features_filename, "r") as input_file:
        for line in input_file.readlines():
            song_features = json.loads(line)[0]
            songs.append(song_features)
        
    return pd.DataFrame(songs)

# %%
df_songs = build_songs_dataframe("2018_playlist_audio_features.jsonl")
df_songs
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.754   0.449    7    -9.211     1       0.1090        0.0332
# 1          0.585   0.520    5    -6.136     0       0.0712        0.1240
# 2          0.351   0.296    4   -10.109     0       0.0333        0.9340
# 3          0.461   0.593    1    -4.954     1       0.0356        0.1700
# 4          0.698   0.633    8    -4.946     1       0.0597        0.0605
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.596   0.854    7    -5.114     0       0.4630        0.0169
# 96         0.642   0.881   11    -3.537     1       0.0393        0.2090
# 97         0.899   0.586   11    -7.866     0       0.3430        0.2790
# 98         0.856   0.632    6    -3.692     0       0.0740        0.1930
# 99         0.693   0.624    0    -7.482     0       0.0448        0.2990
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000083    0.5520    0.357   77.169  audio_features
# 1           0.000070    0.1310    0.129  159.801  audio_features
# 2           0.000000    0.0950    0.120  115.284  audio_features
# 3           0.000000    0.3070    0.175  134.170  audio_features
# 4           0.000194    0.0926    0.552   96.924  audio_features
# ..               ...       ...      ...      ...             ...
# 95          0.000000    0.1240    0.152  120.274  audio_features
# 96          0.000000    0.2100    0.913  138.030  audio_features
# 97          0.000000    0.0836    0.492  150.002  audio_features
# 98          0.000000    0.0688    0.697  112.009  audio_features
# 99          0.000008    0.0955    0.369  105.002  audio_features
#
#                         id                                   uri  \
# 0   6DCZcSspjsKoFjzjrWoCdn  spotify:track:6DCZcSspjsKoFjzjrWoCdn
# 1   0e7ipj03S05BNilyu5bRzt  spotify:track:0e7ipj03S05BNilyu5bRzt
# 2   0u2P5u6lvoDfwTYjAADbn4  spotify:track:0u2P5u6lvoDfwTYjAADbn4
# 3   09mEdoA6zrmBPgTEN5qXmN  spotify:track:09mEdoA6zrmBPgTEN5qXmN
# 4   3GCdLUSnKSMJhs4Tj6CV3s  spotify:track:3GCdLUSnKSMJhs4Tj6CV3s
# ..                     ...                                   ...
# 95  55S2PQgSMYAhgoTCcGCDfw  spotify:track:55S2PQgSMYAhgoTCcGCDfw
# 96  38zwkK6TtTjIW9tpYBfZ3D  spotify:track:38zwkK6TtTjIW9tpYBfZ3D
# 97  3qN5qMTKyEEmiTZD38BNTT  spotify:track:3qN5qMTKyEEmiTZD38BNTT
# 98  1lsBTdE6MGsKeZCD6llNu7  spotify:track:1lsBTdE6MGsKeZCD6llNu7
# 99  0Ult84lvFuqNvbyXwyRQ58  spotify:track:0Ult84lvFuqNvbyXwyRQ58
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/6DCZcSspjsKo...
# 1   https://api.spotify.com/v1/tracks/0e7ipj03S05B...
# 2   https://api.spotify.com/v1/tracks/0u2P5u6lvoDf...
# 3   https://api.spotify.com/v1/tracks/09mEdoA6zrmB...
# 4   https://api.spotify.com/v1/tracks/3GCdLUSnKSMJ...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/55S2PQgSMYAh...
# 96  https://api.spotify.com/v1/tracks/38zwkK6TtTjI...
# 97  https://api.spotify.com/v1/tracks/3qN5qMTKyEEm...
# 98  https://api.spotify.com/v1/tracks/1lsBTdE6MGsK...
# 99  https://api.spotify.com/v1/tracks/0Ult84lvFuqN...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/6DCZ...       198973
# 1   https://api.spotify.com/v1/audio-analysis/0e7i...       218147
# 2   https://api.spotify.com/v1/audio-analysis/0u2P...       200186
# 3   https://api.spotify.com/v1/audio-analysis/09mE...       228373
# 4   https://api.spotify.com/v1/audio-analysis/3GCd...       232187
# ..                                                ...          ...
# 95  https://api.spotify.com/v1/audio-analysis/55S2...       203418
# 96  https://api.spotify.com/v1/audio-analysis/38zw...       222045
# 97  https://api.spotify.com/v1/audio-analysis/3qN5...       214467
# 98  https://api.spotify.com/v1/audio-analysis/1lsB...       180493
# 99  https://api.spotify.com/v1/audio-analysis/0Ult...       205987
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                3
# 4                4
# ..             ...
# 95               4
# 96               4
# 97               4
# 98               4
# 99               4
#
# [100 rows x 18 columns]

# %%
df_songs["year"]=2018

# %%
print("danceability mean", df_songs['danceability'].mean())
# Out:
# danceability mean 0.7040499999999998

# %%
print("energy mean", df_songs['energy'].mean())
# Out:
# energy mean 0.6619099999999999

# %%
print("loudness mean", df_songs['loudness'].mean())

#The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire trackand are useful for
#comparing relative loudness of tracks. Loudness is the quality of a sound that is
#the primary psychological correlate of physical strength (amplitude).
#Values typically range between -60 and 0 db.
# Out:
# loudness mean -5.7631499999999996

# %%
print("mode mean", df_songs['mode'].mean())
# Out:
# mode mean 0.64

# %%
print("speechiness mean", df_songs['speechiness'].mean())
# Out:
# speechiness mean 0.12210499999999999

# %%
print("acousticness mean", df_songs['acousticness'].mean())
# Out:
# acousticness mean 0.18256176

# %%
print("instrumentalness mean", df_songs['instrumentalness'].mean())
# Out:
# instrumentalness mean 0.0026916361

# %%
print("liveness mean", df_songs['liveness'].mean())
# Out:
# liveness mean 0.16674300000000003

# %%
print("valence mean", df_songs['valence'].mean())
# Out:
# valence mean 0.479732

# %%
print("tempo mean", df_songs['tempo'].mean())
# Out:
# tempo mean 118.35101000000003

# %%
print("time_signature mean", df_songs['time_signature'].mean())
# Out:
# time_signature mean 3.98

# %%
df_songs["key"].hist()
# Out:
# <Axes: >

# %%
df_songs["mode"].hist()
# Out:
# <Axes: >

# %%
df_songs["time_signature"].hist()
# Out:
# <Axes: >

# %%
df_songs.to_csv("Dataclean_2018.csv")

# %%
df_songs.describe()
# Out:
#        danceability      energy         key   loudness        mode  \
# count    100.000000  100.000000  100.000000  100.00000  100.000000
# mean       0.704050    0.661910    5.830000   -5.76315    0.640000
# std        0.132705    0.141575    3.578993    1.91530    0.482418
# min        0.351000    0.296000    0.000000  -12.80800    0.000000
# 25%        0.621000    0.577000    2.000000   -7.03400    0.000000
# 50%        0.704000    0.676000    6.000000   -5.45450    1.000000
# 75%        0.791250    0.773000    9.000000   -4.39450    1.000000
# max        0.963000    0.909000   11.000000   -2.38400    1.000000
#
#        speechiness  acousticness  instrumentalness    liveness     valence  \
# count   100.000000    100.000000        100.000000  100.000000  100.000000
# mean      0.122105      0.182562          0.002692    0.166743    0.479732
# std       0.108884      0.199031          0.018882    0.125987    0.210249
# min       0.028000      0.000239          0.000000    0.021500    0.049900
# 25%       0.046225      0.040225          0.000000    0.094400    0.336750
# 50%       0.085450      0.120500          0.000000    0.122500    0.479000
# 75%       0.144250      0.232750          0.000013    0.199250    0.625250
# max       0.530000      0.934000          0.181000    0.742000    0.926000
#
#             tempo    duration_ms  time_signature    year
# count  100.000000     100.000000      100.000000   100.0
# mean   118.351010  208011.320000        3.980000  2018.0
# std     27.852412   38697.095843        0.140705     0.0
# min     64.934000  121887.000000        3.000000  2018.0
# 25%     96.070000  185083.000000        4.000000  2018.0
# 50%    119.170500  204669.000000        4.000000  2018.0
# 75%    138.004500  221119.750000        4.000000  2018.0
# max    199.811000  417920.000000        4.000000  2018.0
