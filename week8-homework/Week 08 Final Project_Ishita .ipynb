# %% [markdown]
# What is your proposed unit of analysis? In other words, if/when you end up building something like a spreadsheet, what are rows going to represent?
#
#
# A dataset focused on a specific keyword would shed light on how YouTube's recommendation algorithm operates. Specifically, I'm curious about how YouTube recommends similar content based on the initial keyword used in a video, and at what point in the view count does it start to make such recommendations. Does the algorithm prioritize the usage of the keyword, or does it prioritize popularity? Which of these factors carries more weight in YouTube's decision-making process for recommendations?

# %%
pip install youtube-data-api
# Out:
# Requirement already satisfied: youtube-data-api in /Users/ishita/anaconda3/lib/python3.10/site-packages (0.0.21)
# Requirement already satisfied: pandas in /Users/ishita/anaconda3/lib/python3.10/site-packages (from youtube-data-api) (1.5.3)
# Requirement already satisfied: requests in /Users/ishita/anaconda3/lib/python3.10/site-packages (from youtube-data-api) (2.28.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/ishita/anaconda3/lib/python3.10/site-packages (from pandas->youtube-data-api) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/ishita/anaconda3/lib/python3.10/site-packages (from pandas->youtube-data-api) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in /Users/ishita/anaconda3/lib/python3.10/site-packages (from pandas->youtube-data-api) (1.23.5)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/ishita/anaconda3/lib/python3.10/site-packages (from requests->youtube-data-api) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ishita/anaconda3/lib/python3.10/site-packages (from requests->youtube-data-api) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/ishita/anaconda3/lib/python3.10/site-packages (from requests->youtube-data-api) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ishita/anaconda3/lib/python3.10/site-packages (from requests->youtube-data-api) (2022.12.7)
# Requirement already satisfied: six>=1.5 in /Users/ishita/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->youtube-data-api) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from youtube_api import YouTubeDataAPI
from youtube_key import youtube_key

youtube_key 
yt = YouTubeDataAPI(youtube_key)

yt.search('alexandria ocasio-cortez')

#see how to get the videos part similar to the chrome code and find a way to use it in this api key
# Out:
# [{'video_id': '1tk01l_jRX0',
#   'channel_title': 'ABC News',
#   'channel_id': 'UCBi2mrWuNuyYy4gbM6fU18Q',
#   'video_publish_date': 1675398840.0,
#   'video_title': 'Rep. Alexandria Ocasio-Cortez excoriates Republicans for ousting Rep. Ilhan Omar from committee.',
#   'video_description': '"There is nothing consistent about the Republican Party\'s continued attack, except for the racism... against women of color in this ...',
#   'video_category': None,
#   'video_thumbnail': 'https://i.ytimg.com/vi/1tk01l_jRX0/hqdefault.jpg',
#   'collection_date': datetime.datetime(2023, 5, 21, 22, 7, 57, 452093)},
#  {'video_id': 'lMeF_jwnHMA',
#   'channel_title': 'Inside Edition',
#   'channel_id': 'UC9k-yiEpRHMNVOnOi_aQK8w',
#   'video_publish_date': 1657861094.0,
#   'video_title': 'AOC Harassed by Man on Capitol Steps',
#   'video_description': 'Representative Alexandria Ocasio-Cortez is calling out the man she says harassed her on the steps of the U.S. Capitol. The New ...',
#   'video_category': None,
#   'video_thumbnail': 'https://i.ytimg.com/vi/lMeF_jwnHMA/hqdefault.jpg',
#   'collection_date': datetime.datetime(2023, 5, 21, 22, 7, 57, 452246)},
#  {'video_id': '3RrsXuecHwQ',
#   'channel_title': 'MSNBC',
#   'channel_id': 'UCaXkIU1QidjPwiAYu6GcHjg',
#   'video_publish_date': 1683843300.0,
#   'video_title': '#AOC disagrees with #Trump&#39;s #CNN town hall',
#   'video_description': 'Rep. #AlexandriaOcasioCortez calls CNN town hall with former President Trump “shameful” and a “profoundly irresponsible ...',
#   'video_category': None,
#   'video_thumbnail': 'https://i.ytimg.com/vi/3RrsXuecHwQ/hqdefault.jpg',
#   'collection_date': datetime.datetime(2023, 5, 21, 22, 7, 57, 452333)},
#  {'video_id': 'MVEHMMtglUQ',
#   'channel_title': 'MSNBC',
#   'channel_id': 'UCaXkIU1QidjPwiAYu6GcHjg',
#   'video_publish_date': 1683797409.0,
#   'video_title': '&#39;Profoundly irresponsible&#39;: Ocasio-Cortez rips &#39;atrocious&#39; Trump town hall',
#   'video_description': "Rep. Alexandria Ocasio-Cortez talks with Alex Wagner about Donald Trump's remarks on January 6, E. Jean Carroll, the 2020 ...",
#   'video_category': None,
#   'video_thumbnail': 'https://i.ytimg.com/vi/MVEHMMtglUQ/hqdefault.jpg',
#   'collection_date': datetime.datetime(2023, 5, 21, 22, 7, 57, 452404)},
#  {'video_id': 'XtHLLFdue-s',
#   'channel_title': 'CNN',
#   'channel_id': 'UCupvZG-5ko_eiXAupbDfxWw',
#   'video_publish_date': 1680946243.0,
#   'video_title': 'Alexandria Ocasio-Cortez reacts to Texas judge&#39;s abortion pill ruling',
#   'video_description': "Rep. Alexandria Ocasio-Cortez (D-NY) explains to CNN's Anderson Cooper why she believes the Biden administration should ...",
#   'video_category': None,
#   'video_thumbnail': 'https://i.ytimg.com/vi/XtHLLFdue-s/hqdefault.jpg',
#   'collection_date': datetime.datetime(2023, 5, 21, 22, 7, 57, 452475)}]

# %%
pip install --upgrade google-auth-oauthlib google-auth-httplib2
# Out:
# Collecting google-auth-oauthlib
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting google-auth-httplib2
#   Downloading google_auth_httplib2-0.1.0-py2.py3-none-any.whl (9.3 kB)
# Collecting google-auth>=2.15.0 (from google-auth-oauthlib)
#   Downloading google_auth-2.18.0-py2.py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.9/178.9 kB 340.5 kB/s eta 0:00:00a 0:00:01
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib)
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting httplib2>=0.15.0 (from google-auth-httplib2)
#   Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.9/96.9 kB 218.0 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: six in /Users/ishita/anaconda3/lib/python3.10/site-packages (from google-auth-httplib2) (1.16.0)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth>=2.15.0->google-auth-oauthlib)
#   Downloading cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/ishita/anaconda3/lib/python3.10/site-packages (from google-auth>=2.15.0->google-auth-oauthlib) (0.2.8)
# Requirement already satisfied: urllib3<2.0 in /Users/ishita/anaconda3/lib/python3.10/site-packages (from google-auth>=2.15.0->google-auth-oauthlib) (1.26.14)
# Collecting rsa<5,>=3.1.4 (from google-auth>=2.15.0->google-auth-oauthlib)
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/ishita/anaconda3/lib/python3.10/site-packages (from httplib2>=0.15.0->google-auth-httplib2) (3.0.9)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib)
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 167.9 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: requests>=2.0.0 in /Users/ishita/anaconda3/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.28.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/ishita/anaconda3/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-auth-oauthlib) (0.4.8)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/ishita/anaconda3/lib/python3.10/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ishita/anaconda3/lib/python3.10/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ishita/anaconda3/lib/python3.10/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2022.12.7)
# Installing collected packages: rsa, oauthlib, httplib2, cachetools, requests-oauthlib, google-auth, google-auth-oauthlib, google-auth-httplib2
# Successfully installed cachetools-5.3.0 google-auth-2.18.0 google-auth-httplib2-0.1.0 google-auth-oauthlib-1.0.0 httplib2-0.22.0 oauthlib-3.2.2 requests-oauthlib-1.3.1 rsa-4.9
# Note: you may need to restart the kernel to use updated packages.

# %%
from youtube_key import youtube_key
import requests
response =  requests.get(f'https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&chart=mostPopular&regionCode=US&key={youtube_key}')
print (response)              
print (response.json())
# Out:
# <Response [200]>
# {'kind': 'youtube#videoListResponse', 'etag': 'TBp17txAVA4owF2hnZwdsgqR5y4', 'items': [{'kind': 'youtube#video', 'etag': 'htUWkfeHoJNcmnCDmqSdsLEYanA', 'id': '3HGvOnEY_A0', 'snippet': {'publishedAt': '2023-05-21T17:15:35Z', 'channelId': 'UC7_YxT-KID8kRbqZo7MyscQ', 'title': 'The Return to Bloody Nights: Part 1', 'description': "The Return to Bloody Nights is an amazing Five Nights at Freddy's fan game that drops you in and never lets go. \n\nPlay The Return to Bloody Nights ► https://gamejolt.com/games/thereturntobloodynights/595647\n\nEdited By ► https://www.youtube.com/LixianTV\n\nScary Games Playlist ► https://www.youtube.com/playlist?list=PL3tRBEVW0hiBSFOFhTC5wt75P2BES0rAo\n\nHorror Outro ► https://soundcloud.com/shurkofficial/haunted", 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3HGvOnEY_A0/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/3HGvOnEY_A0/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/3HGvOnEY_A0/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/3HGvOnEY_A0/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/3HGvOnEY_A0/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'channelTitle': 'Markiplier', 'tags': ['markiplier', 'the return to bloody nights', 'part 1', "five nights at freddy's", 'fan game', 'fnaf'], 'categoryId': '20', 'liveBroadcastContent': 'none', 'defaultLanguage': 'en', 'localized': {'title': 'The Return to Bloody Nights: Part 1', 'description': "The Return to Bloody Nights is an amazing Five Nights at Freddy's fan game that drops you in and never lets go. \n\nPlay The Return to Bloody Nights ► https://gamejolt.com/games/thereturntobloodynights/595647\n\nEdited By ► https://www.youtube.com/LixianTV\n\nScary Games Playlist ► https://www.youtube.com/playlist?list=PL3tRBEVW0hiBSFOFhTC5wt75P2BES0rAo\n\nHorror Outro ► https://soundcloud.com/shurkofficial/haunted"}, 'defaultAudioLanguage': 'en'}, 'contentDetails': {'duration': 'PT35M48S', 'dimension': '2d', 'definition': 'hd', 'caption': 'false', 'licensedContent': True, 'contentRating': {}, 'projection': 'rectangular'}, 'statistics': {'viewCount': '1439075', 'likeCount': '111191', 'favoriteCount': '0', 'commentCount': '5329'}}, {'kind': 'youtube#video', 'etag': '3pdb5WxseSTa-fjqqPRwFFhq-KI', 'id': 'LA4bwTqnCUk', 'snippet': {'publishedAt': '2023-05-21T06:10:30Z', 'channelId': 'UCbzRzJNHx7ZLlJML9BjZQVQ', 'title': 'Haney & Loma Put On Instant Classic | Haney Retains Undisputed Belts | FIGHT HIGHLIGHTS', 'description': "Watch #highlights from the main event of #haneyloma featuring #devinhaney and #vasiliylomachenko In the back and forth affair, it was Haney who won by decision to retain his undisputed belts.\n\nNext up for Top Rank Boxing,  Luis Alberto “El Venado” Lopez may have to start calling himself “The Road Warrior.” Lopez will make the first defense of his IBF featherweight world title against Michael “Mick” Conlan on Saturday, May 27, at The SSE Arena in Conlan’s hometown of Belfast.\n \nLopez captured the title last December, venturing to Josh Warrington’s home base of Leeds, England, to grind out a majority decision.\n \nLopez-Conlan and undercard bouts will stream live and exclusively on ESPN+ in the United States. BT Sport will broadcast the event in the UK and Ireland.\n \nTry ESPN+ For Free: https://watch.espnplus.com/toprank/\n\nSubscribe to our YouTube channel to get notified about the latest highlights, free full fights, and fight week content as it's posted.\n\nFollow Top Rank on Twitter: http://www.twitter.com/trboxing\nFollow Top Rank on Instagram: http://www.instagram.com/toprank\nLike Top Rank on Facebook: http://www.facebook.com/trboxing", 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LA4bwTqnCUk/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/LA4bwTqnCUk/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'htt ...

# %%
from youtube_key import youtube_key
import requests
response =  requests.get(f'https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&chart=mostPopular&regionCode=US&key={youtube_key}')
print (response)              
print (response.json())  
df = pd.DataFrame(json_data)

file_path = 'Deskstop/Data Science/Youtube.tsv'
df.to_csv(file_path, sep = '\t', index=false)
# Out:
# <Response [200]>
# {'kind': 'youtube#videoListResponse', 'etag': 'ClMkac22lcRDXGswbJNMX4R6tEo', 'items': [{'kind': 'youtube#video', 'etag': 'CoEsQwJSrLbxKoXPRKKosChssoc', 'id': '3HGvOnEY_A0', 'snippet': {'publishedAt': '2023-05-21T17:15:35Z', 'channelId': 'UC7_YxT-KID8kRbqZo7MyscQ', 'title': 'The Return to Bloody Nights: Part 1', 'description': "The Return to Bloody Nights is an amazing Five Nights at Freddy's fan game that drops you in and never lets go. \n\nPlay The Return to Bloody Nights ► https://gamejolt.com/games/thereturntobloodynights/595647\n\nEdited By ► https://www.youtube.com/LixianTV\n\nScary Games Playlist ► https://www.youtube.com/playlist?list=PL3tRBEVW0hiBSFOFhTC5wt75P2BES0rAo\n\nHorror Outro ► https://soundcloud.com/shurkofficial/haunted", 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3HGvOnEY_A0/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/3HGvOnEY_A0/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/3HGvOnEY_A0/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/3HGvOnEY_A0/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/3HGvOnEY_A0/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'channelTitle': 'Markiplier', 'tags': ['markiplier', 'the return to bloody nights', 'part 1', "five nights at freddy's", 'fan game', 'fnaf'], 'categoryId': '20', 'liveBroadcastContent': 'none', 'defaultLanguage': 'en', 'localized': {'title': 'The Return to Bloody Nights: Part 1', 'description': "The Return to Bloody Nights is an amazing Five Nights at Freddy's fan game that drops you in and never lets go. \n\nPlay The Return to Bloody Nights ► https://gamejolt.com/games/thereturntobloodynights/595647\n\nEdited By ► https://www.youtube.com/LixianTV\n\nScary Games Playlist ► https://www.youtube.com/playlist?list=PL3tRBEVW0hiBSFOFhTC5wt75P2BES0rAo\n\nHorror Outro ► https://soundcloud.com/shurkofficial/haunted"}, 'defaultAudioLanguage': 'en'}, 'contentDetails': {'duration': 'PT35M48S', 'dimension': '2d', 'definition': 'hd', 'caption': 'false', 'licensedContent': True, 'contentRating': {}, 'projection': 'rectangular'}, 'statistics': {'viewCount': '1459414', 'likeCount': '112215', 'favoriteCount': '0', 'commentCount': '5356'}}, {'kind': 'youtube#video', 'etag': 'AHQI5HHz-RTQy9gg-aseVflgB04', 'id': 'LA4bwTqnCUk', 'snippet': {'publishedAt': '2023-05-21T06:10:30Z', 'channelId': 'UCbzRzJNHx7ZLlJML9BjZQVQ', 'title': 'Haney & Loma Put On Instant Classic | Haney Retains Undisputed Belts | FIGHT HIGHLIGHTS', 'description': "Watch #highlights from the main event of #haneyloma featuring #devinhaney and #vasiliylomachenko In the back and forth affair, it was Haney who won by decision to retain his undisputed belts.\n\nNext up for Top Rank Boxing,  Luis Alberto “El Venado” Lopez may have to start calling himself “The Road Warrior.” Lopez will make the first defense of his IBF featherweight world title against Michael “Mick” Conlan on Saturday, May 27, at The SSE Arena in Conlan’s hometown of Belfast.\n \nLopez captured the title last December, venturing to Josh Warrington’s home base of Leeds, England, to grind out a majority decision.\n \nLopez-Conlan and undercard bouts will stream live and exclusively on ESPN+ in the United States. BT Sport will broadcast the event in the UK and Ireland.\n \nTry ESPN+ For Free: https://watch.espnplus.com/toprank/\n\nSubscribe to our YouTube channel to get notified about the latest highlights, free full fights, and fight week content as it's posted.\n\nFollow Top Rank on Twitter: http://www.twitter.com/trboxing\nFollow Top Rank on Instagram: http://www.instagram.com/toprank\nLike Top Rank on Facebook: http://www.facebook.com/trboxing", 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LA4bwTqnCUk/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/LA4bwTqnCUk/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'htt ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 6
#       4 print (response)
#       5 print (response.json())
# ----> 6 df = pd.DataFrame(json_data)
#       8 file_path = 'Deskstop/Data Science/Youtube.tsv'
#       9 df.to_csv(file_path, sep = '\t', index=false)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:664, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     658     mgr = self._init_mgr(
#     659         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     660     )
#     662 elif isinstance(data, dict):
#     663     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 664     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     665 elif isinstance(data, ma.MaskedArray):
#     666     import numpy.ma.mrecords as mrecords
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/internals/construction.py:493, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     489     else:
#     490         # dtype check to exclude e.g. range objects, scalars
#     491         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 493 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/internals/construction.py:118, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     115 if verify_integrity:
#     116     # figure out the index, if necessary
#     117     if index is None:
# --> 118         index = _extract_index(arrays)
#     119     else:
#     120         index = ensure_index(index)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/internals/construction.py:669, in _extract_index(data)
#     666     raise ValueError("All arrays must be of the same length")
#     668 if have_dicts:
# --> 669     raise ValueError(
#     670         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     671     )
#     673 if have_series:
#     674     assert index is not None  # for mypy
#
# ValueError: Mixing dicts with non-Series may lead to ambiguous ordering.
