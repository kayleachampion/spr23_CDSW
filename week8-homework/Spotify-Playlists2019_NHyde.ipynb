# %% [markdown]
# Spotify Boilerplate

# %%
import spotipy 

from spotify_authentication import SPOTIPY_CLIENT_ID
from spotify_authentication import SPOTIPY_CLIENT_SECRET

from spotipy.oauth2 import SpotifyClientCredentials

# %%
#/playlists/{playlist_id}/tracks

#playlist_tracks(playlist_id, fields=None, limit=100, offset=0, market=None, additional_types=('track', ))

#uri = 'spotify:artist:0oSGxfWSnnOXhD2fKuz2Gy'

spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id=SPOTIPY_CLIENT_ID, client_secret=SPOTIPY_CLIENT_SECRET))
#This is the playlist API for 2019 Top Tracks. 
results = spotify.playlist_tracks("37i9dQZF1DWVRSukIED0e9")
items = results['items']

track_list = r"C:\Users\Nicke\OneDrive\Desktop\CommunityDataScience\2019_playlist_ids.txt"

with open(track_list, 'w') as output_file:

    for item in items:
        track_data = item['track']
        track_id = track_data['id']
    
        print(track_id, file=output_file)

# %%
for item in items:
    track_data = item['track']
    track_id = track_data['id']
    
    track_name =  track_data['name']
    
    print(track_id, track_name)
# Out:
# 2YpeDb67231RjR0MgVLzsG Old Town Road - Remix
# 2Fxmhks0bxGSBdJ92vM42m bad guy
# 6v3KW9xbzN5yKLt9YKDYA2 Señorita
# 6ocbgoVGwYJhOv1GgI9NsF 7 rings
# 0RiRZpuVRbi7oqRdSMwhQY Sunflower - Spider-Man: Into the Spider-Verse
# 1BxfuPKGuaTgP7aM0Bbdwr Cruel Summer
# 5p7ujcrUXASCNwRaWNHR1C Without Me
# 0u2P5u6lvoDfwTYjAADbn4 lovely (with Khalid)
# 2VxeLyX666F8uXCJ0dZF8B Shallow
# 2qxmye6gAegTMjLKEBoR3d Let Me Down Slowly
# 7qEHsqek33rTcFNT9PFqLf Someone You Loved
# 2vXKRlJBXyOcvZYTdNeckS Lost in the Fire (feat. The Weeknd)
# 21jGcNKet2qwijlDFuPiPb Circles
# 43zdsphuZLzwA9k4DJhU0I when the party's over
# 2xLMifQCjDGFmkHkpNLD9h SICKO MODE
# 1dGr1c8CrMLDpV6mPbImSI Lover
# 0Oqc0kKFsQ6MhFOLBNZIGX Doin' Time
# 5hVghJ4KaYES3BFUATCYn0 EARFQUAKE
# 2JvzF1RMd7lE3KmFlsyZD8 MIDDLE CHILD
# 1rqqCSm0Qe4I9rUvWncaom High Hopes
# 4l0Mvzj72xxOpRrp6h8nHi Lose You To Love Me
# 7xQAfvXzm3AkraOtGPWIZg Wow.
# 2t8yVaLvJ0RenpXUIAC52d a lot
# 4Of7rzpRpV1mWRbhp5rAqG Bruises
# 3e9HZxeyfWwjeyPAMmWSSQ thank u, next
# ...
