# %%
import pandas as pd
import requests
import json

# %%
requests.get ('https://data.seattle.gov/resource/tmmm-ytt6.json')
# Out:
# <Response [200]>

# %%
import requests

query="Library_Data" #Define query
url = f"https://data.seattle.gov/resource/tmmm-ytt6.json?checkoutyear=2023&$limit=1000&$offset=1000"
request = requests.get(url)
json_response = request.json()
json_response
# Out:
# [{'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '2',
#   'title': 'Principle-Centered Leadership',
#   'isbn': '9780795309496',
#   'creator': 'Stephen R. Covey',
#   'subjects': 'Self-Improvement, Nonfiction',
#   'publisher': 'RosettaBooks',
#   'publicationyear': '2012'},
#  {'usageclass': 'Physical',
#   'checkouttype': 'Horizon',
#   'materialtype': 'SOUNDDISC',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '2',
#   'title': 'Eat to the beat / Blondie.',
#   'creator': 'Blondie (Musical group)',
#   'subjects': 'Rock music 1971 1980, New wave music',
#   'publisher': 'Capitol/Chrysalis,',
#   'publicationyear': '[2001]'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'AUDIOBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Delete All Suspects (unabridged)',
#   'isbn': '9781666551358',
#   'creator': 'Donna Andrews',
#   'subjects': 'Fiction, Mystery',
#   'publisher': 'Dreamscape Media, LLC',
#   'publicationyear': '2020'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'What Are Castles and Knights?',
#   'isbn': '9780593226889',
#   'creator': 'Sarah Fabiny',
#   'subjects': 'History, Juvenile Nonfiction, Geography',
#   'publisher': 'Penguin Group (USA), Inc.',
#   'publicationyear': '2022'},
#  {'usageclass': 'Physical',
#   'checkouttype': 'Horizon',
#   'materialtype': 'SOUNDDISC',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Do to the beast / Afghan Whigs.',
#   'creator': 'Afghan Whigs (Musical group)',
#   'subjects': 'Rock music 2011 2020',
#   'publisher': 'Sub Pop,',
#   'publicationyear': '[2014]'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '3',
#   'title': 'Secrets of the Tulip Sisters: A Novel',
#   'isbn': '9781488023224',
#   'creator': 'Susan Mallery',
#   'subjects': 'Fiction, Literature, Romance',
#   'publisher': 'Harlequin Enterprises, Ltd.',
#   'publicationyear': '2017'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'AUDIOBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '2',
#   'title': 'The Way to Bea (unabridged)',
#   'isbn': '9781478994299',
#   'creator': 'Kat Yeh',
#   'subjects': 'Juvenile Fiction, Juvenile Literature',
#   'publisher': 'Hachette Audio',
#   'publicationyear': '2017'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '8',
#   'title': 'The Devil Takes You Home: A Novel',
#   'isbn': '9780316426817',
#   'creator': 'Gabino Iglesias',
#   'subjects': 'Fiction, Suspense, Thriller',
#   'publisher': 'Hachette Digital, Inc.',
#   'publicationyear': '2022'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '2',
#   'title': 'Human Voices',
#   'isbn': '9780544227682',
#   'creator': 'Penelope Fitzgerald',
#   'subjects': 'Fiction, Literature',
#   'publisher': 'Houghton Mifflin Harcourt Trade and Reference',
#   'publicationyear': '2014'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '4',
#   'title': 'A Stranger in Olondria: a novel',
#   'isbn': '9781931520775',
#   'creator': 'Sofia Samatar',
#   'subjects': 'Fantasy, Fiction, Literature',
#   'publisher': 'Lightning Source Inc',
#   'publicationyear': '2013'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Get Lost, Odysseus!',
#   'isbn': '9781496500786',
#   'creator': 'Kate McMullan',
#   'subjects': 'Juvenile Fiction, Juvenile Literature, Mythology, Humor (Fiction)',
#   'publisher': 'Capstone',
#   'publicationyear': '2014'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'AUDIOBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '3',
#   'title': 'The Extractionist (unabridged)',
#   'isbn': '9781705044582',
#   'creator': 'Kimberly Unger',
#   'subjects': 'Fiction, Science Fiction',
#   'publisher': 'Recorded Books, LLC',
#   'publicationyear': '2022'},
#  {'usageclass': 'Physical',
#   'checkouttype': 'Horizon',
#   'materialtype': 'SOUNDDISC',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Songs without jokes / by Bret McKenzie.',
#   'creator': 'McKenzie, Bret',
#   'subjects': 'Popular music 2021 2030, Popular music',
#   'publisher': 'Sub Pop,',
#   'publicationyear': '[2022]'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Cut-Throat Dogs: Amos Walker Series, Book 29',
#   'isbn': '9781250258649',
#   'creator': 'Loren D. Estleman',
#   'subjects': 'Fiction, Mystery',
#   'publisher': 'Macmillan Publishers',
#   'publicationyear': '2022'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'AUDIOBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '4',
#   'title': 'Luda: A Novel (unabridged)',
#   'isbn': '9780593633137',
#   'creator': 'Grant Morrison',
#   'subjects': 'Fiction, Literature, Thriller',
#   'publisher': 'Books on Tape',
#   'publicationyear': '2022'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'I Am Perfectly Designed',
#   'isbn': '9781250762221',
#   'creator': 'Karamo Brown',
#   'subjects': 'Juvenile Fiction, Picture Book Fiction',
#   'publisher': 'Macmillan Publishers',
#   'publicationyear': '2019'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '3',
#   'title': 'The Lost Girls of Camp Forevermore: A Novel',
#   'isbn': '9780544227323',
#   'creator': 'Kim Fu',
#   'subjects': 'Fiction, Literature',
#   'publisher': 'Open Road Integrated Media',
#   'publicationyear': '2018'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '6',
#   'title': 'In a Lonely Place',
#   'isbn': '9781681371481',
#   'creator': 'Dorothy B. Hughes',
#   'subjects': 'Fiction, Mystery, Suspense, Thriller',
#   'publisher': 'Random House, Inc.',
#   'publicationyear': '2017'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'AUDIOBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Conagher: A Novel (unabridged)',
#   'isbn': '9781524783426',
#   'creator': "Louis L'Amour",
#   'subjects': 'Fiction, Western, Thriller, Historical Fiction',
#   'publisher': 'Books on Tape',
#   'publicationyear': '2019'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'AUDIOBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '2',
#   'title': 'Light in August (unabridged)',
#   'isbn': '9780739345405',
#   'creator': 'William Faulkner',
#   'subjects': 'Classic Literature, Fiction, Literature',
#   'publisher': 'Books on Tape',
#   'publicationyear': '2006'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'The Crush',
#   'isbn': '9781455546404',
#   'creator': 'Sandra Brown',
#   'subjects': 'Fiction, Romance, Suspense, Thriller',
#   'publisher': 'Hachette Digital, Inc.',
#   'publicationyear': '2013'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'AUDIOBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '18',
#   'title': 'The Left Hand of Darkness (unabridged)',
#   'isbn': '9781501910111',
#   'creator': 'Ursula K. Le Guin',
#   'subjects': 'Fiction, Science Fiction',
#   'publisher': 'Recorded Books, LLC',
#   'publicationyear': '2019'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'AUDIOBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Awayland: Stories (unabridged)',
#   'isbn': '9780525528418',
#   'creator': 'Ramona Ausubel',
#   'subjects': 'Fiction, Literature, Short Stories',
#   'publisher': 'Books on Tape',
#   'publicationyear': '2018'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'AUDIOBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Telling Tails (unabridged)',
#   'isbn': '9781515992363',
#   'creator': 'Sofie Ryan',
#   'subjects': 'Fiction, Mystery',
#   'publisher': 'Tantor Media, Inc',
#   'publicationyear': '2017'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'AUDIOBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Ticktock: A Novel (unabridged)',
#   'isbn': '9781415947722',
#   'creator': 'Dean Koontz',
#   'subjects': 'Fiction, Horror, Suspense, Thriller',
#   'publisher': 'Books on Tape',
#   'publicationyear': '2008'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Nobody from Somewhere: A Crime Novel',
#   'isbn': '9781773059105',
#   'creator': 'Dietrich Kalteis',
#   'subjects': 'Fiction, Mystery',
#   'publisher': 'ECW Press Ltd.',
#   'publicationyear': '2022'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'AUDIOBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '3',
#   'title': 'Scandal in Skibbereen (unabridged)',
#   'isbn': '9781452699189',
#   'creator': 'Sheila Connolly',
#   'subjects': 'Fiction, Literature, Mystery',
#   'publisher': 'Tantor Media, Inc',
#   'publicationyear': '2015'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '2',
#   'title': 'Marked',
#   'isbn': '9781601831545',
#   'creator': 'Rebecca Zanetti',
#   'subjects': 'Fantasy, Fiction, Romance, Suspense',
#   'publisher': 'Lightning Source Inc',
#   'publicationyear': '2015'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '3',
#   'title': 'Greek Tycoon, Waitress Wife',
#   'isbn': '9781426822711',
#   'creator': 'Julia James',
#   'subjects': 'Fiction, Romance',
#   'publisher': 'Harlequin Enterprises, Ltd.',
#   'publicationyear': '2008'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': "Red Hood's Revenge",
#   'isbn': '9781101188675',
#   'creator': 'Jim C. Hines',
#   'subjects': 'Fiction, Mythology, Thriller, Historical Fiction',
#   'publisher': 'Random House, Inc.',
#   'publicationyear': '2013'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '4',
#   'title': 'The Lost Husband: A Novel',
#   'isbn': '9780345538918',
#   'creator': 'Katherine Center',
#   'subjects': 'Fiction, Literature, Humor (Fiction)',
#   'publisher': 'Random House, Inc.',
#   'publicationyear': '2013'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'The Lightkeeper',
#   'isbn': '9781426828638',
#   'creator': 'SUSAN WIGGS',
#   'subjects': 'Fiction, Romance, Historical Fiction',
#   'publisher': 'Harlequin Enterprises, Ltd.',
#   'publicationyear': '2009'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'AUDIOBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '2',
#   'title': 'The Gauntlet and the Fist Beneath (unabridged)',
#   'isbn': '9781803281797',
#   'creator': 'Ian Green',
#   'subjects': 'Fiction, Science Fiction',
#   'publisher': 'W. F. Howes Ltd.',
#   'publicationyear': '2022'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Child of Flame',
#   'isbn': '9781101639825',
#   'creator': 'Kate Elliott',
#   'subjects': 'Fantasy, Fiction, Literature, Science Fiction',
#   'publisher': 'Random House, Inc.',
#   'publicationyear': '2013'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Trafalgar Sunrise',
#   'isbn': '9789814828444',
#   'creator': 'Danielle Lim',
#   'subjects': 'Fiction, Literature',
#   'publisher': 'Marshall Cavendish Internationl (Asia) Pte Ltd',
#   'publicationyear': '2022'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'The Noel Letters',
#   'isbn': '9781982129613',
#   'creator': 'Richard Paul Evans',
#   'subjects': 'Fiction, Literature',
#   'publisher': 'Simon & Schuster, Inc.',
#   'publicationyear': '2020'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'John Henry Days',
#   'isbn': '9780307486677',
#   'creator': 'Colson Whitehead',
#   'subjects': 'Fiction, Literature, Thriller, Historical Fiction',
#   'publisher': 'Random House, Inc.',
#   'publicationyear': '2011'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '3',
#   'title': 'Six Days of the Condor: Condor Series, Book 1',
#   'isbn': '9781453229231',
#   'creator': 'James  Grady',
#   'subjects': 'Fiction, Thriller',
#   'publisher': 'Open Road Integrated Media',
#   'publicationyear': '2015'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '17',
#   'title': 'Stone Blind: A Novel',
#   'isbn': '9780063258419',
#   'creator': 'Natalie Haynes',
#   'subjects': 'Classic Literature, Fiction, Literature',
#   'publisher': 'HarperCollins Publishers Inc.',
#   'publicationyear': '2023'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'AUDIOBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Targeted (unabridged)',
#   'isbn': '9781494527129',
#   'creator': 'Katie Reus',
#   'subjects': 'Fiction, Romance, Suspense, Thriller',
#   'publisher': 'Tantor Media, Inc',
#   'publicationyear': '2015'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'AUDIOBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '2',
#   'title': 'Tailing a Tabby (unabridged)',
#   'isbn': '9781977320575',
#   'creator': 'Laurie Cass',
#   'subjects': 'Fiction, Mystery',
#   'publisher': 'Tantor Media, Inc',
#   'publicationyear': '2022'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'AUDIOBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Perfume River: A Novel (unabridged)',
#   'isbn': '9781681683270',
#   'creator': 'Robert Olen Butler',
#   'subjects': 'Fiction, Literature',
#   'publisher': 'HighBridge Company',
#   'publicationyear': '2016'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': "All God's Dangers",
#   'isbn': '9780307831910',
#   'creator': 'Theodore Rosengarten',
#   'subjects': 'Biography & Autobiography, Sociology, Nonfiction',
#   'publisher': 'Random House, Inc.',
#   'publicationyear': '2014'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Half-light: Collected Poems 1965-2016',
#   'isbn': '9780374715182',
#   'creator': 'Frank Bidart',
#   'subjects': 'Fiction, Poetry',
#   'publisher': 'Macmillan Publishers',
#   'publicationyear': '2017'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '5',
#   'title': 'Battle of the Linguist Mages',
#   'isbn': '9781250767691',
#   'creator': 'Scotto Moore',
#   'subjects': 'Fiction, Science Fiction',
#   'publisher': 'Macmillan Publishers',
#   'publicationyear': '2022'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': "When I'm Gone: Rosemary Beach Series, Book 11",
#   'isbn': '9781476776101',
#   'creator': 'Abbi Glines',
#   'subjects': 'Fiction, Romance',
#   'publisher': 'Simon & Schuster, Inc.',
#   'publicationyear': '2015'},
#  {'usageclass': 'Physical',
#   'checkouttype': 'Horizon',
#   'materialtype': 'BOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Japan / by Dorothy Wood ; photographs by Lucy Mason.',
#   'isbn': '081182814X',
#   'creator': 'Wood, Dorothy, 1955-',
#   'subjects': 'Handicraft Japan',
#   'publisher': 'Chronicle Books,',
#   'publicationyear': '2000.'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '2',
#   'title': 'Akin',
#   'isbn': '9780316491983',
#   'creator': 'Emma Donoghue',
#   'subjects': 'Fiction, Literature, Historical Fiction',
#   'publisher': 'Hachette Digital, Inc.',
#   'publicationyear': '2019'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '2',
#   'title': 'Faces of Love: Hafez and the Poets of Shiraz',
#   'isbn': '9781101627174',
#   'creator': 'Dick Davis',
#   'subjects': 'Fiction, Poetry',
#   'publisher': 'Penguin Group (USA), Inc.',
#   'publicationyear': '2013'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '2',
#   'title': 'Safe in My Arms',
#   'isbn': '9781524746797',
#   'creator': 'Sara Shepard',
#   'subjects': 'Fiction, Literature, Thriller',
#   'publisher': 'Penguin Group (USA), Inc.',
#   'publicationyear': '2021'},
#  {'usageclass': 'Physical',
#   'checkouttype': 'Horizon',
#   'materialtype': 'SOUNDDISC',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Bonnie Raitt.',
#   'creator': 'Raitt, Bonnie',
#   'subjects': 'Popular music 1971 1980, Blues Music 1971 1980, Rock music 1971 1980',
#   'publisher': 'Warner Bros.,',
#   'publicationyear': '[2001]'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'AUDIOBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Did You Ever Have a Family (unabridged)',
#   'isbn': '9781442385276',
#   'creator': 'Bill  Clegg',
#   'subjects': 'Fiction, Literature',
#   'publisher': 'Simon & Schuster - Audiobooks',
#   'publicationyear': '2015'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Essays of Travel',
#   'isbn': '9781620119037',
#   'creator': 'Robert Louis Stevenson',
#   'subjects': 'Multi-Cultural, Travel, Nonfiction',
#   'publisher': 'Duke Classics',
#   'publicationyear': '2021'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '3',
#   'title': 'The Noise of Time: A novel',
#   'isbn': '9781101947258',
#   'creator': 'Julian Barnes',
#   'subjects': 'Fiction, Literature, Historical Fiction',
#   'publisher': 'Random House, Inc.',
#   'publicationyear': '2016'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'The Great Weaver From Kashmir',
#   'isbn': '9780981987361',
#   'creator': 'Halldor Laxness',
#   'subjects': 'Fiction, Literature',
#   'publisher': 'Random House, Inc.',
#   'publicationyear': '2013'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '2',
#   'title': 'The Fran Lebowitz Reader',
#   'isbn': '9780307744937',
#   'creator': 'Fran Lebowitz',
#   'subjects': 'Fiction, Literary Anthologies',
#   'publisher': 'Random House, Inc.',
#   'publicationyear': '2012'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'AUDIOBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '2',
#   'title': 'The Batboy (unabridged)',
#   'isbn': '9781101976814',
#   'creator': 'Mike Lupica',
#   'subjects': 'Juvenile Fiction, Juvenile Literature',
#   'publisher': 'Books on Tape',
#   'publicationyear': '2010'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '3',
#   'title': 'Deep South',
#   'isbn': '9780544323537',
#   'creator': 'Paul Theroux',
#   'subjects': 'Biography & Autobiography, Travel, Nonfiction',
#   'publisher': 'Open Road Integrated Media',
#   'publicationyear': '2015'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '3',
#   'title': 'Big Game: FunJungle Series, Book 3',
#   'isbn': '9781481423359',
#   'creator': 'Stuart Gibbs',
#   'subjects': 'Juvenile Fiction, Mystery',
#   'publisher': 'Simon & Schuster, Inc.',
#   'publicationyear': '2015'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'The Cartels Jungle',
#   'isbn': '9781620137352',
#   'creator': 'Irving E. Cox',
#   'subjects': 'Fantasy, Fiction, Science Fiction',
#   'publisher': 'Duke Classics',
#   'publicationyear': '2021'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'AUDIOBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Missing Person (unabridged)',
#   'isbn': '9781504663199',
#   'creator': 'Patrick Modiano',
#   'subjects': 'Fiction, Literature, Mystery',
#   'publisher': 'Blackstone Audio, Inc.',
#   'publicationyear': '2016'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Anything Considered: A Novel',
#   'isbn': '9780307791931',
#   'creator': 'Peter Mayle',
#   'subjects': 'Fiction, Literature, Mystery, Humor (Fiction)',
#   'publisher': 'Random House, Inc.',
#   'publicationyear': '2013'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'A Love Like This',
#   'isbn': '9780369700940',
#   'creator': 'Diana Palmer',
#   'subjects': 'Fiction, Literature, Romance',
#   'publisher': 'Harlequin Enterprises, Ltd.',
#   'publicationyear': '2021'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '3',
#   'title': 'Fortunes of War',
#   'isbn': '9781590177037',
#   'creator': 'Olivia Manning',
#   'subjects': 'Fiction, Literature, Historical Fiction',
#   'publisher': 'Random House, Inc.',
#   'publicationyear': '2014'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '5',
#   'title': 'Mrs. Pollifax and the Second Thief',
#   'isbn': '9780593159521',
#   'creator': 'Dorothy Gilman',
#   'subjects': 'Fiction, Mystery, Suspense, Thriller',
#   'publisher': 'Random House, Inc.',
#   'publicationyear': '2021'},
#  {'usageclass': 'Physical',
#   'checkouttype': 'Horizon',
#   'materialtype': 'SOUNDDISC',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Exploding head / a Place to Bury Strangers.',
#   'creator': 'Place to Bury Strangers (Musical group)',
#   'subjects': 'Rock music 2001 2010',
#   'publisher': 'Mute,',
#   'publicationyear': '[2009]'},
#  {'usageclass': 'Physical',
#   'checkouttype': 'Horizon',
#   'materialtype': 'BOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Reapers of the dust; a prairie chronicle.',
#   'creator': 'Hudson, Lois Phillips, 1927-2010',
#   'publisher': 'Little, Brown,',
#   'publicationyear': '[1964]'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Down Home with the Neelys',
#   'isbn': '9780307767578',
#   'creator': 'Pat Neely',
#   'subjects': 'Cooking & Food, Nonfiction',
#   'publisher': 'Random House, Inc.',
#   'publicationyear': '2010'},
#  {'usageclass': 'Physical',
#   'checkouttype': 'Horizon',
#   'materialtype': 'SOUNDDISC',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Visions of a life / Wolf Alice.',
#   'creator': 'Wolf Alice (Musical group)',
#   'subjects': 'Rock music 2011 2020, Rock music',
#   'publisher': 'RCA,',
#   'publicationyear': '[2017]'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Vera: A Novel',
#   'isbn': '9781501157547',
#   'creator': 'Carol Edgarian',
#   'subjects': 'Fiction, Literature, Historical Fiction',
#   'publisher': 'Simon & Schuster, Inc.',
#   'publicationyear': '2021'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '7',
#   'title': 'My Year Abroad: A Novel',
#   'isbn': '9780698407046',
#   'creator': 'Chang-rae Lee',
#   'subjects': 'Fiction, Literature',
#   'publisher': 'Penguin Group (USA), Inc.',
#   'publicationyear': '2021'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '3',
#   'title': 'The Great Fire: A Novel',
#   'isbn': '9780374706357',
#   'creator': 'Shirley Hazzard',
#   'subjects': 'Fiction, Literature',
#   'publisher': 'Macmillan Publishers',
#   'publicationyear': '2013'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Maybelle the Cable Car',
#   'isbn': '9780547422329',
#   'creator': 'Virginia Lee Burton',
#   'subjects': 'Juvenile Fiction',
#   'publisher': 'Houghton Mifflin Harcourt Trade and Reference',
#   'publicationyear': '2011'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'AUDIOBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '2',
#   'title': "Smiley's People (unabridged)",
#   'isbn': '9781408439920',
#   'creator': 'John le Carré',
#   'subjects': 'Fiction, Mystery, Thriller',
#   'publisher': 'Penguin Random House UK',
#   'publicationyear': '2010'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '2',
#   'title': 'Collected Poems: 1950-2012',
#   'isbn': '9780393285123',
#   'creator': 'Adrienne Rich',
#   'subjects': 'Fiction, Poetry, LGBTQIA+ (Fiction)',
#   'publisher': 'W. W. Norton & Company',
#   'publicationyear': '2016'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Conversion',
#   'isbn': '9780698158412',
#   'creator': 'Katherine Howe',
#   'subjects': 'Young Adult Fiction, Young Adult Literature',
#   'publisher': 'Penguin Group (USA), Inc.',
#   'publicationyear': '2014'},
#  {'usageclass': 'Physical',
#   'checkouttype': 'Horizon',
#   'materialtype': 'SOUNDDISC',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Minecraft. Volume Alpha / C418.',
#   'creator': 'C418 (Musician)',
#   'subjects': 'Video game music, Electronic music',
#   'publisher': 'Ghostly International,',
#   'publicationyear': '[2015]'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'AUDIOBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '13',
#   'title': 'Witchmark: Kingston Cycle, Book 1 (unabridged)',
#   'isbn': '9781980002000',
#   'creator': 'C.L. Polk',
#   'subjects': 'Fantasy, Fiction',
#   'publisher': 'Recorded Books, LLC',
#   'publicationyear': '2018'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '2',
#   'title': 'Weaving on a Little Loom',
#   'isbn': '9781616897796',
#   'creator': 'Fiona Daly',
#   'subjects': 'Crafts, Nonfiction',
#   'publisher': 'Chronicle Books',
#   'publicationyear': '2022'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '3',
#   'title': 'Playground',
#   'isbn': '9780061749537',
#   'creator': 'Jennifer Saginor',
#   'subjects': 'Biography & Autobiography, History, Nonfiction',
#   'publisher': 'HarperCollins Publishers Inc.',
#   'publicationyear': '2005'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'AUDIOBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '5',
#   'title': 'The Russian Cage (unabridged)',
#   'isbn': '9781501962813',
#   'creator': 'Charlaine Harris',
#   'subjects': 'Fantasy, Fiction, Romance',
#   'publisher': 'Recorded Books, LLC',
#   'publicationyear': '2021'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '3',
#   'title': 'The Roan Stallion',
#   'isbn': '9781939053718',
#   'creator': 'Alfreda Beartrack-Algeo',
#   'subjects': 'Juvenile Fiction, Juvenile Literature',
#   'publisher': 'eBooks2go,Inc.',
#   'publicationyear': '2023'},
#  {'usageclass': 'Physical',
#   'checkouttype': 'Horizon',
#   'materialtype': 'BOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Post-truth / Lee McIntyre.',
#   'isbn': '0262535041, 9780262535045',
#   'creator': 'McIntyre, Lee C.',
#   'subjects': 'Truth, Truthfulness and falsehood',
#   'publisher': 'The MIT Press,',
#   'publicationyear': '[2018]'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Gold Fever: Klondike Mystery Series, Book 2',
#   'isbn': '9781459706231',
#   'creator': 'Vicki Delany',
#   'subjects': 'Fiction, Mystery, Historical Fiction',
#   'publisher': 'Dundurn Press',
#   'publicationyear': '2013'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '3',
#   'title': 'The Horsewoman',
#   'isbn': '9780316499781',
#   'creator': 'James Patterson',
#   'subjects': 'Fiction, Literature, Romance, Thriller',
#   'publisher': 'Hachette Digital, Inc.',
#   'publicationyear': '2022'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'The House Swap',
#   'isbn': '9780063034556',
#   'creator': 'Yvette Clark',
#   'subjects': 'Juvenile Fiction, Juvenile Literature',
#   'publisher': 'HarperCollins Publishers Inc.',
#   'publicationyear': '2023'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '2',
#   'title': 'We Came Here to Forget: A Novel',
#   'isbn': '9781982103446',
#   'creator': 'Andrea Dunlop',
#   'subjects': 'Fiction, Literature',
#   'publisher': 'Simon & Schuster, Inc.',
#   'publicationyear': '2019'},
#  {'usageclass': 'Physical',
#   'checkouttype': 'Horizon',
#   'materialtype': 'BOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Deer / Jordan McGill.',
#   'isbn': '1616909366, 9781616909369',
#   'creator': 'McGill, Jordan',
#   'subjects': 'Deer Juvenile literature',
#   'publisher': 'AV2 by Weigl,',
#   'publicationyear': '[2012]'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'T. Rex Time Machine',
#   'isbn': '9781452161761',
#   'creator': 'Jared Chapman',
#   'subjects': 'Juvenile Fiction, Picture Book Fiction',
#   'publisher': 'Chronicle Books',
#   'publicationyear': '2019'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '2',
#   'title': 'The Sagas of the Icelanders',
#   'isbn': '9780141933269',
#   'creator': 'Jane Smiley',
#   'subjects': 'Classic Literature, Fiction, Literature',
#   'publisher': 'Penguin Random House UK',
#   'publicationyear': '2011'},
#  {'usageclass': 'Physical',
#   'checkouttype': 'Horizon',
#   'materialtype': 'SOUNDDISC',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'MGMT.',
#   'isbn': '5099967818129',
#   'subjects': 'Popular music 2011 2020, Rock music 2011 2020',
#   'publisher': 'Night Time Stories,',
#   'publicationyear': '[2011]'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'People in the Room',
#   'isbn': '9781911508236',
#   'creator': 'Norah Lange',
#   'subjects': 'Classic Literature, Fiction, Literature',
#   'publisher': 'Lightning Source Inc',
#   'publicationyear': '2018'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '2',
#   'title': 'Beyond the Ties of Blood: A Novel',
#   'isbn': '9781480416246',
#   'creator': 'Florencia Mallon',
#   'subjects': 'Fiction, Literature',
#   'publisher': 'Open Road Integrated Media',
#   'publicationyear': '2012'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Crash & Burn: Cut & Run Series, Book 9',
#   'isbn': '9781626492028',
#   'creator': 'Abigail Roux',
#   'subjects': 'Fiction, Romance, Suspense',
#   'publisher': 'Riptide Publishing',
#   'publicationyear': '2015'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '7',
#   'title': 'Angle of Repose',
#   'isbn': '9781101064382',
#   'creator': 'Wallace Stegner',
#   'subjects': 'Classic Literature, Fiction, Literature',
#   'publisher': 'Penguin Group (USA), Inc.',
#   'publicationyear': '2009'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Vanished',
#   'isbn': '9781101210963',
#   'creator': 'Karen Robards',
#   'subjects': 'Fiction, Romance, Suspense, Thriller',
#   'publisher': 'Penguin Group (USA), Inc.',
#   'publicationyear': '2011'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': "Alindarka's Children: Things Will Be Bad",
#   'isbn': '9780811231978',
#   'creator': 'Alhierd Bacharevic',
#   'subjects': 'Fiction, Literature',
#   'publisher': 'W. W. Norton & Company',
#   'publicationyear': '2022'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '2',
#   'title': 'Or What You Will',
#   'isbn': '9781250309013',
#   'creator': 'Jo Walton',
#   'subjects': 'Fantasy, Fiction, Historical Fiction',
#   'publisher': 'Macmillan Publishers',
#   'publicationyear': '2020'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Cleopatra',
#   'isbn': '9781620126202',
#   'creator': 'H. Rider Haggard',
#   'subjects': 'Fiction, Historical Fiction',
#   'publisher': 'Duke Classics',
#   'publicationyear': '2021'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'AUDIOBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '2',
#   'title': 'Breach of Duty: J. P. Beaumont Series, Book 14 (unabridged)',
#   'creator': 'J. A. Jance',
#   'subjects': 'Fiction, Mystery',
#   'publisher': 'Books In Motion',
#   'publicationyear': '2005'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '2',
#   'title': 'Why We Broke Up',
#   'isbn': '9780316194587',
#   'creator': 'Daniel Handler',
#   'subjects': 'Romance, Young Adult Fiction, Young Adult Literature',
#   'publisher': 'Hachette Digital, Inc.',
#   'publicationyear': '2013'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Caught Dead to Write: Cat Latimer Mysteries, #8',
#   'isbn': '9798215083987',
#   'creator': 'Lynn Cahoon',
#   'subjects': 'Fiction, Mystery',
#   'publisher': 'Draft2Digital, LLC',
#   'publicationyear': '2022'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Maelstrom: A Diving Universe Novella',
#   'isbn': '9781393142300',
#   'creator': 'Kristine Kathryn Rusch',
#   'subjects': 'Fiction, Science Fiction',
#   'publisher': 'Draft2Digital, LLC',
#   'publicationyear': '2022'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'AUDIOBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Here in Berlin (unabridged)',
#   'isbn': '9781666593167',
#   'creator': 'Cristina Garcia',
#   'subjects': 'Fiction, Literature, Historical Fiction',
#   'publisher': 'Dreamscape Media, LLC',
#   'publicationyear': '2018'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'AUDIOBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Wicked River (unabridged)',
#   'isbn': '9781666607628',
#   'creator': 'Jenny Milchman',
#   'subjects': 'Fiction, Literature, Suspense, Thriller',
#   'publisher': 'Dreamscape Media, LLC',
#   'publicationyear': '2018'},
#  {'usageclass': 'Physical',
#   'checkouttype': 'Horizon',
#   'materialtype': 'SOUNDDISC',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '2',
#   'title': 'Schmilco / Wilco.',
#   'creator': 'Wilco (Musical group)',
#   'subjects': 'Rock music 2011 2020, Rock music',
#   'publisher': 'dBpm Records : ANTI- ,',
#   'publicationyear': '[2016]'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'AUDIOBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '4',
#   'title': "The Kitchen God's Wife (unabridged)",
#   'creator': 'Amy Tan',
#   'subjects': 'Fiction, Literature',
#   'publisher': 'Independent Publishers Group',
#   'publicationyear': '2017'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Rickshaw Girl',
#   'isbn': '9781607345077',
#   'creator': 'Mitali Perkins',
#   'subjects': 'Juvenile Fiction, Juvenile Literature',
#   'publisher': 'Random House, Inc.',
#   'publicationyear': '2013'},
#  {'usageclass': 'Physical',
#   'checkouttype': 'Horizon',
#   'materialtype': 'SOUNDDISC',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Sunny side up / Paolo Nutini.',
#   'creator': 'Nutini, Paolo',
#   'subjects': 'Popular music 2001 2010, Rock music 2001 2010',
#   'publisher': 'Atlantic,',
#   'publicationyear': '[2009]'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '2',
#   'title': 'Sing You Home: A Novel',
#   'isbn': '9781439149713',
#   'creator': 'Jodi Picoult',
#   'subjects': 'Fiction, Literature',
#   'publisher': 'Simon & Schuster, Inc.',
#   'publicationyear': '2014'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'AUDIOBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '8',
#   'title': 'Sycamore Circle (unabridged)',
#   'isbn': '9781799921929',
#   'creator': 'Shelley Shepard Gray',
#   'subjects': 'Fiction, Mystery, Romance',
#   'publisher': 'Blackstone Audio, Inc.',
#   'publicationyear': '2023'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'AUDIOBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '3',
#   'title': 'The Darkest Game (unabridged)',
#   'isbn': '9781666535853',
#   'creator': 'Joseph Schneider',
#   'subjects': 'Fiction, Mystery, Suspense, Thriller',
#   'publisher': 'Dreamscape Media, LLC',
#   'publicationyear': '2022'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': '10Easy Origami: 8',
#   'isbn': '9781429647106',
#   'creator': 'Mary Meinking',
#   'subjects': 'Art, Crafts, Games, Juvenile Nonfiction',
#   'publisher': 'Capstone',
#   'publicationyear': '2012'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '5',
#   'title': 'Playing for Keeps: Hot Jocks, #1',
#   'isbn': '9781393757733',
#   'creator': 'Kendall Ryan',
#   'subjects': 'Fiction, Romance',
#   'publisher': 'Draft2Digital, LLC',
#   'publicationyear': '2019'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '2',
#   'title': 'Vital Parts: A Novel',
#   'isbn': '9781497674691',
#   'creator': 'Thomas Berger',
#   'subjects': 'Fiction, Literature, Humor (Fiction)',
#   'publisher': 'Open Road Integrated Media',
#   'publicationyear': '2023'},
#  {'usageclass': 'Physical',
#   'checkouttype': 'Horizon',
#   'materialtype': 'SOUNDDISC',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Couple tracks / Fucked Up.',
#   'creator': 'Fucked Up (Musical group)',
#   'subjects': 'Rock music 2001 2010, Punk rock music',
#   'publisher': 'Matador Records,',
#   'publicationyear': '[2009]'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '7',
#   'title': 'The Stars Undying',
#   'isbn': '9780316391597',
#   'creator': 'Emery Robin',
#   'subjects': 'Fantasy, Fiction, Romance, Science Fiction',
#   'publisher': 'Hachette Digital, Inc.',
#   'publicationyear': '2022'},
#  {'usageclass': 'Physical',
#   'checkouttype': 'Horizon',
#   'materialtype': 'BOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '3',
#   'title': 'Bicycle : the definitive visual history.',
#   'isbn': '1465443932, 9781465443939',
#   'subjects': 'Bicycles History, Bicycles Pictorial works',
#   'publisher': 'DK,',
#   'publicationyear': '2016.'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '48',
#   'title': 'Ms. Demeanor: A Novel',
#   'isbn': '9780063280298',
#   'creator': 'Elinor Lipman',
#   'subjects': 'Fiction, Literature',
#   'publisher': 'HarperCollins Publishers Inc.',
#   'publicationyear': '2023'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '1',
#   'title': 'Emerald Embrace',
#   'isbn': '9781605421087',
#   'creator': 'Shannon Drake',
#   'subjects': 'Fiction, Romance, Historical Fiction',
#   'publisher': 'Perseus Books Group',
#   'publicationyear': '2010'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '3',
#   'title': 'Claudius the God',
#   'isbn': '9780795337017',
#   'creator': 'Robert Graves',
#   'subjects': 'Fiction, Literature, Historical Fiction',
#   'publisher': 'Open Road Integrated Media',
#   'publicationyear': '2017'},
#  {'usageclass': 'Physical',
#   'checkouttype': 'Horizon',
#   'materialtype': 'SOUNDDISC',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '3',
#   'title': 'Sister / Sonic Youth.',
#   'creator': 'Sonic Youth (Musical group)',
#   'subjects': 'Rock music 1981 1990, Rock music',
#   'publisher': "[Goofin'],",
#   'publicationyear': '[2016]'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '5',
#   'title': 'The Map of Salt and Stars: A Novel',
#   'isbn': '9781501169106',
#   'creator': 'Zeyn Joukhadar',
#   'subjects': 'Fiction, Literature, Mythology',
#   'publisher': 'Simon & Schuster, Inc.',
#   'publicationyear': '2018'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '3',
#   'title': 'The Chaperone',
#   'isbn': '9781101585658',
#   'creator': 'Laura Moriarty',
#   'subjects': 'Fiction, Literature, Historical Fiction',
#   'publisher': 'Penguin Group (USA), Inc.',
#   'publicationyear': '2013'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '10',
#   'title': 'A History of Present Illness: A Novel',
#   'isbn': '9780316381284',
#   'creator': 'Anna DeForest',
#   'subjects': 'Fiction, Literature',
#   'publisher': 'Hachette Digital, Inc.',
#   'publicationyear': '2022'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '8',
#   'title': 'On Chesil Beach',
#   'isbn': '9780307455826',
#   'creator': 'Ian McEwan',
#   'subjects': 'Fiction, Literature, Historical Fiction',
#   'publisher': 'Random House, Inc.',
#   'publicationyear': '2009'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '6',
#   'title': 'The Deal of a Lifetime',
#   'isbn': '9781501193507',
#   'creator': 'Fredrik Backman',
#   'subjects': 'Fiction, Literature',
#   'publisher': 'Simon & Schuster, Inc.',
#   'publicationyear': '2017'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '4',
#   'title': 'Star Wars: Shadow of the Sith',
#   'isbn': '9780593358610',
#   'creator': 'Adam Christopher',
#   'subjects': 'Fiction, Literature, Science Fiction',
#   'publisher': 'Random House, Inc.',
#   'publicationyear': '2022'},
#  {'usageclass': 'Physical',
#   'checkouttype': 'Horizon',
#   'materialtype': 'SOUNDDISC',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '2',
#   'title': 'Cello sonatas / Reger.',
#   'creator': 'Reger, Max, 1873-1916',
#   'subjects': 'Sonatas Cello and piano, Suites Cello',
#   'publisher': 'Hyperion,',
#   'publicationyear': '[2008]'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '2',
#   'checkouts': '3',
#   'title': 'The Torqued Man: A Novel',
#   'isbn': '9780063072121',
#   'creator': 'Peter Mann',
#   'subjects': 'Fiction, Historical Fiction',
#   'publisher': 'HarperCollins Publishers Inc.',
# ...
#   'creator': 'Collins, Shirley, 1935-',
#   'subjects': 'Folk music Great Britain, Folk music United States, Folk music',
#   'publisher': 'Domino Recording Co.,',
#   'publicationyear': '[2016]'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '1',
#   'checkouts': '1',
#   'title': 'The Romanov Sisters: The Lost Lives of the Daughters of Nicholas and Alexandra',
#   'isbn': '9781250020215',
#   'creator': 'Helen Rappaport',
#   'subjects': 'Biography & Autobiography, History, Nonfiction',
#   'publisher': 'Macmillan Publishers',
#   'publicationyear': '2014'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '1',
#   'checkouts': '2',
#   'title': 'No Mistress of Mine',
#   'isbn': '9780062334688',
#   'creator': 'Laura Lee Guhrke',
#   'subjects': 'Fiction, Literature, Romance, Historical Fiction',
#   'publisher': 'HarperCollins Publishers Inc.',
#   'publicationyear': '2016'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '1',
#   'checkouts': '4',
#   'title': 'Ravenspur: Wars of the Roses Series, Book 4',
#   'isbn': '9781681776873',
#   'creator': 'Conn Iggulden',
#   'subjects': 'Fiction, Literature, Historical Fiction',
#   'publisher': 'Simon & Schuster, Inc.',
#   'publicationyear': '2017'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'AUDIOBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '1',
#   'checkouts': '1',
#   'title': 'Weight Loss for People Who Feel Too Much: A 4-Step, 8-Week Plan to Finally Lose the Weight, Manage Emotional Eating, and Find Your Fabulous Self (unabridged)',
#   'isbn': '9780385360708',
#   'creator': 'Colette Baron-Reid',
#   'subjects': 'Health & Fitness, Self-Improvement, Nonfiction',
#   'publisher': 'Books on Tape',
#   'publicationyear': '2013'},
#  {'usageclass': 'Physical',
#   'checkouttype': 'Horizon',
#   'materialtype': 'BOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '1',
#   'checkouts': '1',
#   'title': 'The adrenal reset diet : strategically cycle carbs and proteins to lose weight, balance hormones, and move from stressed to thriving / Alan Christianson ; [foreword by Sara Gottfried].',
#   'isbn': '0804140537, 9780804140539',
#   'creator': 'Christianson, Alan',
#   'subjects': 'Weight loss, Weight loss Endocrine aspects, Metabolism Regulation, Adrenal glands, Reducing diets',
#   'publisher': 'Harmony Books,',
#   'publicationyear': 'c2014.'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '1',
#   'checkouts': '1',
#   'title': 'Mistress Wilding',
#   'isbn': '9781620125168',
#   'creator': 'Rafael Sabatini',
#   'subjects': 'Fiction, Literature, Romance, Historical Fiction',
#   'publisher': 'Duke Classics',
#   'publicationyear': '2021'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'AUDIOBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '1',
#   'checkouts': '3',
#   'title': 'Jesus Always, with Scripture References: Embracing Joy in His Presence (a 365-Day Devotional) (unabridged)',
#   'isbn': '9780718092368',
#   'creator': 'Sarah Young',
#   'subjects': 'Christian Nonfiction, Religion & Spirituality, Nonfiction',
#   'publisher': 'HarperCollins Christian Publishing',
#   'publicationyear': '2017'},
#  {'usageclass': 'Physical',
#   'checkouttype': 'Horizon',
#   'materialtype': 'BOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '1',
#   'checkouts': '1',
#   'title': 'The color of money / Walter Tevis.',
#   'isbn': '1560254858, 9781560254850',
#   'creator': 'Tevis, Walter S.',
#   'subjects': 'Pool Game Fiction',
#   'publisher': "Thunder's Mouth Press ; Distributed by Publishers Group West,",
#   'publicationyear': '[2003?]'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '1',
#   'checkouts': '2',
#   'title': 'Gender Swapped Fairy Tales',
#   'isbn': '9780571360208',
#   'creator': 'Karrie Fransman',
#   'subjects': 'Classic Literature, Fiction, Mythology',
#   'publisher': 'Faber and Faber Ltd',
#   'publicationyear': '2021'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '1',
#   'checkouts': '1',
#   'title': 'Match: A Medical Murder Mystery',
#   'isbn': '9781647420192',
#   'creator': 'Amy S. Peele',
#   'subjects': 'Fiction, Literature, Mystery',
#   'publisher': 'Lightning Source Inc',
#   'publicationyear': '2022'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '1',
#   'checkouts': '2',
#   'title': 'Khann: Vaxxlian Alien Mail Order Brides (Intergalactic Dating Agency), #5',
#   'isbn': '9781393535348',
#   'creator': 'Sue Mercury',
#   'subjects': 'Fantasy, Fiction, Romance, Science Fiction',
#   'publisher': 'Draft2Digital, LLC',
#   'publicationyear': '2021'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'AUDIOBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '1',
#   'checkouts': '1',
#   'title': 'The One-in-a-Million Boy (unabridged)',
#   'isbn': '9781666574487',
#   'creator': 'Monica Wood',
#   'subjects': 'Fiction, Literature',
#   'publisher': 'Dreamscape Media, LLC',
#   'publicationyear': '2016'},
#  {'usageclass': 'Physical',
#   'checkouttype': 'Horizon',
#   'materialtype': 'BOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '1',
#   'checkouts': '3',
#   'title': 'Wizards of Mickey : the graphic novel. [Volume five] / story by Matteo Venerus, Maria Muzzolini (Lost Legends) ; art by Roberto Marini ; art by Roberto Vian ; translation by Linda Ghio and Sephanie Dagg at Editing Zone ; lettering by Katie Blakeslee.',
#   'isbn': '1975336550, 9781975336554, 9781975336561',
#   'creator': 'Venerus, Matteo',
#   'subjects': 'Mouse Mickey Fictitious character Comic books strips etc, Mouse Mickey Fictitious character Juvenile fiction, Goofy Fictitious character Comic books strips etc, Goofy Fictitious character Juvenile fiction, Duck Donald Fictitious character Comic books strips etc, Duck Donald Fictitious character Juvenile fiction, Magic Comic books strips etc, Magic Juvenile fiction, Wizards Comic books strips etc, Wizards Juvenile fiction, Cartoons and comics, Comics Graphic works, Fantasy comics, Graphic novels',
#   'publisher': 'JY, an imprint of Yen Press, LLC,',
#   'publicationyear': '2021.'},
#  {'usageclass': 'Physical',
#   'checkouttype': 'Horizon',
#   'materialtype': 'BOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '1',
#   'checkouts': '1',
#   'title': 'Austin, lost in America : a geography adventure / Jef Czekaj.',
#   'isbn': '0062280171, 9780062280176',
#   'creator': 'Czekaj, Jef',
#   'subjects': 'Dogs Juvenile fiction, French bulldog Juvenile fiction, Pet adoption Juvenile fiction, Voyages and travels Juvenile fiction, U S states Juvenile fiction',
#   'publisher': 'Balzer + Bray, an imprint of HarperCollinsPublishers,',
#   'publicationyear': '[2015]'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '1',
#   'checkouts': '2',
#   'title': 'The Sable Quean: Redwall Series, Book 21',
#   'isbn': '9781101163214',
#   'creator': 'Brian Jacques',
#   'subjects': 'Fantasy, Juvenile Fiction, Juvenile Literature',
#   'publisher': 'Penguin Group (USA), Inc.',
#   'publicationyear': '2010'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'AUDIOBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '1',
#   'checkouts': '7',
#   'title': 'Zoey and Sassafras: Unicorns and Germs (unabridged)',
#   'isbn': '9781665026345',
#   'creator': 'Asia Citro',
#   'subjects': 'Fantasy, Juvenile Fiction, Juvenile Literature',
#   'publisher': 'Blackstone Audio, Inc.',
#   'publicationyear': '2021'},
#  {'usageclass': 'Physical',
#   'checkouttype': 'Horizon',
#   'materialtype': 'BOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '1',
#   'checkouts': '1',
#   'title': 'Corsair / Clive Cussler with Jack Du Brul.',
#   'isbn': '1597229024, 9781597229029',
#   'creator': 'Cussler, Clive',
#   'subjects': 'Cabrillo Juan Fictitious character Fiction, Mercenary troops Fiction, Large type books, Action and adventure fiction, Sea fiction, Thrillers Fiction',
#   'publisher': 'Wheeler Pub.,',
#   'publicationyear': '2009.'},
#  {'usageclass': 'Physical',
#   'checkouttype': 'Horizon',
#   'materialtype': 'BOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '1',
#   'checkouts': '1',
#   'title': 'Vagabond. Volume 9 / Takehiko Inoue ; [English adaptation by Yuji Oniki ; touch-up and lettering by Steve Dutro].',
#   'isbn': '1421523132, 9781421523132',
#   'creator': 'Inoue, Takehiko',
#   'subjects': 'Miyamoto Musashi 1584 1645 Comic books strips etc, Swordsmen Japan Comic books strips etc, Comic books strips etc Japan Translations into English, Japan History Tokugawa period 1600 1868 Comic books strips etc, Graphic novels, Comics Graphic works',
#   'publisher': 'Viz Comics,',
#   'publicationyear': '[2010]'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'AUDIOBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '1',
#   'checkouts': '2',
#   'title': 'Tales from Shakespeare (unabridged)',
#   'creator': 'Charles Lamb',
#   'subjects': 'Classic Literature, Fiction, Suspense',
#   'publisher': 'Findaway',
#   'publicationyear': '2005'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '1',
#   'checkouts': '1',
#   'title': 'Heaven Is Beyond Your Wildest Expectations: Ten True Stories of Experiencing Heaven',
#   'isbn': '9780768488036',
#   'creator': 'Sid Roth',
#   'subjects': 'Religion & Spirituality, Nonfiction',
#   'publisher': 'Destiny Image Inc',
#   'publicationyear': '2014'},
#  {'usageclass': 'Physical',
#   'checkouttype': 'Horizon',
#   'materialtype': 'BOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '1',
#   'checkouts': '20',
#   'title': 'Luminous : living things that light up the night / Julia Kuo.',
#   'isbn': '1771648880, 9781771648882',
#   'creator': 'Kuo, Julia',
#   'subjects': 'Bioluminescence Juvenile literature, Marine animals Juvenile literature, Fireflies Juvenile literature, Bioluminescence, Marine animals, Fireflies, Creative nonfiction, Informational works, Illustrated works',
#   'publisher': 'Greystone Kids, Greystone Books,',
#   'publicationyear': '[2022]'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '1',
#   'checkouts': '1',
#   'title': 'Tarot for Teens',
#   'isbn': '9781594775550',
#   'creator': 'M. J. Abadie',
#   'subjects': 'New Age, Young Adult Nonfiction',
#   'publisher': 'Simon & Schuster, Inc.',
#   'publicationyear': '2012'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'AUDIOBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '1',
#   'checkouts': '2',
#   'title': "In the Vanishers' Palace (unabridged)",
#   'isbn': '9781977353375',
#   'creator': 'Aliette de Bodard',
#   'subjects': 'Fantasy, Fiction, Literature',
#   'publisher': 'Tantor Media, Inc',
#   'publicationyear': '2019'},
#  {'usageclass': 'Physical',
#   'checkouttype': 'Horizon',
#   'materialtype': 'VIDEODISC',
#   'checkoutyear': '2023',
#   'checkoutmonth': '1',
#   'checkouts': '3',
#   'title': 'Writing with fire / Black Ticket Films presents ; a film by Rintu Thomas & Sushmit Ghosh ; directed by Rintu Thomas & Sushmit Ghosh ; produced by Sushmit Ghosh & Rintu Thomas.',
#   'subjects': 'Khabara lahariya, Rural journalism India Bundelkhand, Women in journalism India Bundelkhand, Women in rural development Press coverage India Bundelkhand, Rural women Social conditions Press coverage India Bundelkhand, Documentary films, Nonfiction films, Feature films',
#   'publisher': 'Music Box Films,',
#   'publicationyear': '[2022]'},
#  {'usageclass': 'Physical',
#   'checkouttype': 'Horizon',
#   'materialtype': 'BOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '1',
#   'checkouts': '1',
#   'title': 'Aubrey Beardsley / edited by Stephen Calloway and Caroline Corbeau-Parsons ; with contributions by Clare Barlow [and 6 others].',
#   'isbn': '1849766800, 9781849766807',
#   'subjects': 'Beardsley Aubrey 1872 1898 Exhibitions, Illustrators 19th century Exhibitions, Exhibition catalogs',
#   'publisher': 'Tate Publishing,',
#   'publicationyear': '2020.'},
#  {'usageclass': 'Physical',
#   'checkouttype': 'Horizon',
#   'materialtype': 'BOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '1',
#   'checkouts': '1',
#   'title': 'The PTSD workbook for teens : simple, effective skills for healing trauma / Libbi Palmer.',
#   'isbn': '1608823210, 9781608823215',
#   'creator': 'Palmer, Libbi',
#   'subjects': 'Post traumatic stress disorder in adolescence Treatment Juvenile literature, Cognitive therapy for teenagers Juvenile literature, Post traumatic stress disorder Juvenile literature, Cognitive therapy Juvenile literature',
#   'publisher': 'Instant Help Books,',
#   'publicationyear': '[2012]'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'AUDIOBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '1',
#   'checkouts': '3',
#   'title': "Spider Woman's Daughter: Joe Leaphorn, Jim Chee & Bernadette Manualito Series, Book 1 (unabridged)",
#   'isbn': '9780062283832',
#   'creator': 'Anne Hillerman',
#   'subjects': 'Fiction, Literature, Mystery',
#   'publisher': 'HarperCollins Publishers Inc.',
#   'publicationyear': '2013'},
#  {'usageclass': 'Physical',
#   'checkouttype': 'Horizon',
#   'materialtype': 'SOUNDDISC',
#   'checkoutyear': '2023',
#   'checkoutmonth': '1',
#   'checkouts': '1',
#   'title': 'Behind closed doors : [a novel] / B.A. Paris.',
#   'isbn': '1427281882, 9781427281883',
#   'creator': 'Paris, B. A.',
#   'subjects': 'Married people Fiction, Marital conflict Fiction, Abusive men Fiction, Family secrets Fiction, Spousal abuse Fiction, Abused women Fiction, Psychological fiction, Thrillers Fiction, Audiobooks',
#   'publisher': 'Macmillan Audio,',
#   'publicationyear': '[2016]'},
#  {'usageclass': 'Physical',
#   'checkouttype': 'Horizon',
#   'materialtype': 'BOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '1',
#   'checkouts': '1',
#   'title': "Star Wars. Captain Phasma / writer, Kelly Thompson ; artist, Marco Checchetto ; letterer, VC's Clayton Cowles.",
#   'isbn': '078519455X, 9780785194552',
#   'creator': 'Thompson, Kelly, 1976-',
#   'subjects': 'Star Wars fiction Comic books strips etc, Space warfare Comic books strips etc, Science fiction comics, Graphic novels',
#   'publisher': 'Marvel Worldwide, Inc., a subsidiary of Marvel Entertainment,',
#   'publicationyear': '[2017]'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '1',
#   'checkouts': '5',
#   'title': 'The Golden Key: Geronimo Stilton and the Kingdom of Fantasy Series, Book 15',
#   'isbn': '9781338848014',
#   'creator': 'Geronimo Stilton',
#   'subjects': 'Juvenile Fiction, Juvenile Literature',
#   'publisher': 'Scholastic, Inc. (US)',
#   'publicationyear': '2022'},
#  {'usageclass': 'Digital',
#   'checkouttype': 'OverDrive',
#   'materialtype': 'EBOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '1',
#   'checkouts': '1',
#   'title': 'Palace of Spies',
#   'isbn': '9780544073753',
#   'creator': 'Sarah Zettel',
#   'subjects': 'Mystery, Historical Fiction, Young Adult Fiction, Young Adult Literature',
#   'publisher': 'Open Road Integrated Media',
#   'publicationyear': '2013'},
#  {'usageclass': 'Physical',
#   'checkouttype': 'Horizon',
#   'materialtype': 'BOOK',
#   'checkoutyear': '2023',
#   'checkoutmonth': '1',
#   'checkouts': '1',
#   'title': "Australia's best trips : 38 amazing road trips / Paul Harding [and fifteen others].",
#   'isbn': '1788683609, 9781788683609',
#   'creator': 'Harding, Paul',
#   'subjects': 'Automobile travel Australia Guidebooks, Australia Guidebooks, Guidebooks',
#   'publisher': 'Lonely Planet,',
#   'publicationyear': '2021.'}]
